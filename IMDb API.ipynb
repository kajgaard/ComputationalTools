# %% [markdown]
# # Get actors, rating and movie title based on titleId
#
# We want to retrieve relevant information from the IMDb API based on the titleId retrieved from the reviews data. In addition to this, the objective is to connect the titleIds and reviews, with corresponding data from the api into a single dataframe.
#
# Link to the API: https://developer.imdb.com/documentation/api-documentation/?ref_=/documentation/_PAGE_BODY

# %%
pip install imdbpy
# Out:
# Collecting imdbpy
#   Downloading IMDbPY-2022.7.9-py3-none-any.whl (1.2 kB)
# Collecting cinemagoer
#   Downloading cinemagoer-2022.2.11-py3-none-any.whl (301 kB)
# Requirement already satisfied: SQLAlchemy in c:\users\maria\anaconda3\lib\site-packages (from cinemagoer->imdbpy) (1.4.32)
# Requirement already satisfied: lxml in c:\users\maria\anaconda3\lib\site-packages (from cinemagoer->imdbpy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\maria\anaconda3\lib\site-packages (from SQLAlchemy->cinemagoer->imdbpy) (1.1.1)
# Installing collected packages: cinemagoer, imdbpy
# Successfully installed cinemagoer-2022.2.11 imdbpy-2022.7.9
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install import-ipynb
# Out:
# Collecting import-ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: IPython in c:\users\maria\anaconda3\lib\site-packages (from import-ipynb) (8.2.0)
# Requirement already satisfied: nbformat in c:\users\maria\anaconda3\lib\site-packages (from import-ipynb) (5.3.0)
# Requirement already satisfied: stack-data in c:\users\maria\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: colorama in c:\users\maria\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.4.4)
# Requirement already satisfied: traitlets>=5 in c:\users\maria\anaconda3\lib\site-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\maria\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: decorator in c:\users\maria\anaconda3\lib\site-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\maria\anaconda3\lib\site-packages (from IPython->import-ipynb) (61.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\maria\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\maria\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.1.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\maria\anaconda3\lib\site-packages (from IPython->import-ipynb) (2.11.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\maria\anaconda3\lib\site-packages (from IPython->import-ipynb) (3.0.20)
# Requirement already satisfied: backcall in c:\users\maria\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\maria\anaconda3\lib\site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\maria\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: jupyter-core in c:\users\maria\anaconda3\lib\site-packages (from nbformat->import-ipynb) (4.9.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\maria\anaconda3\lib\site-packages (from nbformat->import-ipynb) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\maria\anaconda3\lib\site-packages (from nbformat->import-ipynb) (2.15.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\maria\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\maria\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.18.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\maria\anaconda3\lib\site-packages (from jupyter-core->nbformat->import-ipynb) (302)
# Requirement already satisfied: pure-eval in c:\users\maria\anaconda3\lib\site-packages (from stack-data->IPython->import-ipynb) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\maria\anaconda3\lib\site-packages (from stack-data->IPython->import-ipynb) (2.0.5)
# Requirement already satisfied: executing in c:\users\maria\anaconda3\lib\site-packages (from stack-data->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: six in c:\users\maria\anaconda3\lib\site-packages (from asttokens->stack-data->IPython->import-ipynb) (1.16.0)
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import imdb
import pandas as pd
import numpy as np
import re


db = imdb.IMDb()

#print(dir(moviesDB)) #Get available keys

def getMovie(id):
    movie = db.get_movie(id)
    return movie

def getActors(movie):
    try:
        top_actors_list = movie['cast'][:10]
        actors = re.findall('_([A-Za-z ]+)_', str(top_actors_list))
        return list(actors)
    except KeyError:
        print("Oops!  Movie has no or few actors...")
        return False

# %%
reviewsDf = pd.read_pickle("reviewsDf.pkl")
reviewsDf
# Out:
#                                                  reviews  titleId
# 0      ["I went and saw this movie last night after b...  0406816
# 1      ["My boyfriend and I went to watch The Guardia...  0406816
# 2      ['My yardstick for measuring a movie\'s watch-...  0406816
# 3      ["How many movies are there that you can think...  0406816
# 4      ["This movie was sadly under-promoted but prov...  0406816
# ...                                                  ...      ...
# 24995  ["CyberTracker is set in Los Angeles sometime ...  0109515
# 24996  ["Eric Phillips (Don Wilson) is a secret servi...  0109515
# 24997  ['Plot Synopsis: Los Angeles in the future. Cr...  0109515
# 24998  ['Oh, dear! This has to be one of the worst fi...  0109515
# 24999  ['This movie was sooo bad. It wasn\'t even fun...  0485161
#
# [25000 rows x 2 columns]

# %%
titleId_column = reviewsDf["titleId"].to_numpy()
listOfMovieIds = np.unique(titleId_column)
listOfMovieIds = list(listOfMovieIds)

# %%
df = pd.DataFrame()
for titleId in listOfMovieIds: 
    print(listOfMovieIds.index(titleId), "of", len(listOfMovieIds))
    movie = getMovie(titleId)
    title = movie['title']
    hasActors = getActors(movie)
    if(hasActors):
        new_row = pd.Series({'TitleId':titleId, 'MovieTitle':title, 'Actors': hasActors})
        df = pd.concat([df, new_row.to_frame().T], ignore_index=True)
        
    else:
        print("removing title: ", title)
        cleaned_movieId_list = listOfMovieIds.remove(titleId)
# Out:
# 0 of 3581
# Oops!  Movie has no or few actors...
# removing title:  Rough Sea at Dover
# 1 of 3580
# 2 of 3580
# 3 of 3580
# 4 of 3580
# 5 of 3580
# 6 of 3580
# 7 of 3580
# 8 of 3580
# 9 of 3580
# 10 of 3580
# 11 of 3580
# 12 of 3580
# 13 of 3580
# 14 of 3580
# 15 of 3580
# 16 of 3580
# 17 of 3580
# 18 of 3580
# 19 of 3580
# 20 of 3580
# 21 of 3580
# 22 of 3580
# 23 of 3580
# 24 of 3580
# 25 of 3580
# 26 of 3580
# 27 of 3580
# 28 of 3580
# 29 of 3580
# 30 of 3580
# Oops!  Movie has no or few actors...
# removing title:  The Frogs Who Wanted a King
# 31 of 3579
# 32 of 3579
# 33 of 3579
# 34 of 3579
# 35 of 3579
# 36 of 3579
# 37 of 3579
# 38 of 3579
# 39 of 3579
# 40 of 3579
# 41 of 3579
# 42 of 3579
# Oops!  Movie has no or few actors...
# removing title:  Felix in Hollywood
# 43 of 3578
# 44 of 3578
# 45 of 3578
# 46 of 3578
# 47 of 3578
# 48 of 3578
# 49 of 3578
# 50 of 3578
# 51 of 3578
# 52 of 3578
# 53 of 3578
# 54 of 3578
# 55 of 3578
# 56 of 3578
# 57 of 3578
# 58 of 3578
# 59 of 3578
# 60 of 3578
# 61 of 3578
# 62 of 3578
# 63 of 3578
# 64 of 3578
# 65 of 3578
# 66 of 3578
# 67 of 3578
# 68 of 3578
# 69 of 3578
# 70 of 3578
# 71 of 3578
# 72 of 3578
# 73 of 3578
# 74 of 3578
# 75 of 3578
# 76 of 3578
# 77 of 3578
# 78 of 3578
# 79 of 3578
# 80 of 3578
# 81 of 3578
# 82 of 3578
# 83 of 3578
# 84 of 3578
# 85 of 3578
# 86 of 3578
# 87 of 3578
# 88 of 3578
# 89 of 3578
# 90 of 3578
# 91 of 3578
# 92 of 3578
# 93 of 3578
# 94 of 3578
# 95 of 3578
# 96 of 3578
# 97 of 3578
# 98 of 3578
# 99 of 3578
# 100 of 3578
# 101 of 3578
# 102 of 3578
# 103 of 3578
# 104 of 3578
# 105 of 3578
# 943 of 3578
# 944 of 3578
# 945 of 3578
# 946 of 3578
# 947 of 3578
# 948 of 3578
# 949 of 3578
# 950 of 3578
# 951 of 3578
# 952 of 3578
# 953 of 3578
# 954 of 3578
# 955 of 3578
# 956 of 3578
# 957 of 3578
# 958 of 3578
# 959 of 3578
# 960 of 3578
# 961 of 3578
# 962 of 3578
# 963 of 3578
# 964 of 3578
# 965 of 3578
# 966 of 3578
# 967 of 3578
# 968 of 3578
# 969 of 3578
# 970 of 3578
# 971 of 3578
# 972 of 3578
# 973 of 3578
# 974 of 3578
# 975 of 3578
# 976 of 3578
# 977 of 3578
# 978 of 3578
# 979 of 3578
# 2022-11-03 18:00:35,043 CRITICAL [imdbpy] C:\Users\Maria\anaconda3\lib\site-packages\imdb\_exceptions.py:32: IMDbDataAccessError exception raised; args: ({'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0088512/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': timeout('The read operation timed out')},); kwds: {}
# Traceback (most recent call last):
#   File "C:\Users\Maria\anaconda3\lib\site-packages\imdb\parser\http\__init__.py", line 221, in retrieve_unicode
#     response = uopener.open(url)
#   File "C:\Users\Maria\anaconda3\lib\urllib\request.py", line 517, in open
#     response = self._open(req, data)
#   File "C:\Users\Maria\anaconda3\lib\urllib\request.py", line 534, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "C:\Users\Maria\anaconda3\lib\urllib\request.py", line 494, in _call_chain
#     result = func(*args)
#   File "C:\Users\Maria\anaconda3\lib\urllib\request.py", line 1389, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "C:\Users\Maria\anaconda3\lib\urllib\request.py", line 1350, in do_open
#     r = h.getresponse()
#   File "C:\Users\Maria\anaconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\Maria\anaconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\Maria\anaconda3\lib\http\client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\Maria\anaconda3\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Maria\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Maria\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
# 2022-11-03 18:00:35,058 CRITICAL [imdbpy] C:\Users\Maria\anaconda3\lib\site-packages\imdb\__init__.py:833: caught an exception retrieving or parsing "main" info set for mopID "0088512" (accessSystem: http)
# Traceback (most recent call last):
#   File "C:\Users\Maria\anaconda3\lib\site-packages\imdb\parser\http\__init__.py", line 221, in retrieve_unicode
#     response = uopener.open(url)
#   File "C:\Users\Maria\anaconda3\lib\urllib\request.py", line 517, in open
#     response = self._open(req, data)
#   File "C:\Users\Maria\anaconda3\lib\urllib\request.py", line 534, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "C:\Users\Maria\anaconda3\lib\urllib\request.py", line 494, in _call_chain
#     result = func(*args)
#   File "C:\Users\Maria\anaconda3\lib\urllib\request.py", line 1389, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "C:\Users\Maria\anaconda3\lib\urllib\request.py", line 1350, in do_open
#     r = h.getresponse()
#   File "C:\Users\Maria\anaconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\Maria\anaconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\Maria\anaconda3\lib\http\client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\Maria\anaconda3\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Maria\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Maria\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Maria\anaconda3\lib\site-packages\imdb\__init__.py", line 831, in update
#     ret = method(mopID)
#   File "C:\Users\Maria\anaconda3\lib\site-packages\imdb\parser\http\__init__.py", line 468, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#   File "C:\Users\Maria\anaconda3\lib\site-packages\imdb\parser\http\__init__.py", line 379, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "C:\Users\Maria\anaconda3\lib\site-packages\imdb\parser\http\__init__.py", line 249, in retrieve_unicode
#     raise IMDbDataAccessError(
# imdb._exceptions.IMDbDataAccessError: {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0088512/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': timeout('The read operation timed out')}
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\imdb\parser\http\__init__.py:221, in IMDbURLopener.retrieve_unicode(self, url, size)
#     220 uopener.addheaders = list(self.addheaders)
# --> 221 response = uopener.open(url)
#     222 content = response.read()
#
# File ~\anaconda3\lib\urllib\request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#
# File ~\anaconda3\lib\urllib\request.py:534, in OpenerDirector._open(self, req, data)
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#
# File ~\anaconda3\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     493 func = getattr(handler, meth_name)
# --> 494 result = func(*args)
#     495 if result is not None:
#
# File ~\anaconda3\lib\urllib\request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File ~\anaconda3\lib\urllib\request.py:1350, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1349         raise URLError(err)
# -> 1350     r = h.getresponse()
#    1351 except:
#
# File ~\anaconda3\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1376 try:
# -> 1377     response.begin()
#    1378 except ConnectionError:
#
# File ~\anaconda3\lib\http\client.py:320, in HTTPResponse.begin(self)
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#
# File ~\anaconda3\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#
# File ~\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     703 try:
# --> 704     return self._sock.recv_into(b)
#     705 except timeout:
#
# File ~\anaconda3\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File ~\anaconda3\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# IMDbDataAccessError                       Traceback (most recent call last)
# Input In [170], in <cell line: 2>()
#       2 for titleId in listOfMovieIds:
#       3     print(listOfMovieIds.index(titleId), "of", len(listOfMovieIds))
# ----> 4     movie = getMovie(titleId)
#       5     title = movie['title']
#       6     hasActors = getActors(movie)
#
# Input In [132], in getMovie(id)
#      11 def getMovie(id):
# ---> 12     movie = db.get_movie(id)
#      13     return movie
#
# File ~\anaconda3\lib\site-packages\imdb\__init__.py:423, in IMDbBase.get_movie(self, movieID, info, modFunct)
#     421 if modFunct is not None:
#     422     movie.set_mod_funct(modFunct)
# --> 423 self.update(movie, info)
#     424 return movie
#
# File ~\anaconda3\lib\site-packages\imdb\__init__.py:831, in IMDbBase.update(self, mop, info, override)
#     829     method = lambda *x: {}
#     830 try:
# --> 831     ret = method(mopID)
#     832 except Exception:
#     833     _imdb_logger.critical(
#     834         'caught an exception retrieving or parsing "%s" info set'
#     835         ' for mopID "%s" (accessSystem: %s)',
#     836         i, mopID, mop.accessSystem, exc_info=True
#     837     )
#
# File ~\anaconda3\lib\site-packages\imdb\parser\http\__init__.py:468, in IMDbHTTPAccessSystem.get_movie_main(self, movieID)
#     467 def get_movie_main(self, movieID):
# --> 468     cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#     469     return self.mProxy.movie_parser.parse(cont, mdparse=self._mdparse)
#
# File ~\anaconda3\lib\site-packages\imdb\parser\http\__init__.py:379, in IMDbHTTPAccessSystem._retrieve(self, url, size, _noCookies)
#     377 """Retrieve the given URL."""
#     378 self._http_logger.debug('fetching url %s (size: %d)', url, size)
# --> 379 ret = self.urlOpener.retrieve_unicode(url, size=size)
#     380 if PY2 and isinstance(ret, str):
#     381     ret = ret.decode('utf-8')
#
# File ~\anaconda3\lib\site-packages\imdb\parser\http\__init__.py:249, in IMDbURLopener.retrieve_unicode(self, url, size)
#     246     if size != -1:
#     247         # Ensure that the Range header is removed.
#     248         self.del_header('Range')
# --> 249     raise IMDbDataAccessError(
#     250         {'errcode': e.errno,
#     251          'errmsg': str(e.strerror),
#     252          'url': url,
#     253          'proxy': self.get_proxy(),
#     254          'exception type': 'IOError',
#     255          'original exception': e}
#     256     )
#     257 if encode is None:
#     258     encode = 'utf8'
#
# IMDbDataAccessError: {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0088512/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': timeout('The read operation timed out')}

# %%
df
# Out:
#      TitleId                          MovieTitle  \
# 0    0000399              Jack and the Beanstalk
# 1    0000430                     A Chess Dispute
# 2    0000653              A Calamitous Elopement
# 3    0002816              The Drummer of the 8th
# 4    0003662       The Battle of Elderbush Gulch
# ..       ...                                 ...
# 971  0088249                Terror in the Aisles
# 972  0088263           Michael Jackson: Thriller
# 973  0088323               The NeverEnding Story
# 974  0088381  Nausicaä of the Valley of the Wind
# 975  0088402                       The Wild Life
#
#                                                 Actors
# 0                                       [Thomas White]
# 1                                     [Alfred Collins]
# 2    [Harry Solter, Linda Arvidson, Charles Inslee,...
# 3       [Cyril Gardner, Mildred Harris, Frank Borzage]
# 4    [Mae Marsh, Leslie Loveridge, Alfred Paget, Ro...
# ..                                                 ...
# 971  [Donald Pleasence, Nancy Allen, Fred Asparagus...
# 972  [Michael Jackson, Ola Ray, Brandon Scott Mille...
# 973  [Barret Oliver, Gerald McRaney, Chris Eastman,...
# 974  [Sumi Shimamoto, Mahito Tsujimura, Minoru Yada...
# 975  [Chris Penn, Eric Stoltz, Jenny Wright, Lea Th...
#
# [976 rows x 3 columns]

# %%
df.to_pickle("moviesDf.pkl")
