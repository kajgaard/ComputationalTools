# %%
import imdb
import pandas as pd
import numpy as np
import re
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Dataset can be found here:
# https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset?resource=download

# %%
df = pd.read_csv("archive/movies_metadata.csv")
df2=df.dropna(subset=['imdb_id','genres'])
# Extracting the columns to be used
titles = df2['original_title'].to_numpy()
genres = df2['genres'].to_numpy()
imdbIds = df2['imdb_id'].to_numpy()

# Removing NaN
imdbIds = [idee.replace('tt','') for idee in imdbIds]

# %%
# Defining imdb object
db = imdb.IMDb()

# %%
def getActors(movie):
    try:
        top_actors_list = movie['cast']#[:10]
        actors = re.findall('_([A-Za-z ]+)_', str(top_actors_list))
        return list(actors)
    except KeyError:
        print("Oops!  Movie has no or few actors...")
        return False

def getReviews(movie):
    try:
        reviews = []
        # Concatenating all reviews for given movie
        for review in movie['reviews']:
            content = review['content']
            reviews.append(content)       
        return reviews
    except:
        print("Oops! Movie has not been reviewed...")
        return False
    
def getMovie(id):
    movie = db.get_movie(id,['main', 'reviews'])
    return movie

# %%
df = pd.DataFrame()
#N = 500
#for i, titge in enumerate(zip(titles[:N], genres[:N], imdbIds[:N])):
for i, titge in enumerate(zip(titles, genres, imdbIds)):

    title, genre, imdbId = titge
    print(f'{i} + {title}')
    
    movie = getMovie(imdbId)
    reviews = getReviews(movie)
    
    # Check that movie has been reviewed
    if(reviews):
        actors = getActors(movie)
        
        # Check that movie has enough actors
        if(actors):
            new_row = pd.Series({'TitleId':imdbId, 'MovieTitle':title, 'Actors': actors, 'Genres': genre, 'Reviews': reviews})
            df = pd.concat([df, new_row.to_frame().T], ignore_index=True)
# Out:
# 0 + Toy Story
# 1 + Jumanji
# 2 + Grumpier Old Men
# 3 + Waiting to Exhale
# 4 + Father of the Bride Part II
# 5 + Heat
# 6 + Sabrina
# 7 + Tom and Huck
# 8 + Sudden Death
# 9 + GoldenEye
# 10 + The American President
# 11 + Dracula: Dead and Loving It
# 12 + Balto
# 13 + Nixon
# 14 + Cutthroat Island
# 15 + Casino
# 16 + Sense and Sensibility
# 17 + Four Rooms
# 18 + Ace Ventura: When Nature Calls
# 19 + Money Train
# 20 + Get Shorty
# 21 + Copycat
# 22 + Assassins
# 23 + Powder
# 24 + Leaving Las Vegas
# 25 + Othello
# 26 + Now and Then
# 27 + Persuasion
# 28 + La Cité des Enfants Perdus
# 29 + 摇啊摇，摇到外婆桥
# 30 + Dangerous Minds
# 31 + Twelve Monkeys
# 32 + Guillaumet, les ailes du courage
# 33 + Babe
# 34 + Carrington
# 35 + Dead Man Walking
# 36 + Across the Sea of Time
# 37 + It Takes Two
# 38 + Clueless
# 39 + Cry, the Beloved Country
# 40 + Richard III
# 41 + Dead Presidents
# 42 + Restoration
# 43 + Mortal Kombat
# 44 + To Die For
# 45 + How To Make An American Quilt
# 46 + Se7en
# 47 + Pocahontas
# 48 + When Night Is Falling
# 49 + The Usual Suspects
# 50 + Guardian Angel
# 51 + Mighty Aphrodite
# 52 + Lamerica
# 53 + The Big Green
# 54 + Georgia
# 55 + Kids of the Round Table
# 56 + Home for the Holidays
# 57 + Il postino
# 58 + Le confessionnal
# 59 + The Indian in the Cupboard
# 60 + Eye for an Eye
# 61 + Mr. Holland's Opus
# 62 + Don't Be a Menace to South Central While Drinking Your Juice in the Hood
# 63 + Two If by Sea
# 64 + Bio-Dome
# 65 + Lawnmower Man 2: Beyond Cyberspace
# 66 + Two Bits
# 67 + Gazon maudit
# 68 + Friday
# 69 + From Dusk Till Dawn
# 70 + Fair Game
# 71 + Kicking and Screaming
# 72 + Les misérables
# 73 + Bed of Roses
# 74 + Big Bully
# 75 + Screamers
# 76 + Nico Icon
# 77 + The Crossing Guard
# 78 + The Juror
# 79 + بادکنک سفید
# 80 + Things to Do in Denver When You're Dead
# 81 + Antonia
# 82 + Once Upon a Time... When We Were Colored
# 83 + Last Summer in the Hamptons
# 84 + Angels and Insects
# 85 + White Squall
# 86 + Dunston Checks In
# 87 + Black Sheep
# 88 + Nick of Time
# 89 + The Journey of August King
# 90 + Mary Reilly
# 91 + Vampire in Brooklyn
# 92 + Beautiful Girls
# 93 + Broken Arrow
# 94 + A Midwinter's Tale
# 95 + La Haine
# 96 + Shopping
# 97 + Heidi Fleiss: Hollywood Madam
# 98 + City Hall
# 99 + Bottle Rocket
# 100 + Mr. Wrong
# 101 + Unforgettable
# 102 + Happy Gilmore
# 103 + The Bridges of Madison County
# 104 + Keiner liebt mich
# 105 + Muppet Treasure Island
# 106 + Catwalk
# 107 + Headless Body in Topless Bar
# 108 + Braveheart
# 109 + Taxi Driver
# 110 + 紅番區
# 111 + Before and After
# 112 + Margaret's Museum
# 113 + Le Bonheur est dans le pré
# 114 + Anne Frank Remembered
# 115 + The Young Poisoner's Handbook
# 116 + If Lucy Fell
# 117 + Steal Big Steal Little
# 118 + Race the Sun
# 119 + The Boys of St. Vincent
# 120 + Boomerang
# 121 + 重慶森林
# 122 + L'uomo delle stelle
# 123 + Flirting with Disaster
# 124 + The NeverEnding Story III
# 125 + صمت القصور
# 126 + Jupiter's Wife
# 127 + Pie in the Sky
# 128 + Angela
# 129 + Frankie Starlight
# 130 + Jade
# 131 + Nueba Yol
# 132 + Sonic Outlaws
# 133 + Down Periscope
# 134 + From the Journals of Jean Seberg
# 135 + Man of the Year
# 136 + The Neon Bible
# 137 + Target
# 138 + Up Close & Personal
# 139 + The Birdcage
# 140 + Gospa
# 141 + The Brothers McMullen
# 142 + Bad Boys
# 143 + The Amazing Panda Adventure
# 144 + The Basketball Diaries
# 145 + An Awfully Big Adventure
# 146 + Amateur
# 147 + Apollo 13
# 148 + Rob Roy
# 149 + The Addiction
# 150 + Batman Forever
# 151 + Belle de jour
# 152 + Beyond Rangoon
# 153 + Blue in the Face
# 154 + Canadian Bacon
# 155 + Casper
# 156 + Clockers
# 157 + Congo
# 158 + Crimson Tide
# 159 + Crumb
# 160 + Desperado
# 161 + Devil in a Blue Dress
# 162 + Die Hard: With a Vengeance
# 163 + The Doom Generation
# 164 + Feast of July
# 165 + First Knight
# 166 + Free Willy 2 - The Adventure Home
# 167 + Hackers
# 168 + Jeffrey
# 169 + Johnny Mnemonic
# 170 + Judge Dredd
# 171 + Jury Duty
# 172 + Kids
# 173 + Living in Oblivion
# 174 + Lord of Illusions
# 175 + Love & Human Remains
# 176 + Mad Love
# 177 + Mallrats
# 178 + Mighty Morphin Power Rangers: The Movie
# 179 + Moonlight and Valentino
# 180 + Mute Witness
# 181 + Nadja
# 182 + The Net
# 183 + Nine Months
# 184 + Party Girl
# 185 + The Prophecy
# 186 + Reckless
# 187 + Safe
# 188 + The Scarlet Letter
# 189 + The Show
# 190 + Showgirls
# 191 + Smoke
# 192 + Something to Talk About
# 193 + Species
# 194 + The Stars Fell on Henrietta
# 195 + Strange Days
# 196 + Les parapluies de Cherbourg
# 197 + The Tie That Binds
# 198 + Three Wishes
# 199 + Total Eclipse
# 200 + To Wong Foo, Thanks for Everything! Julie Newmar
# 201 + Under Siege 2: Dark Territory
# 202 + Unstrung Heroes
# 203 + Unzipped
# 204 + A Walk in the Clouds
# 205 + Waterworld
# 206 + White Man's Burden
# 207 + Wild Bill
# 208 + The Browning Version
# 209 + Bushwhacked
# 210 + Утомлённые солнцем
# 211 + Before the Rain
# 212 + Before Sunrise
# 213 + Billy Madison
# 214 + The Babysitter
# 215 + Boys on the Side
# 216 + The Cure
# 217 + Castle Freak
# 218 + Circle of Friends
# 219 + Clerks
# 220 + Don Juan DeMarco
# 221 + Disclosure
# 222 + Dream Man
# 223 + Drop Zone
# 224 + Destiny Turns on the Radio
# 225 + Death and the Maiden
# 226 + Dolores Claiborne
# 227 + Dumb and Dumber
# 228 + 飲食男女
# 229 + Exotica
# 230 + Exit to Eden
# 231 + Ed Wood
# 232 + French Kiss
# 233 + Forget Paris
# 234 + Far from Home: The Adventures of Yellow Dog
# 235 + A Goofy Movie
# 236 + Hideaway
# 237 + Fluke
# 238 + Farinelli
# 239 + Gordy
# 240 + Gumby: The Movie
# 241 + The Glass Shield
# 242 + Hoop Dreams
# 243 + Heavenly Creatures
# 244 + Houseguest
# 245 + Immortal Beloved
# 246 + Heavyweights
# 247 + The Hunted
# 248 + I.Q.
# 249 + Interview with the Vampire
# 250 + Jefferson in Paris
# 251 + The Jerky Boys
# 252 + Junior
# 253 + Just Cause
# 254 + A Kid in King Arthur's Court
# 255 + Kiss of Death
# 256 + Star Wars
# 257 + Little Women
# 258 + A Little Princess
# 259 + Ladybird Ladybird
# 260 + L'Enfer
# 261 + Como agua para chocolate
# 262 + Legends of the Fall
# 263 + Major Payne
# 264 + Little Odessa
# 265 + Mi Vida Loca
# 266 + Love Affair
# 267 + Losing Isaiah
# 268 + The Madness of King George
# 269 + Frankenstein
# 270 + Man of the House
# 271 + Mixed Nuts
# 272 + Milk Money
# 273 + Miracle on 34th Street
# 274 + Miami Rhapsody
# 275 + My Family
# 276 + Murder in the First
# 277 + Nobody's Fool
# 278 + Nell
# 279 + New Jersey Drive
# 280 + New York Cop
# 281 + Beyond Bedlam
# 282 + Nemesis 2 - Nebula
# 283 + Nina Takes a Lover
# 284 + Natural Born Killers
# 285 + Only You
# 286 + Once Were Warriors
# 287 + Poison Ivy II: Lily
# 288 + Outbreak
# 289 + Léon
# 290 + The Perez Family
# 291 + A Pyromaniac's Love Story
# 292 + Pulp Fiction
# 293 + Panther
# 294 + Pushing Hands
# 295 + Priest
# 296 + Quiz Show
# 297 + Picture Bride
# 298 + La Reine Margot
# 299 + The Quick and the Dead
# 300 + Roommates
# 301 + Prêt-à-Porter
# 302 + Trois couleurs : Rouge
# 303 + Trois couleurs : Bleu
# 304 + Trois couleurs : Blanc
# 305 + Pao Da Shuang Deng
# 306 + Rent-a-Kid
# 307 + Relative Fear
# 308 + Stuart Saves His Family
# 309 + The Swan Princess
# 310 + The Secret of Roan Inish
# 311 + The Specialist
# 312 + Stargate
# 313 + The Santa Clause
# 314 + The Shawshank Redemption
# 315 + Shallow Grave
# 316 + Suture
# 317 + Fresa y chocolate
# 318 + Swimming with Sharks
# 319 + The Sum of Us
# 320 + Senior Trip
# 321 + 活着
# 322 + Tank Girl
# 323 + Tales from the Crypt: Demon Knight
# 324 + Star Trek: Generations
# 325 + Tales from the Hood
# 326 + Tom & Viv
# 327 + Village of the Damned
# 328 + Tommy Boy
# 329 + Vanya on 42nd Street
# 330 + The Underneath
# 331 + The Walking Dead
# 332 + What's Eating Gilbert Grape
# 333 + Virtuosity
# 334 + While You Were Sleeping
# 335 + The War
# 336 + Double Happiness
# 337 + Muriel's Wedding
# 338 + The Baby-Sitters Club
# 339 + Ace Ventura: Pet Detective
# 340 + The Adventures of Priscilla, Queen of the Desert
# 341 + Backbeat
# 342 + Bitter Moon
# 343 + Bullets Over Broadway
# 344 + Clear and Present Danger
# 345 + The Client
# 346 + Corrina, Corrina
# 347 + Crooklyn
# 348 + The Crow
# 349 + Cobb
# 350 + The Flintstones
# 351 + Forrest Gump
# 352 + Four Weddings and a Funeral
# 353 + Higher Learning
# 354 + I Like It Like That
# 355 + I Love Trouble
# 356 + It Could Happen to You
# 357 + The Jungle Book
# 358 + Die Macht der Bilder: Leni Riefenstahl
# 359 + The Lion King
# 360 + Little Buddha
# 361 + New Nightmare
# 362 + The Mask
# 363 + Maverick
# 364 + Mrs. Parker and the Vicious Circle
# 365 + The Naked Gun 33⅓: The Final Insult
# 366 + The Paper
# 367 + Reality Bites
# 368 + Red Rock West
# 369 + Ri¢hie Ri¢h
# 370 + Safe Passage
# 371 + The River Wild
# 372 + Speed
# 373 + Speechless
# 374 + Timecop
# 375 + True Lies
# 376 + When a Man Loves a Woman
# 377 + Wolf
# 378 + Wyatt Earp
# 379 + Bad Company
# 380 + A Man of No Importance
# 381 + S.F.W.
# 382 + A Low Down Dirty Shame
# 383 + Boys Life: Three Stories of Love, Lust, and Liberation
# 384 + Le colonel Chabert
# 385 + Faster, Pussycat! Kill! Kill!
# 386 + Jason's Lyric
# 387 + The Secret Adventures of Tom Thumb
# 388 + Street Fighter
# 389 + Coldblooded
# 390 + Desert Winds
# 391 + Fall Time
# 392 + The Fear
# 393 + Frank and Ollie
# 394 + Girl in the Cadillac
# 395 + Homage
# 396 + Mirage
# 397 + Open Season
# 398 + Dos Crímenes
# 399 + Brother Minister: The Assassination of Malcolm X
# 400 + Highlander III: The Sorcerer
# 401 + Federal Hill
# 402 + In the Mouth of Madness
# 403 + 8 Seconds
# 404 + Above the Rim
# 405 + Addams Family Values
# 406 + Martin Lawrence: You So Crazy
# 407 + The Age of Innocence
# 408 + Airheads
# 409 + The Air Up There
# 410 + Another Stakeout
# 411 + Bad Girls
# 412 + Barcelona
# 413 + Being Human
# 414 + The Beverly Hillbillies
# 415 + Beverly Hills Cop III
# 416 + Black Beauty
# 417 + Blink
# 418 + Blown Away
# 419 + Blue Chips
# 420 + Blue Sky
# 421 + Body Snatchers
# 422 + Boxing Helena
# 423 + A Bronx Tale
# 424 + Cabin Boy
# 425 + Calendar Girl
# 426 + Carlito's Way
# 427 + City Slickers II: The Legend of Curly's Gold
# 428 + Clean Slate
# 429 + Cliffhanger
# 430 + Coneheads
# 431 + Color of Night
# 432 + Cops & Robbersons
# 433 + The Cowboy Way
# 434 + Dangerous Game
# 435 + Dave
# 436 + Dazed and Confused
# 437 + Demolition Man
# 438 + The Endless Summer 2
# 439 + Even Cowgirls Get the Blues
# 440 + Fatal Instinct
# 441 + 霸王别姬
# 442 + The Favor
# 443 + Fearless
# 444 + Fear of a Black Hat
# 445 + With Honors
# 446 + Flesh and Bone
# 447 + Widows' Peak
# 448 + For Love or Money
# 449 + The Firm
# 450 + Free Willy
# 451 + Fresh
# 452 + The Fugitive
# 453 + Geronimo: An American Legend
# 454 + The Getaway
# 455 + Getting Even with Dad
# 456 + Go Fish
# 457 + A Good Man in Africa
# 458 + Guilty as Sin
# 459 + Hard Target
# 460 + Heaven & Earth
# 461 + Hot Shots! Part Deux
# 462 + Live Nude Girls
# 463 + The Englishman Who Went Up a Hill But Came Down a Mountain
# 464 + The House of the Spirits
# 465 + House Party 3
# 466 + The Hudsucker Proxy
# 467 + I'll Do Anything
# 468 + In the Army Now
# 469 + In the Line of Fire
# 470 + In the Name of the Father
# 471 + The Inkwell
# 472 + What's Love Got to Do with It
# 473 + Jimmy Hollywood
# 474 + Judgment Night
# 475 + Jurassic Park
# 476 + Kalifornia
# 477 + Killing Zoe
# 478 + King of the Hill
# 479 + Lassie
# 480 + Last Action Hero
# 481 + Life With Mikey
# 482 + Lightning Jack
# 483 + M. Butterfly
# 484 + Made in America
# 485 + Malice
# 486 + The Man without a Face
# 487 + Manhattan Murder Mystery
# 488 + Menace II Society
# 489 + Executive Decision
# 490 + 愛のコリーダ
# 491 + What Happened Was...
# 492 + Much Ado About Nothing
# 493 + Mr. Jones
# 494 + Mr. Wonderful
# 495 + Mrs. Doubtfire
# 496 + Naked
# 497 + The Next Karate Kid
# 498 + The New Age
# 499 + No Escape
# 500 + North
# 501 + Orlando
# 502 + A Perfect World
# 503 + Philadelphia
# 504 + The Piano
# 505 + Poetic Justice
# 506 + The Program
# 507 + The Puppet Masters
# 508 + Radioland Murders
# 509 + The Ref
# 510 + The Remains of the Day
# 511 + Renaissance Man
# 512 + Rising Sun
# 513 + The Road to Wellville
# 514 + RoboCop 3
# 515 + Robin Hood: Men in Tights
# 516 + Romeo Is Bleeding
# 517 + Romper Stomper
# 518 + Ruby in Paradise
# 519 + Rudy
# 520 + The Saint of Fort Washington
# 521 + Les Nuits Fauves
# 522 + Schindler's List
# 523 + The Scout
# 524 + Searching for Bobby Fischer
# 525 + Second Best
# 526 + The Secret Garden
# 527 + Serial Mom
# 528 + The Shadow
# 529 + Shadowlands
# 530 + Short Cuts
# 531 + A Simple Twist of Fate
# 532 + Sirens
# 533 + Six Degrees of Separation
# 534 + Sleepless in Seattle
# 535 + Sliver
# 536 + Blade Runner
# 537 + Son in Law
# 538 + So I Married an Axe Murderer
# 539 + Striking Distance
# 540 + Harem
# 541 + Super Mario Bros.
# 542 + Surviving the Game
# 543 + Terminal Velocity
# 544 + Thirty Two Short Films About Glenn Gould
# 545 + Threesome
# 546 + The Nightmare Before Christmas
# 547 + The Three Musketeers
# 548 + Tombstone
# 549 + Trial by Jury
# 550 + True Romance
# 551 + The War Room
# 552 + The Pagemaster
# 553 + Paris, France
# 554 + The Beans of Egypt, Maine
# 555 + Killer
# 556 + Welcome to the Dollhouse
# 557 + Germinal
# 558 + Chasers
# 559 + Cronos
# 560 + Naked in New York
# 561 + Kika
# 562 + Bhaji on the Beach
# 563 + Little Big League
# 564 + Kådisbellan
# 565 + Wide Eyed and Legless
# 566 + Foreign Student
# 567 + Io speriamo che me la cavo
# 568 + Spanking the Monkey
# 569 + The Little Rascals
# 570 + À la mode
# 571 + Andre
# 572 + La scorta
# 573 + Princess Caraboo
# 574 + The Celluloid Closet
# 575 + Métisse
# 576 + Caro diario
# 577 + De eso no se habla
# 578 + The Brady Bunch Movie
# 579 + Home Alone
# 580 + Ghost
# 581 + Aladdin
# 582 + Terminator 2: Judgment Day
# 583 + Dances with Wolves
# 584 + Tough and Deadly
# 585 + Batman
# 586 + The Silence of the Lambs
# 587 + Snow White and the Seven Dwarfs
# 588 + Beauty and the Beast
# 589 + Pinocchio
# 590 + Pretty Woman
# 591 + Окно в Париж
# 592 + The Wild Bunch
# 593 + Love and a .45
# 594 + The Wooden Man's Bride
# 595 + A Great Day in Harlem
# 596 + Bye Bye Love
# 597 + One Fine Day
# 598 + Candyman: Farewell to the Flesh
# 599 + Century
# 600 + Fargo
# 601 + Homeward Bound II: Lost in San Francisco
# 602 + Heavy Metal
# 603 + Hellraiser: Bloodline
# 604 + The Pallbearer
# 605 + Jane Eyre
# 606 + Loaded
# 607 + Pane e cioccolata
# 608 + The Aristocats
# 609 + La flor de mi secreto
# 610 + Two Much
# 611 + Ed
# 612 + Schrei aus Stein
# 613 + Ma saison préférée
# 614 + A Modern Affair
# 615 + Condition Red
# 616 + Asfour Stah
# 617 + A Thin Line Between Love and Hate
# 618 + The Last Supper
# 619 + Primal Fear
# 620 + Rude
# 621 + Carried Away
# 622 + All Dogs Go to Heaven 2
# 623 + Land and Freedom
# 624 + Denise Calls Up
# 625 + Theodore Rex
# 626 + A Family Thing
# 627 + Frisk
# 628 + Sgt. Bilko
# 629 + Jack & Sarah
# 630 + Girl 6
# 631 + Diabolique
# 632 + Un indien dans la ville
# 633 + Roula - Dunkle Geheimnisse
# 634 + Peanuts – Die Bank zahlt alles
# Oops! Movie has not been reviewed...
# 635 + Happy Weekend
# Oops! Movie has not been reviewed...
# 636 + Nelly & Monsieur Arnaud
# 637 + Courage Under Fire
# 638 + Mission: Impossible
# 639 + Á köldum klaka
# 640 + Moll Flanders
# 641 + Das Superweib
# 642 + 삼공일 삼공이
# 643 + DragonHeart
# 644 + Und keiner weint mir nach
# Oops! Movie has not been reviewed...
# 645 + My Mother's Courage
# 646 + Eddie
# 647 + Yankee Zulu
# 648 + Billy's Holiday
# 649 + Plein soleil
# 650 + August
# 651 + James and the Giant Peach
# 652 + Fear
# 653 + Kids in the Hall: Brain Candy
# 654 + Faithful
# 655 + Podzemlje
# 656 + Lust och fägring stor
# 657 + Bloodsport II
# 658 + পথের পাঁচালী
# 659 + অপুর সংসার
# 660 + Mystery Science Theater 3000: The Movie
# 661 + Tarantella
# 662 + Space Jam
# 663 + Barbarella
# 664 + Hostile Intentions
# 665 + They Bite
# 666 + Some Folks Call It a Sling Blade
# 667 + The Run of the Country
# 668 + Alphaville, une étrange aventure de Lemmy Caution
# 669 + Coup de torchon
# 670 + Tigrero: A Film That Was Never Made
# 671 + L'oeil de Vichy
# 672 + Windows
# 673 + It's My Party
# 674 + Country Life
# 675 + Operation Dumbo Drop
# 676 + Das Versprechen
# 677 + Mrs. Winterbourne
# 678 + Solo
# 679 + Etz Hadomim Tafus
# 680 + The Substitute
# 681 + True Crime
# 682 + Butterfly Kiss
# 683 + Feeling Minnesota
# 684 + Delta of Venus
# 685 + To Cross the Rubicon
# 686 + Angus
# 687 + Daens
# 688 + Faces
# 689 + Boys
# 690 + The Quest
# 691 + Cosi
# 692 + Sunset Park
# 693 + Mulholland Falls
# 694 + The Truth About Cats & Dogs
# 695 + Oliver & Company
# 696 + Celtic Pride
# 697 + Flipper
# 698 + Captives
# 699 + Of Love and Shadows
# 700 + Dead Man
# 701 + Le Hussard sur le toit
# 702 + Switchblade Sisters
# 703 + Boca a boca
# 704 + Les visiteurs
# 705 + Multiplicity
# 706 + The Haunted World of Edward D. Wood, Jr.
# 707 + Due Amici
# 708 + The Craft
# 709 + The Great White Hype
# 710 + Last Dance
# 711 + War Stories Our Mother Never Told Us
# 712 + Cold Comfort Farm
# 713 + Institute Benjamenta, or This Dream People Call Human Life
# 714 + Heaven's Prisoners
# 715 + Original Gangstas
# 716 + The Rock
# 717 + Getting Away with Murder
# 718 + Dellamorte Dellamore
# 719 + Twister
# 720 + Barb Wire
# 721 + Le garçu
# 722 + Honigmond
# Oops! Movie has not been reviewed...
# 723 + GHOST IN THE SHELL
# 724 + Thinner
# 725 + Spy Hard
# 726 + Brothers in Trouble
# Oops! Movie has not been reviewed...
# 727 + A Close Shave
# 728 + Force of Evil
# 729 + The Stupids
# 730 + The Arrival
# 731 + The Man from Down Under
# 732 + Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# 733 + Careful
# 734 + Vermont Is for Lovers
# 735 + A Month by the Lake
# 736 + Gold Diggers: The Secret of Bear Mountain
# 737 + Kim
# 738 + Carmen Miranda: Bananas Is My Business
# 739 + 東邪西毒
# 740 + Khomreh
# 741 + Maya Lin: A Strong Clear Vision
# 742 + Stalingrad
# 743 + The Phantom
# 744 + Striptease
# 745 + The Last of the High Kings
# 746 + Heavy
# 747 + Jack
# 748 + I Shot Andy Warhol
# 749 + The Grass Harp
# 750 + Tuđa Amerika
# 751 + La vie est belle
# 752 + Quartier Mozart
# 753 + Touki-Bouki
# 754 + Wend Kuuni
# 755 + Histoires extraordinaires
# 756 + Babyfever
# 757 + Pharaoh's  Army
# 758 + Trainspotting
# 759 + Til There Was You
# 760 + Independence Day
# 761 + Stealing Beauty
# 762 + The Fan
# 763 + The Hunchback of Notre Dame
# 764 + The Cable Guy
# 765 + Kingpin
# 766 + Eraser
# 767 + The Gate of Heavenly Peace
# 768 + The Nutty Professor
# 769 + Yo, la peor de todas
# 770 + Un été inoubliable
# 771 + Hol volt, hol nem volt
# 772 + En compagnie d'Antonin Artaud
# 773 + Sibak
# 774 + Somebody to Love
# 775 + A Very Natural Thing
# 776 + La vieille qui marchait dans la mer
# 777 + Daylight
# 778 + The Frighteners
# 779 + Lone Star
# 780 + Harriet the Spy
# 781 + Phenomenon
# 782 + Walking and Talking
# 783 + She's the One
# 784 + A Time to Kill
# 785 + American Buffalo
# 786 + Les Rendez-vous de Paris
# 787 + Alaska
# 788 + Fled
# 789 + Kazaam
# 790 + Bűvös vadász
# 791 + Larger Than Life
# 792 + A Boy Called Hate
# 793 + Power 98
# 794 + Two Deaths
# 795 + A Very Brady Sequel
# 796 + Stefano Quantestorie
# 797 + La mort en ce jardin
# 798 + Hedd Wyn
# 799 + La Collectionneuse
# 800 + Kaspar Hauser
# 801 + Echte Kerle
# 802 + Diebinnen
# Oops! Movie has not been reviewed...
# 803 + O Convento
# 804 + The Adventures of Pinocchio
# 805 + Joe's Apartment
# 806 + The First Wives Club
# 807 + Stonewall
# 808 + Ransom
# 809 + High School High
# 810 + Phat Beach
# 811 + Foxfire
# 812 + Chain Reaction
# 813 + Matilda
# 814 + Emma
# 815 + The Crow: City of Angels
# 816 + House Arrest
# 817 + Les Yeux sans visage
# 818 + Bordello of Blood
# 819 + Lotto Land
# 820 + The Story of Xinghua
# 821 + 天國逆子
# 822 + Flirt
# 823 + The Big Squeeze
# 824 + The Spitfire Grill
# 825 + Escape from L.A.
# 826 + Xích lô
# 827 + Basquiat
# 828 + Tin Cup
# 829 + Dingo
# 830 + 楢山節考
# 831 + Un week-end sur deux
# 832 + Mille bolle blu
# 833 + Wuya yu maque
# 834 + The Godfather
# 835 + Der bewegte Mann
# 836 + 警察故事 III：超級警察
# 837 + Manny & Lo
# 838 + Tsuma
# 839 + Small Faces
# 840 + Bound
# 841 + Carpool
# 842 + Death in Brunswick
# 843 + Kansas City
# 844 + Gone Fishin'
# 845 + Lover's Knot
# 846 + 愛情萬歲
# 1367 + Walkabout
# 1368 + Message to Love: The Isle of Wight Festival
# 1369 + Murder at 1600
# 1370 + Hearts and Minds
# 1371 + Inside
# 1372 + Fierce Creatures
# 1373 + Zeus & Roxanne
# 1374 + Turbulence
# 1375 + Angel Baby
# 1376 + 警察故事4之簡單任務
# 1377 + Underworld
# 1378 + Beverly Hills Ninja
# 1379 + Metro
# 1380 + La machine
# 1381 + Falling in Love Again
# 1382 + The Cement Garden
# 1383 + Dante's Peak
# 1384 + Meet Wally Sparks
# 1385 + Amos & Andrew
# 1386 + Benny & Joon
# 1387 + Prefontaine
# 1388 + A Tickle in the Heart
# 1389 + Guantanamera
# 1390 + McHale's Navy
# 1391 + Kolja
# 1392 + Gridlock'd
# 1393 + Fire on the Mountain
# Oops! Movie has not been reviewed...
# 1394 + Waiting for Guffman
# 1395 + Кавказский пленник
# 1396 + The Beautician and the Beast
# 1397 + SubUrbia
# 1398 + Hotel de Love
# 1399 + The Pest
# 1400 + Fools Rush In
# 1401 + Touch
# 1402 + Absolute Power
# 1403 + That Darn Cat
# 1404 + Vegas Vacation
# 1405 + Unforgotten: Twenty-Five Years After Willowbrook
# 1406 + That Old Feeling
# 1407 + Lost Highway
# 1408 + Rosewood
# 1409 + Donnie Brasco
# 1410 + Salut cousin !
# 1411 + Booty Call
# 1412 + Rhyme & Reason
# 1413 + Boys Life 2
# 1414 + City of Industry
# 1415 + Best Men
# 1416 + Jungle 2 Jungle
# 1417 + Kama Sutra - A Tale of Love
# 1418 + Private Parts
# 1419 + Love Jones
# 1420 + The Saint
# 1421 + Smilla's Sense of Snow
# 1422 + The Van
# 1423 + Crash
# 1424 + The Daytrippers
# 1425 + Liar Liar
# 1426 + The Quiet Room
# 1427 + Selena
# 1428 + The Devil's Own
# 1429 + Cats Don't Dance
# 1430 + B.A.P.S.
# 1431 + Love and Other Catastrophes
# 1432 + Turbo: A Power Rangers Movie
# 1433 + Anna Karenina
# 1434 + Double Team
# 1435 + Inventing the Abbotts
# 1436 + Anaconda
# 1437 + Grosse Pointe Blank
# 1438 + Keys to Tulsa
# 1439 + Kissed
# 1440 + 8 Heads in a Duffel Bag
# 1441 + Hollow Reed
# 1442 + Paradise Road
# 1443 + Traveller
# 1444 + All Over Me
# 1445 + A Brother's Kiss
# 1446 + Shekvarebuli kulinaris ataserti retsepti
# 1447 + Romy and Michele's High School Reunion
# 1448 + Feng yue
# 1449 + Volcano
# 1450 + Children of the Revolution
# 1451 + Austin Powers: International Man of Mystery
# 1452 + Breakdown
# 1453 + Broken English
# 1454 + Commandments
# 1455 + Ripe
# 1456 + Truth or Consequences, N.M.
# 1457 + The Turning
# 1458 + Warriors of Virtue
# 1459 + Fathers' Day
# 1460 + The Fifth Element
# 1461 + Intimate Relations
# 1462 + Nowhere
# 1463 + Losing Chase
# 1464 + Sprung
# 1465 + Das Versprechen
# 1466 + Le bonheur
# 1467 + Love! Valour! Compassion!
# 1468 + Shall we ダンス?
# 1469 + The Second Jungle Book: Mowgli & Baloo
# 1470 + Twin Town
# 4877 + Topkapi
# 4878 + Witness for the Prosecution
# 4879 + Ali
# 4880 + Black Hawk Down
# 4881 + Charlotte Gray
# 4882 + Yentl
# 4883 + Gosford Park
# 4884 + I Am Sam
# 4885 + Monster's Ball
# 4886 + The Shipping News
# 4887 + The Big Heat
# 4888 + Motorama
# 4889 + Queen Bee
# 4890 + Silent Trigger
# 4891 + Murder by Death
# 4892 + The Servant
# 4893 + The Waterdance
# 4894 + Presque rien
# 4895 + Orange County
# 4896 + Le Pacte des loups
# 4897 + Another 48 Hrs.
# 4898 + 你那邊幾點
# 4899 + China Moon
# 4900 + The Umbrella Woman
# 4901 + Maria's Lovers
# 4902 + Romantic Comedy
# 4903 + The Russia House
# 4904 + Truly Madly Deeply
# 4905 + Wuthering Heights
# 4906 + California Suite
# 4907 + The Long Gray Line
# 4908 + The Flight of Dragons
# 4909 + Dragonslayer
# 4910 + Conan the Destroyer
# 4911 + Fire and Ice
# 4912 + Forbidden Zone
# 4913 + The Formula
# 4914 + Foxes
# 4915 + Galaxina
# 4916 + Impostor
# 4917 + Kung Pow: Enter the Fist
# 2022-11-14 20:18:14,546 CRITICAL [imdbpy] C:\Users\magma\anaconda3\lib\site-packages\imdb\_exceptions.py:32: IMDbDataAccessError exception raised; args: ({'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0240468/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': URLError(TimeoutError(10060, 'Et forsøg på at oprette forbindelse mislykkedes, fordi den part, der havde oprettet forbindelse, ikke svarede korrekt efter en periode, eller en oprettet forbindelse blev afbrudt, fordi værten ikke svarede', None, 10060, None))},); kwds: {}
# Traceback (most recent call last):
#   File "C:\Users\magma\anaconda3\lib\urllib\request.py", line 1350, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#   File "C:\Users\magma\anaconda3\lib\http\client.py", line 1255, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\magma\anaconda3\lib\http\client.py", line 1301, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\magma\anaconda3\lib\http\client.py", line 1250, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\magma\anaconda3\lib\http\client.py", line 1010, in _send_output
#     self.send(msg)
#   File "C:\Users\magma\anaconda3\lib\http\client.py", line 950, in send
#     self.connect()
#   File "C:\Users\magma\anaconda3\lib\http\client.py", line 1417, in connect
#     super().connect()
#   File "C:\Users\magma\anaconda3\lib\http\client.py", line 921, in connect
#     self.sock = self._create_connection(
#   File "C:\Users\magma\anaconda3\lib\socket.py", line 808, in create_connection
#     raise err
#   File "C:\Users\magma\anaconda3\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] Et forsøg på at oprette forbindelse mislykkedes, fordi den part, der havde oprettet forbindelse, ikke svarede korrekt efter en periode, eller en oprettet forbindelse blev afbrudt, fordi værten ikke svarede
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\magma\anaconda3\lib\site-packages\imdb\parser\http\__init__.py", line 221, in retrieve_unicode
#     response = uopener.open(url)
#   File "C:\Users\magma\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\magma\anaconda3\lib\urllib\request.py", line 542, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "C:\Users\magma\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\magma\anaconda3\lib\urllib\request.py", line 1393, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "C:\Users\magma\anaconda3\lib\urllib\request.py", line 1353, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error [WinError 10060] Et forsøg på at oprette forbindelse mislykkedes, fordi den part, der havde oprettet forbindelse, ikke svarede korrekt efter en periode, eller en oprettet forbindelse blev afbrudt, fordi værten ikke svarede>
# 2022-11-14 20:18:14,578 CRITICAL [imdbpy] C:\Users\magma\anaconda3\lib\site-packages\imdb\__init__.py:833: caught an exception retrieving or parsing "main" info set for mopID "0240468" (accessSystem: http)
# Traceback (most recent call last):
#   File "C:\Users\magma\anaconda3\lib\urllib\request.py", line 1350, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#   File "C:\Users\magma\anaconda3\lib\http\client.py", line 1255, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\magma\anaconda3\lib\http\client.py", line 1301, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\magma\anaconda3\lib\http\client.py", line 1250, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\magma\anaconda3\lib\http\client.py", line 1010, in _send_output
#     self.send(msg)
#   File "C:\Users\magma\anaconda3\lib\http\client.py", line 950, in send
#     self.connect()
#   File "C:\Users\magma\anaconda3\lib\http\client.py", line 1417, in connect
#     super().connect()
#   File "C:\Users\magma\anaconda3\lib\http\client.py", line 921, in connect
#     self.sock = self._create_connection(
#   File "C:\Users\magma\anaconda3\lib\socket.py", line 808, in create_connection
#     raise err
#   File "C:\Users\magma\anaconda3\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] Et forsøg på at oprette forbindelse mislykkedes, fordi den part, der havde oprettet forbindelse, ikke svarede korrekt efter en periode, eller en oprettet forbindelse blev afbrudt, fordi værten ikke svarede
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\magma\anaconda3\lib\site-packages\imdb\parser\http\__init__.py", line 221, in retrieve_unicode
#     response = uopener.open(url)
#   File "C:\Users\magma\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\magma\anaconda3\lib\urllib\request.py", line 542, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "C:\Users\magma\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\magma\anaconda3\lib\urllib\request.py", line 1393, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "C:\Users\magma\anaconda3\lib\urllib\request.py", line 1353, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error [WinError 10060] Et forsøg på at oprette forbindelse mislykkedes, fordi den part, der havde oprettet forbindelse, ikke svarede korrekt efter en periode, eller en oprettet forbindelse blev afbrudt, fordi værten ikke svarede>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\magma\anaconda3\lib\site-packages\imdb\__init__.py", line 831, in update
#     ret = method(mopID)
#   File "C:\Users\magma\anaconda3\lib\site-packages\imdb\parser\http\__init__.py", line 468, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#   File "C:\Users\magma\anaconda3\lib\site-packages\imdb\parser\http\__init__.py", line 379, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "C:\Users\magma\anaconda3\lib\site-packages\imdb\parser\http\__init__.py", line 249, in retrieve_unicode
#     raise IMDbDataAccessError(
# imdb._exceptions.IMDbDataAccessError: {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0240468/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': URLError(TimeoutError(10060, 'Et forsøg på at oprette forbindelse mislykkedes, fordi den part, der havde oprettet forbindelse, ikke svarede korrekt efter en periode, eller en oprettet forbindelse blev afbrudt, fordi værten ikke svarede', None, 10060, None))}
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\lib\urllib\request.py:1350, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1349 try:
# -> 1350     h.request(req.get_method(), req.selector, req.data, headers,
#    1351               encode_chunked=req.has_header('Transfer-encoding'))
#    1352 except OSError as err: # timeout error
#
# File ~\anaconda3\lib\http\client.py:1255, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1254 """Send a complete request to the server."""
# -> 1255 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1301, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1300     body = _encode(body, 'body')
# -> 1301 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1250, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1249     raise CannotSendHeader()
# -> 1250 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1010, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1009 del self._buffer[:]
# -> 1010 self.send(msg)
#    1012 if message_body is not None:
#    1013
#    1014     # create a consistent interface to message_body
#
# File ~\anaconda3\lib\http\client.py:950, in HTTPConnection.send(self, data)
#     949 if self.auto_open:
# --> 950     self.connect()
#     951 else:
#
# File ~\anaconda3\lib\http\client.py:1417, in HTTPSConnection.connect(self)
#    1415 "Connect to a host on a given (SSL) port."
# -> 1417 super().connect()
#    1419 if self._tunnel_host:
#
# File ~\anaconda3\lib\http\client.py:921, in HTTPConnection.connect(self)
#     920 """Connect to the host and port specified in __init__."""
# --> 921 self.sock = self._create_connection(
#     922     (self.host,self.port), self.timeout, self.source_address)
#     923 self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# File ~\anaconda3\lib\socket.py:808, in create_connection(address, timeout, source_address)
#     807 try:
# --> 808     raise err
#     809 finally:
#     810     # Break explicitly a reference cycle
#
# File ~\anaconda3\lib\socket.py:796, in create_connection(address, timeout, source_address)
#     795     sock.bind(source_address)
# --> 796 sock.connect(sa)
#     797 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] Et forsøg på at oprette forbindelse mislykkedes, fordi den part, der havde oprettet forbindelse, ikke svarede korrekt efter en periode, eller en oprettet forbindelse blev afbrudt, fordi værten ikke svarede
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\imdb\parser\http\__init__.py:221, in IMDbURLopener.retrieve_unicode(self, url, size)
#     220 uopener.addheaders = list(self.addheaders)
# --> 221 response = uopener.open(url)
#     222 content = response.read()
#
# File ~\anaconda3\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     524 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525 response = self._open(req, data)
#     527 # post-process response
#
# File ~\anaconda3\lib\urllib\request.py:542, in OpenerDirector._open(self, req, data)
#     541 protocol = req.type
# --> 542 result = self._call_chain(self.handle_open, protocol, protocol +
#     543                           '_open', req)
#     544 if result:
#
# File ~\anaconda3\lib\urllib\request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     501 func = getattr(handler, meth_name)
# --> 502 result = func(*args)
#     503 if result is not None:
#
# File ~\anaconda3\lib\urllib\request.py:1393, in HTTPSHandler.https_open(self, req)
#    1392 def https_open(self, req):
# -> 1393     return self.do_open(http.client.HTTPSConnection, req,
#    1394         context=self._context, check_hostname=self._check_hostname)
#
# File ~\anaconda3\lib\urllib\request.py:1353, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1352 except OSError as err: # timeout error
# -> 1353     raise URLError(err)
#    1354 r = h.getresponse()
#
# URLError: <urlopen error [WinError 10060] Et forsøg på at oprette forbindelse mislykkedes, fordi den part, der havde oprettet forbindelse, ikke svarede korrekt efter en periode, eller en oprettet forbindelse blev afbrudt, fordi værten ikke svarede>
#
# During handling of the above exception, another exception occurred:
#
# IMDbDataAccessError                       Traceback (most recent call last)
# Cell In [10], line 9
#       6 title, genre, imdbId = titge
#       7 print(f'{i} + {title}')
# ----> 9 movie = getMovie(imdbId)
#      10 reviews = getReviews(movie)
#      12 # Check that movie has been reviewed
#
# Cell In [9], line 23, in getMovie(id)
#      22 def getMovie(id):
# ---> 23     movie = db.get_movie(id,['main', 'reviews'])
#      24     return movie
#
# File ~\anaconda3\lib\site-packages\imdb\__init__.py:423, in IMDbBase.get_movie(self, movieID, info, modFunct)
#     421 if modFunct is not None:
#     422     movie.set_mod_funct(modFunct)
# --> 423 self.update(movie, info)
#     424 return movie
#
# File ~\anaconda3\lib\site-packages\imdb\__init__.py:831, in IMDbBase.update(self, mop, info, override)
#     829     method = lambda *x: {}
#     830 try:
# --> 831     ret = method(mopID)
#     832 except Exception:
#     833     _imdb_logger.critical(
#     834         'caught an exception retrieving or parsing "%s" info set'
#     835         ' for mopID "%s" (accessSystem: %s)',
#     836         i, mopID, mop.accessSystem, exc_info=True
#     837     )
#
# File ~\anaconda3\lib\site-packages\imdb\parser\http\__init__.py:468, in IMDbHTTPAccessSystem.get_movie_main(self, movieID)
#     467 def get_movie_main(self, movieID):
# --> 468     cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#     469     return self.mProxy.movie_parser.parse(cont, mdparse=self._mdparse)
#
# File ~\anaconda3\lib\site-packages\imdb\parser\http\__init__.py:379, in IMDbHTTPAccessSystem._retrieve(self, url, size, _noCookies)
#     377 """Retrieve the given URL."""
#     378 self._http_logger.debug('fetching url %s (size: %d)', url, size)
# --> 379 ret = self.urlOpener.retrieve_unicode(url, size=size)
#     380 if PY2 and isinstance(ret, str):
#     381     ret = ret.decode('utf-8')
#
# File ~\anaconda3\lib\site-packages\imdb\parser\http\__init__.py:249, in IMDbURLopener.retrieve_unicode(self, url, size)
#     246     if size != -1:
#     247         # Ensure that the Range header is removed.
#     248         self.del_header('Range')
# --> 249     raise IMDbDataAccessError(
#     250         {'errcode': e.errno,
#     251          'errmsg': str(e.strerror),
#     252          'url': url,
#     253          'proxy': self.get_proxy(),
#     254          'exception type': 'IOError',
#     255          'original exception': e}
#     256     )
#     257 if encode is None:
#     258     encode = 'utf8'
#
# IMDbDataAccessError: {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0240468/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': URLError(TimeoutError(10060, 'Et forsøg på at oprette forbindelse mislykkedes, fordi den part, der havde oprettet forbindelse, ikke svarede korrekt efter en periode, eller en oprettet forbindelse blev afbrudt, fordi værten ikke svarede', None, 10060, None))}

# %%
df
# Out:
#       TitleId                   MovieTitle  \
# 0     0114709                    Toy Story
# 1     0113497                      Jumanji
# 2     0113228             Grumpier Old Men
# 3     0114885            Waiting to Exhale
# 4     0113041  Father of the Bride Part II
# ...       ...                          ...
# 4894  0080752               Forbidden Zone
# 4895  0080754                  The Formula
# 4896  0080756                        Foxes
# 4897  0080771                     Galaxina
# 4898  0160399                     Impostor
#
#                                                  Actors  \
# 0     [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1     [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2     [Walter Matthau, Jack Lemmon, Sophia Loren, Bu...
# 3     [Whitney Houston, Angela Bassett, Loretta Devi...
# 4     [Steve Martin, Diane Keaton, Martin Short, Geo...
# ...                                                 ...
# 4894  [Gene Cunningham, Virginia Rose, Phil Gordon, ...
# 4895  [Marlon Brando, Marthe Keller, John Gielgud, B...
# 4896  [Jodie Foster, Cherie Currie, Marilyn Kagan, K...
# 4897  [Stephen Macht, Avery Schreiber, Dorothy Strat...
# 4898  [Gary Sinise, Madeleine Stowe, Tony Shalhoub, ...
#
#                                                  Genres  \
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1     [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2     [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                        [{'id': 35, 'name': 'Comedy'}]
# ...                                                 ...
# 4894  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 4895  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 4896  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 4897  [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...
# 4898  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
#
#                                                 Reviews
# 0     [Andy's toys live a reasonable life of fun and...
# 1     [Among the thousands of films I have viewed, t...
# 2     [Sequels are rarely half as good as the origin...
# 3     [This was a good movie, even though I'm not th...
# 4     [As much as I want to rag this movie, make fun...
# ...                                                 ...
# 4894  [I avoided this film for years even though I s...
# 4895  [The reviews for this movie have been rather c...
# 4896  [Story about four teenage girls growing up in ...
# 4897  [Low budget "Barbarella" knock-off manages to ...
# 4898  [I have no idea why this movie is such underra...
#
# [4899 rows x 5 columns]

# %%
df.to_pickle("moviesDf4899.pkl")
