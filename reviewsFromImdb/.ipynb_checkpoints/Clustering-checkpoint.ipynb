# %% [markdown]
# # Clustering vMagnus

# %%
import pandas as pd
import numpy as np
import re
import networkx as nx
import matplotlib.pyplot as plt
from fa2 import ForceAtlas2
import community
from itertools import combinations

df1 = pd.read_pickle("moviesDf4899_v1.pkl")
df2 = pd.read_pickle("moviesDf4899_v2.pkl")

frames = [df1, df2]
moviesDf = pd.concat(frames)

# %%
actor_column = list(moviesDf["Actors"].to_numpy())
G = nx.Graph()

# Creating the graph. 
# adding edge between all actors in a given movie
for movie_cast in actor_column:
    movie_cast = movie_cast[:5]
    G.add_nodes_from(movie_cast)
    pairs = list(combinations(movie_cast,2))
    G.add_edges_from(pairs)

# %%
# Extracting largest connected component
nodes = max(nx.connected_components(G), key=len)
G = G.subgraph(nodes).copy()

print(f'Stats before removing weakly connected nodes')
print(f'Nodes: {G.number_of_nodes()}')
print(f'Edges: {G.number_of_edges()}\n')

# Removing nodes with very small degree
remove = [node for node,degree in dict(G.degree()).items() if degree < 10]
G.remove_nodes_from(remove)
      
print(f'Stats after removing weakly connected nodes')
print(f'Nodes: {G.number_of_nodes()}')
print(f'Edges: {G.number_of_edges()}')
# Out:
# Stats before removing weakly connected nodes
# Nodes: 112687
# Edges: 6896874
#
# Stats after removing weakly connected nodes
# Nodes: 112104
# Edges: 6893849

# %%
forceatlas2 = ForceAtlas2(
                        # Behavior alternatives
                        outboundAttractionDistribution=True,  # Dissuade hubs
                        linLogMode=False,  # NOT IMPLEMENTED
                        adjustSizes=False,  # Prevent overlap (NOT IMPLEMENTED)
                        edgeWeightInfluence=1.0,

                        # Performance
                        jitterTolerance=1.0,  # Tolerance
                        barnesHutOptimize=True,
                        barnesHutTheta=1.0,
                        multiThreaded=False,  # NOT IMPLEMENTED

                        # Tuning
                        scalingRatio=2,
                        strongGravityMode=False,
                        gravity=1.5,

                        # Log
                        verbose=True)
positions = forceatlas2.forceatlas2_networkx_layout(G, pos=None, iterations=100);
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [13:32<00:00,  8.12s/it]
# BarnesHut Approximation  took  153.56  seconds
# Repulsion forces  took  641.03  seconds
# Gravitational forces  took  0.77  seconds
# Attraction forces  took  11.65  seconds
# AdjustSpeedAndApplyForces step  took  3.38  seconds

# %%
# Best partition found with louvain algorithm
partition = community.best_partition(G, random_state = 1, randomize = False)

# Defining values for the color spectrum
maxval = np.max(list(partition.values())) 
cmap=plt.cm.Spectral
node_color = [cmap(v/maxval) for v in partition.values()]

# Plotting
plt.figure(1,figsize=(20,12)) 
nx.draw_networkx_nodes(G, pos = positions, node_color=node_color, alpha=0.9, node_size = 60);
nx.draw_networkx_edges(G, pos = positions, alpha=0.04);

# For legend creation only
for v in set(partition.values()):
    plt.scatter([],[], c=[cmap(v/maxval)], label='Community {}'.format(v))

plt.title('Network nodes colored by community', fontsize = 20)
plt.legend(loc='upper left', prop={'size': 14})
plt.show()

# %%
# rearanging found partition
parts = []
for i in range(0, len(set(partition.values()))):
    parts.append([])
    
for actor, com in partition.items():
    parts[com].append(actor)

#sorting based on biggest communities
parts.sort(key=len, reverse = True)

# %%
# Most connected actors
sorted(G.degree, key=lambda x: x[1], reverse=True)
# Out:
# [('Greg Bronson', 5255),
#  ('Arthur Tovey', 4250),
#  ('Sam Harris', 4057),
#  ('Bess Flowers', 3960),
#  ('Bert Stevens', 3492),
#  ('Harold Miller', 3349),
#  ('Paul McMichael', 3341),
#  ('Jeffrey Sayre', 3160),
#  ('Michael Jeffers', 3061),
#  ('Marshall Dancing Elk Lucas', 3015),
#  ('Frank Baker', 2951),
#  ('Rudy Germane', 2868),
#  ('Norman Stevans', 2854),
#  ('Lars Hensen', 2802),
#  ('Franklyn Farnum', 2797),
#  ('Guy Standeven', 2678),
#  ('Chuck Hamilton', 2676),
#  ('Stuart Holmes', 2669),
#  ('Shep Houghton', 2662),
#  ('Herschel Graham', 2656),
#  ('Dick Cherney', 2650),
#  ('Robert Haines', 2648),
#  ('James Gonzalez', 2645),
#  ('Frank McLure', 2626),
#  ('Frank Welker', 2617),
#  ('William Meader', 2524),
#  ('Benjie Bancroft', 2524),
#  ('Bob Harks', 2511),
#  ('Walter Bacon', 2503),
#  ('Thomas Martin', 2479),
#  ('John Roy', 2450),
#  ('Mike Starr', 2414),
#  ('Robert Locke Lorraine', 2391),
#  ('Joe Ploski', 2388),
#  ('Scott Seaton', 2367),
#  ('Aileen Lewis', 2357),
#  ('Phil Hawn', 2317),
#  ('John Marlin', 2316),
#  ('Fred Wood', 2315),
#  ('Jimmie Horan', 2310),
#  ('Cosmo Sardo', 2299),
#  ('Ralph Moratz', 2295),
#  ('Stuart Hall', 2284),
#  ('Frank Mills', 2274),
#  ('Suzanne Ridgway', 2260),
#  ('Dick Gordon', 2258),
#  ('Robert De Niro', 2237),
#  ('Waclaw Rekwart', 2237),
#  ('Chet Brandenburg', 2231),
#  ('Whoopi Goldberg', 2220),
#  ('John Gielgud', 2201),
#  ('Brandon Beach', 2193),
#  ('Gertrude Astor', 2187),
#  ('Leoda Richards', 2177),
#  ('Mike Morelli', 2174),
#  ('Bernard Sell', 2168),
#  ('Gene Hackman', 2158),
#  ('George Bruggeman', 2157),
#  ('King Lockwood', 2131),
#  ('Dan Aykroyd', 2110),
#  ('Ray Spiker', 2110),
#  ('Leslie Sketchley', 2109),
#  ('Cap Somers', 2104),
#  ('Tracey Walter', 2100),
#  ('Chuck Hicks', 2096),
#  ('John Rice', 2094),
#  ('Paul Kruger', 2081),
#  ('Paul Cristo', 2075),
#  ('Fred Rapport', 2073),
#  ('Richard LaMarr', 2050),
#  ('Joseph Glick', 2038),
#  ('Frank Sinatra', 2036),
#  ('Bruce Willis', 2035),
#  ('Danny Borzage', 2034),
#  ('Ben Frommer', 2032),
#  ('Boyd Cabeen', 2027),
#  ('Charles Fogel', 2019),
#  ('Paul King', 2017),
#  ('Jack Chefe', 2016),
#  ('Ernesto Molinari', 2011),
#  ('Eumenio Blanco', 2005),
#  ('Paul Guilfoyle', 2004),
#  ('Raoul Freeman', 1996),
#  ('Minta Durfee', 1994),
#  ('Al Bain', 1992),
#  ('George Nardelli', 1992),
#  ('Jack Perrin', 1985),
#  ('Harry Fielder', 1982),
#  ('Shirley MacLaine', 1970),
#  ('Curt Furberg', 1966),
#  ('Jimmy Dime', 1949),
#  ('Edwin Rochelle', 1943),
#  ('Rance Howard', 1938),
#  ('Richard Schiff', 1925),
#  ('Joe Gilbert', 1909),
#  ('Charles Morton', 1909),
#  ('Hans Moebus', 1907),
#  ('Dick Wessel', 1905),
#  ('Harry Denny', 1904),
#  ('Mabel Smaney', 1899),
#  ('Robert Strong', 1890),
#  ('King Mojave', 1890),
#  ('Joe Evans', 1889),
#  ('Duke Fishman', 1888),
#  ('Paul Bradley', 1887),
#  ('Bob Reeves', 1886),
#  ('Jimmy Star', 1879),
#  ('George Spence', 1877),
#  ('Sailor Vincent', 1868),
#  ('Bud Cokes', 1863),
#  ('Barry Norton', 1862),
#  ('Spencer Chan', 1860),
#  ('Marco Lopez', 1852),
#  ('Richard Nixon', 1848),
#  ('John Cusack', 1847),
#  ('Robert Robinson', 1845),
#  ('Richard Elmore', 1844),
#  ('Philip Van Zandt', 1838),
#  ('George Sasaki', 1831),
#  ('Paul Power', 1820),
#  ('Sol Murgi', 1819),
#  ('James Woods', 1818),
#  ('John Turturro', 1816),
#  ('Dick Johnstone', 1813),
#  ('Paul Herman', 1812),
#  ('John George', 1812),
#  ('Jack McGee', 1808),
#  ('Charlton Heston', 1801),
#  ('Bill Murray', 1794),
#  ('Jack Kenny', 1793),
#  ('Roy Damron', 1787),
#  ('Albert Cavens', 1785),
#  ('Clint Howard', 1784),
#  ('Jose Portugal', 1784),
#  ('Allan Graf', 1782),
#  ('Kit Guard', 1782),
#  ('Stephen Soldi', 1780),
#  ('Anne Kunde', 1776),
#  ('Trevor Howard', 1776),
#  ('Lena Banks', 1775),
#  ('Chester Hayes', 1769),
#  ('Jack Stoney', 1767),
#  ('Oscar Blank', 1765),
#  ('John Carradine', 1762),
#  ('Keith David', 1758),
#  ('Harvey Karels', 1750),
#  ('Robert James', 1746),
#  ('Beulah Christian', 1744),
#  ('Kevin Costner', 1733),
#  ('Arnold Montey', 1731),
#  ('Herman Hack', 1719),
#  ('Mike Mazurki', 1717),
#  ('David Paymer', 1715),
#  ('Robin Williams', 1714),
#  ('Jack Tornek', 1708),
#  ('Robert Duvall', 1707),
#  ('Daniel Nunez', 1706),
#  ('Donald Sutherland', 1703),
#  ('Mary Young', 1701),
#  ('Al Haskell', 1700),
#  ('Bob Pepper', 1699),
#  ('Harry Evans', 1699),
#  ('Dan Dowling', 1691),
#  ('Perk Lazelle', 1687),
#  ('Al Pacino', 1685),
#  ('Kathleen Freeman', 1685),
#  ('John Goodman', 1684),
#  ('Graham Tonbridge', 1680),
#  ('Ralph Brooks', 1677),
#  ('Russell Meeker', 1677),
#  ('Steve Buscemi', 1668),
#  ('Dan Hedaya', 1667),
#  ('Adolph Faylauer', 1664),
#  ('James Earl Jones', 1659),
#  ('Giancarlo Esposito', 1651),
#  ('Marlene Dietrich', 1648),
#  ('Richard Riehle', 1645),
#  ('Larry Duran', 1642),
#  ('Tom Sizemore', 1639),
#  ('Danny DeVito', 1637),
#  ('Don Pulford', 1632),
#  ('June Smaney', 1631),
#  ('Charles Pendelton', 1630),
#  ('Harry Dean Stanton', 1627),
#  ('Tim Taylor', 1625),
#  ('Alphonso DuBois', 1623),
#  ('Fred Aldrich', 1622),
#  ('Bill Couch', 1611),
#  ('Buster Keaton', 1607),
#  ('John Davidson', 1606),
#  ('Danny Sands', 1606),
#  ('Daniel von Bargen', 1602),
#  ('Blaine Turner', 1599),
#  ('Abdullah Abbas', 1597),
#  ('Willie Bloom', 1594),
#  ('Victor Paul', 1594),
#  ('Tex Holden', 1593),
#  ('Nina Borget', 1589),
#  ('John Mills', 1587),
#  ('Charles Horvath', 1587),
#  ('Derek Lyons', 1586),
#  ('Ray Armstrong', 1584),
#  ('Johnny Kern', 1583),
#  ('Jack Warden', 1581),
#  ('Sean Connery', 1578),
#  ('Louise Colombet', 1567),
#  ('Bill Raisch', 1567),
#  ('Richard Jenkins', 1559),
#  ('Mike Lally', 1559),
#  ('Phil Schumacher', 1558),
#  ('David Niven', 1557),
#  ('Denzel Washington', 1554),
#  ('Audrey Betz', 1554),
#  ('Phil Bloom', 1554),
#  ('Gordon Mitchell', 1554),
#  ('Harvey Keitel', 1550),
#  ('Peter Lorre', 1546),
#  ('Philip Ahn', 1544),
#  ('Jeanne Lafayette', 1542),
#  ('Harlan Hoagland', 1542),
#  ('Joan Cusack', 1540),
#  ('Clark Ross', 1536),
#  ('Dennis Quaid', 1534),
#  ('Tommy Lee Jones', 1533),
#  ('Loulette Sablon', 1531),
#  ('Sammy Shack', 1527),
#  ('Michael Smith', 1523),
#  ('Robert Street', 1523),
#  ('Christopher Walken', 1522),
#  ('Reginald Lal Singh', 1522),
#  ('Donal Logue', 1520),
#  ('Arthur Dulac', 1520),
#  ('Leroy Johnson', 1515),
#  ('Philip Baker Hall', 1512),
#  ('Cesar Romero', 1512),
#  ('Clive Morgan', 1508),
#  ('Tom Hanks', 1506),
#  ('John Benson', 1503),
#  ('Sam Finn', 1503),
#  ('Keye Luke', 1502),
#  ('Jack Santoro', 1501),
#  ('Gordon Carveth', 1498),
#  ('Gloria Dea', 1495),
#  ('Buddy Roosevelt', 1494),
#  ('Charles Coburn', 1493),
#  ('Harrison Ford', 1492),
#  ('Kay Koury', 1491),
#  ('Tommy Lee', 1489),
#  ('Ray Pourchot', 1487),
#  ('Ray Flynn', 1485),
#  ('Owen Song', 1484),
#  ('Paul Giamatti', 1482),
#  ('Julia Roberts', 1481),
#  ('Brian King', 1481),
#  ('Kathryn Wilson', 1480),
#  ('Xander Berkeley', 1477),
#  ('Bob Whitney', 1475),
#  ('Andy Devine', 1474),
#  ('Marion Ross', 1472),
#  ('Gerry Becker', 1470),
#  ('George Hickman', 1470),
#  ('Elsa Peterson', 1468),
#  ('Alfred Hitchcock', 1468),
#  ('Colin Kenny', 1467),
#  ('Finlay Currie', 1464),
#  ('George Raft', 1463),
#  ('Robert Loggia', 1458),
#  ('Jon Voight', 1457),
#  ('Ed Harris', 1455),
#  ('Sally Yarnell', 1455),
#  ('John Quijada', 1452),
#  ('Martin Sheen', 1450),
#  ('George Blagoi', 1450),
#  ('Anton Northpole', 1450),
#  ('John Diehl', 1449),
#  ('Charles Schaeffer', 1448),
#  ('Jack Del Rio', 1446),
#  ('Tony Randall', 1444),
#  ('Ruth Gordon', 1443),
#  ('Fred Scheiwiller', 1443),
#  ('Ron Veto', 1439),
#  ('David Ahdar', 1439),
#  ('Oliver Cross', 1438),
#  ('Joe Garcio', 1438),
#  ('Michael McKean', 1437),
#  ('Mel Gibson', 1435),
#  ('Bill Cobbs', 1435),
#  ('Melville Cooper', 1433),
#  ('Jack Black', 1430),
#  ('Larry Arnold', 1430),
#  ('Richard Loo', 1430),
#  ('Alan Mowbray', 1429),
#  ('Frank Oz', 1428),
#  ('Marie Ardell', 1426),
#  ('Beverly Mook', 1426),
#  ('Carol White', 1426),
#  ('Alec Baldwin', 1425),
#  ('Robert Minkoff', 1425),
#  ('Michelle Pfeiffer', 1422),
#  ('Roy Darmour', 1422),
#  ('Richard Wattis', 1422),
#  ('Woody Harrelson', 1419),
#  ('Jonni Paris', 1417),
#  ('Cedric Hardwicke', 1416),
#  ('Jane Chung', 1416),
#  ('Jack Krupnick', 1415),
#  ('Ernesto Zambrano', 1413),
#  ('Tony Regan', 1412),
#  ('Carli Elinor', 1409),
#  ('George Cheung', 1404),
#  ('Glynis Johns', 1400),
#  ('William Fichtner', 1399),
#  ('Mike Tellegen', 1395),
#  ('Ralph Grosh', 1395),
#  ('Sam Savitsky', 1394),
#  ('Tony Roux', 1391),
#  ('Betty Burns', 1389),
#  ('Dick Ryan', 1388),
#  ('Rama Bai', 1384),
#  ('Wilbur Mack', 1384),
#  ('Gustave Lax', 1384),
#  ('Danny Nero', 1383),
#  ('Carrie Fisher', 1383),
#  ('James Stewart', 1381),
#  ('Michael Cirillo', 1380),
#  ('Walter Kingsford', 1379),
#  ('Bhogwan Singh', 1379),
#  ('Anita Louise Dano', 1379),
#  ('Barbara Donaldson', 1379),
#  ('Joanne Jones', 1379),
#  ('Charles Lunard', 1379),
#  ('Tela Mansfield', 1379),
#  ('Ila McAvoy', 1379),
#  ('Eddie Searles', 1379),
#  ('Roque Ybarra', 1379),
#  ('Ricky Ricardi', 1378),
#  ('Leslie Denison', 1378),
#  ('Weaver Levy', 1378),
#  ('Leon Alton', 1377),
#  ('Eve Gordon', 1376),
#  ('Vincent Schiavelli', 1375),
#  ('Albert Godderis', 1374),
#  ('Murray Pollack', 1373),
#  ('Evelyn Keyes', 1366),
#  ('Robert Dayo', 1363),
#  ('Virginia Lee', 1363),
#  ('Joe Gold', 1362),
#  ('Charles Soldani', 1361),
#  ('Ashley Cowan', 1360),
#  ('Darren Dublin', 1359),
#  ('Michael Lerner', 1357),
#  ('Fred Perce', 1357),
#  ('Joe Grifasi', 1355),
#  ('George Ross', 1354),
#  ('Christopher McDonald', 1352),
#  ('John Deauville', 1352),
#  ('John Delgado', 1352),
#  ('John Eloff', 1352),
#  ('Walter Findon', 1351),
#  ('Michael Trubshawe', 1351),
#  ('Joe Pesci', 1350),
#  ('Nicolas Cage', 1350),
#  ('Christopher Lloyd', 1350),
#  ('Debi Mazar', 1349),
#  ('Emma Palmese', 1349),
#  ('Lin Shaye', 1348),
#  ('Jack Lemmon', 1347),
#  ('Tim Robbins', 1347),
#  ('Sandee Marriott', 1346),
#  ('Jim Carrey', 1345),
#  ('Robert Morley', 1343),
#  ('Joe Murphy', 1343),
#  ('Hazel Boyne', 1342),
#  ('George Ford', 1341),
#  ('Gino Corrado', 1341),
#  ('Mary Gleason', 1340),
#  ('Louise Laureau', 1340),
#  ('Ralph Madlener', 1340),
#  ('Kevin Cooney', 1339),
#  ('Ronald Adam', 1339),
#  ('Paul Gustine', 1339),
#  ('Norman Papson', 1339),
#  ('Harsh Nayyar', 1338),
#  ('Wilson Cornell', 1338),
#  ('John Candy', 1337),
#  ('Fred Walton', 1337),
#  ('Cecil Combs', 1337),
#  ('John Lewis', 1337),
#  ('Bert Moorhouse', 1336),
#  ('Joe Gray', 1334),
#  ('Faye Michael Nuell', 1334),
#  ('Kit Carson', 1333),
#  ('Joe Rubino', 1333),
#  ('William Lundy', 1332),
#  ('Jay Gerard', 1332),
#  ('Betty Jeanne Glennie', 1332),
#  ('Madge Journeay', 1332),
#  ('Chick Hannan', 1331),
#  ('Harcourt Williams', 1330),
#  ('Paul Rees', 1329),
#  ('Jean Corbett', 1329),
#  ('Paul Busch', 1329),
#  ('Bill Shine', 1328),
#  ('Kevin Pollak', 1327),
#  ('Cy Malis', 1327),
#  ('June Glory', 1326),
#  ('Dan Andreiu', 1326),
#  ('Jim Rhine', 1325),
#  ('Adolf Hitler', 1325),
#  ('Larry King', 1324),
#  ('Lala Detolly', 1322),
#  ('Ann Graeff', 1321),
#  ('Allen Jaffe', 1321),
#  ('Charles Dunbar', 1319),
#  ('Alex Gonzalez', 1319),
#  ('Lisl Valetti', 1318),
#  ('Grace Field', 1317),
#  ('Art Felix', 1317),
#  ('Dale Dye', 1316),
#  ('Dennis Hopper', 1315),
#  ('Hector Elizondo', 1315),
#  ('Chris Rock', 1314),
#  ('Evelyn Moriarty', 1314),
#  ('Albert Smith', 1314),
#  ('David Richardson', 1313),
#  ('George Holmes', 1312),
#  ('Jenny Inge', 1311),
#  ('Martin Luther King', 1310),
#  ('Jack Ellis', 1309),
#  ('Jorga Caye', 1308),
#  ('Jon Lovitz', 1307),
#  ('Basil Sydney', 1306),
#  ('Mitzi Sutherland', 1306),
#  ('Norman MacOwan', 1305),
#  ('John Capodice', 1304),
#  ('Peter Boyle', 1303),
#  ('Wesley Snipes', 1301),
#  ('Leota Lorraine', 1301),
#  ('Reginald Denny', 1301),
#  ('Myra Jones', 1301),
#  ('Byron Poindexter', 1301),
#  ('Maria Haro', 1300),
#  ('Steve Martin', 1297),
#  ('Forbes Murray', 1297),
#  ('Morgan Freeman', 1296),
#  ('Joe DeAngelo', 1296),
#  ('Stevie Myers', 1296),
#  ('Richard Aherne', 1295),
#  ('Tessie Murray', 1295),
#  ('Steven Randazzo', 1294),
#  ('Martin Landau', 1293),
#  ('George Paris', 1293),
#  ('John Kim', 1292),
#  ('George Russell', 1292),
#  ('Harry Gillette', 1291),
#  ('Winona Ryder', 1290),
#  ('Desmond Llewelyn', 1289),
#  ('Janeane Garofalo', 1289),
#  ('Gwyneth Paltrow', 1289),
#  ('Charles Durning', 1289),
#  ('Red Skelton', 1289),
#  ('Janice Hood', 1289),
#  ('Bill Pullman', 1288),
#  ('Stephen Tobolowsky', 1288),
#  ('Charles Boyer', 1288),
#  ('Pola Russ', 1288),
#  ('Murray Steckler', 1288),
#  ('Allen Zeidman', 1288),
#  ('Bob Okazaki', 1287),
#  ('Silver Harr', 1287),
#  ('Israel Garcia', 1286),
#  ('Norman Lee', 1286),
#  ('Kevin Bacon', 1285),
#  ('Renee Paul', 1285),
#  ('James Hong', 1284),
#  ('John Impolito', 1284),
#  ('Clint Eastwood', 1283),
#  ('Kimiko Hiroshige', 1282),
#  ('Helena Benda', 1282),
#  ('Bob Milton', 1282),
#  ('Danny Truppi', 1281),
#  ('George DeNormand', 1281),
#  ('Joe Dougherty', 1278),
#  ('Dolores Domasin', 1278),
#  ('Esther Ying Lee', 1277),
#  ('Marilyn Dialon', 1276),
#  ('Gerald Jann', 1276),
#  ('Carol Kane', 1275),
#  ('Michka Egan', 1275),
#  ('Ken Kane', 1275),
#  ('Nita Mathews', 1275),
#  ('Victor Romito', 1274),
#  ('Lynn Craft', 1274),
#  ('Max Cutler', 1274),
#  ('Charles Heard', 1274),
#  ('Frederick Leister', 1273),
#  ('Casey MacGregor', 1273),
#  ('Herb Pacheco', 1273),
#  ('Duke Seba', 1273),
#  ('John Rothman', 1272),
#  ('Hal Taggart', 1272),
#  ('Satini Pualoa', 1272),
#  ('Mark Margolis', 1271),
#  ('Harry Leroy', 1271),
#  ('Tina Blagoi', 1270),
#  ('Ronald Eng', 1270),
#  ('Fred Spitz', 1270),
#  ('Sylvester Stallone', 1269),
#  ('John Hurt', 1269),
#  ('Louise De Carlo', 1269),
#  ('Kathleen Desmond', 1269),
#  ('Dolores Ellsworth', 1269),
#  ('Joan Patti', 1269),
#  ('Leah Baird', 1269),
#  ('Donald Brown', 1269),
#  ('Armando Rodriguez', 1269),
#  ('Jack Oakie', 1268),
#  ('Jack Davis', 1268),
#  ('Larry Steers', 1267),
#  ('Ronald Colman', 1267),
#  ('Joe Molina', 1267),
#  ('Alfred Tonkel', 1267),
#  ('Gailard Sartain', 1266),
#  ('Leo Abbey', 1266),
#  ('Mary Lou Clifford', 1266),
#  ('Amir Farr', 1266),
#  ('Billy Bob Thornton', 1263),
#  ('Hermione Gingold', 1263),
#  ('Patrick Cargill', 1263),
#  ('Gary Carlos Cervantes', 1262),
#  ('Dale Van Sickel', 1262),
#  ('Tom Cruise', 1261),
#  ('Jack Lee', 1261),
#  ('William Yokota', 1261),
#  ('Eugene Beday', 1260),
#  ('Betty Rome', 1260),
#  ('Dolores Corral', 1259),
#  ('Rosita Delva', 1259),
#  ('Angela Gomez', 1259),
#  ('Harry Mayo', 1259),
#  ('Julio Rojas', 1259),
#  ('Andrew Roud', 1259),
#  ('Marie Scheue', 1259),
#  ('Millie Schottland', 1259),
#  ('Hayward Soo Hoo', 1259),
#  ('Robert Dulaine', 1258),
#  ('Frances Fong', 1257),
#  ('Richard Portnow', 1256),
#  ('John Dennis', 1256),
#  ('Irene Mizushima', 1255),
#  ('Margaret Farrell', 1254),
#  ('Walter Rode', 1254),
#  ('Peter Seal', 1254),
#  ('Bobbie Sheehan', 1253),
#  ('Bob Burrows', 1253),
#  ('Roy Goldman', 1253),
#  ('Charlotte Portney', 1253),
#  ('Amapola Del Vando', 1252),
#  ('Willie Keeler', 1252),
#  ('Jack Mulhall', 1252),
#  ('Clyde Kusatsu', 1251),
#  ('Bo Peep Karlin', 1251),
#  ('Ted Smile', 1251),
#  ('Kenneth Gibson', 1250),
#  ('Vi Ingraham', 1250),
#  ('George Wallace', 1249),
#  ('Salvadore Barroga', 1249),
#  ('Steve Cavalieri', 1249),
#  ('Bert Cefali', 1249),
#  ('Rod De Medici', 1249),
#  ('John Ferguson', 1249),
#  ('Patricia Patrick', 1249),
#  ('Paul Rochin', 1249),
#  ('Renato Siauss', 1249),
#  ('Victor McLaglen', 1248),
#  ('Jesse Adams', 1248),
#  ('Ivan Bell', 1248),
#  ('Martin Cichy', 1248),
#  ('Mark Gates', 1248),
#  ('Theresa Testa', 1248),
#  ('Alfredo Berumen', 1247),
#  ('Sherry Staiger', 1247),
#  ('Mary Kane', 1246),
#  ('William Duray', 1245),
#  ('Steve Carruthers', 1244),
#  ('Aurora Navarro', 1244),
#  ('Freda Jones', 1243),
#  ('Christian Slater', 1242),
#  ('Faye Dunaway', 1242),
#  ('Max Wagner', 1242),
#  ('Otto Forrest', 1242),
#  ('Sing Chen', 1242),
#  ('James Conaty', 1241),
#  ('Louis Hart', 1240),
#  ('Suey Chan', 1239),
#  ('Aida Turturro', 1237),
#  ('Zamba', 1237),
#  ('Anthony Hopkins', 1236),
#  ('Jeffrey Jones', 1236),
#  ('Jeff Goldblum', 1235),
#  ('Robert Newton', 1235),
#  ('Walter Soo Hoo', 1235),
#  ('Angelina Bauer', 1234),
#  ('Donald Gray', 1234),
#  ('Dolly Grey', 1234),
#  ('Gorja Max', 1233),
#  ('John Wayne', 1233),
#  ('John Leguizamo', 1232),
#  ('Philo McCullough', 1231),
#  ('Joan Kelly', 1230),
#  ('Charles Opunui', 1230),
#  ('Gilbert Roland', 1229),
#  ('Ben Stiller', 1227),
#  ('Tanya Samova', 1226),
#  ('Martin Strader', 1226),
#  ('Robert Garvin', 1225),
#  ('Woody Allen', 1224),
#  ('Charlie Sheen', 1223),
#  ('Gill Dennis', 1223),
#  ('Al Kikume', 1222),
#  ('Tony Urchel', 1222),
#  ('Gil Perkins', 1220),
#  ('Walter Fitzgerald', 1219),
#  ('Cameron Hall', 1219),
#  ('Shirley Heart', 1219),
#  ('Bernie Gozier', 1218),
#  ('William Janssen', 1218),
#  ('Ruth Oklander', 1218),
#  ('Keanu Reeves', 1217),
#  ('Michael Rooker', 1217),
#  ('Phil Proctor', 1215),
#  ('Paul Frees', 1215),
#  ('Lester Dorr', 1215),
#  ('Roger Ferreira', 1214),
#  ('Nick Nolte', 1213),
#  ('Ned Beatty', 1210),
#  ('Paul Tuerpe', 1207),
#  ('Ed Lauter', 1207),
#  ('Joe Pantoliano', 1207),
#  ('Cantinflas', 1206),
#  ('Ronald Squire', 1206),
#  ('Martine Carol', 1206),
#  ('Fernandel', 1206),
#  ('Robert Cabal', 1206),
#  ('Tim McCoy', 1206),
#  ('Edmund Lowe', 1206),
#  ('Beatrice Lillie', 1206),
#  ('Frank Royde', 1206),
#  ('Charles Abraham', 1206),
#  ('Dinah Ace', 1206),
#  ('Rosemarie Ace', 1206),
#  ('Boyd Ackerman', 1206),
#  ('Panchita Acosta', 1206),
#  ('Frances Adams', 1206),
#  ('George Agawa', 1206),
#  ('Benny Ahuna', 1206),
#  ('Fred Akahoshi', 1206),
#  ('Carlos Albert', 1206),
#  ('Gladys Alden', 1206),
#  ('Emil Alegata', 1206),
#  ('Kurpan Ali', 1206),
#  ('Lorey Allen', 1206),
#  ('Tom Allen', 1206),
#  ('Sally Alonzo', 1206),
#  ('Lupe Alvarado', 1206),
#  ('Dick Ames', 1206),
#  ('August Angelo', 1206),
#  ('William Angelo', 1206),
#  ('Ernest Aquilar', 1206),
#  ('Ed Arbogast', 1206),
#  ('Gene Ardell', 1206),
#  ('Danny Aredas', 1206),
#  ('Ray Arnett', 1206),
#  ('Russell Ash', 1206),
#  ('Eula Asher', 1206),
#  ('Edward Astran', 1206),
#  ('George Atsumo', 1206),
#  ('Besmark Auelua', 1206),
#  ('Aggie Auld', 1206),
#  ('Irene Austin', 1206),
#  ('Roy Aversa', 1206),
#  ('Kaz Awai', 1206),
#  ('Sande Aziko', 1206),
#  ('Alex Ball', 1206),
#  ('Ralph Bara', 1206),
#  ('Dick Barber', 1206),
#  ('Bertha Barbier', 1206),
#  ('Beverly Barker', 1206),
#  ('Olga Barone', 1206),
#  ('Robert Barry', 1206),
#  ('Mary Ellen Batten', 1206),
#  ('Escolastico Baucin', 1206),
#  ('Elena Beattie', 1206),
#  ('Eleanor Bender', 1206),
#  ('Ongyue Big', 1206),
#  ('Bobby Birchfiel', 1206),
#  ('Cathy Ann Bissutti', 1206),
#  ('Richard Bissutti', 1206),
#  ('Rosemary Blong', 1206),
#  ('George Bloom', 1206),
#  ('Toni Bond', 1206),
#  ('Paul Bordman', 1206),
#  ('Leon Bouvard', 1206),
#  ('Virginia Bradley', 1206),
#  ('Mario Bramucci', 1206),
#  ('Kahala Bray', 1206),
#  ('John Breneman', 1206),
#  ('Ernst Brengt', 1206),
#  ('Kenneth Brischof', 1206),
#  ('Mildred Brown', 1206),
#  ('Ollie Brown', 1206),
#  ('Wanda Brown', 1206),
#  ('Phyllis Brunner', 1206),
#  ('Helen Bruno', 1206),
#  ('Theona Bryant', 1206),
#  ('Guy Buccola', 1206),
#  ('Joan Buckley', 1206),
#  ('Al Buen', 1206),
#  ('Jane Burgess', 1206),
#  ('Ted Burgess', 1206),
#  ('Douglas Burnham', 1206),
#  ('Eugene Cahn', 1206),
#  ('Alan Calm', 1206),
#  ('Ann Cameron', 1206),
#  ('Joyce Cameron', 1206),
#  ('John Carboni', 1206),
#  ('Mick Carr', 1206),
#  ('Dick Carter', 1206),
#  ('Danny Casabian', 1206),
#  ('Perta Castneda', 1206),
#  ('Fred Cavens', 1206),
#  ('Frank Ceniceros', 1206),
#  ('Dorothy Chan', 1206),
#  ('Douglas Chan', 1206),
#  ('Eugene Chan', 1206),
#  ('Jowe Chan', 1206),
#  ('Lum Chan', 1206),
#  ('Mary Chan', 1206),
#  ('Ronald Chan', 1206),
#  ('Wong Hing Chan', 1206),
#  ('Pauline Chang', 1206),
#  ('Irene Chapman', 1206),
#  ('Huaplala Cherie', 1206),
#  ('Fon Chillson', 1206),
#  ('May Chinn', 1206),
#  ('Nina Chirva', 1206),
#  ('Lee Chon', 1206),
#  ('Margarite Chow', 1206),
#  ('Elaine Leemoi Chu', 1206),
#  ('Kui Sau Chui', 1206),
#  ('Wong Chun', 1206),
#  ('Bing Yee Chung', 1206),
#  ('Sue Fawn Chung', 1206),
#  ('Richard Dale Clark', 1206),
#  ('Walter Clinton', 1206),
#  ('Neil Collins', 1206),
#  ('Kathy Connors', 1206),
#  ('Connie Conrad', 1206),
#  ('Miguel Contreras', 1206),
#  ('Chabling Cooper', 1206),
#  ('Louis Cortina', 1206),
#  ('Campbell Cotts', 1206),
#  ('Theresa Courtland', 1206),
#  ('Catalina Cruz', 1206),
#  ('Ann Cullen', 1206),
#  ('Dorothy Curtis', 1206),
#  ('Gloria Dadisman', 1206),
#  ('Ruth Dalbrook', 1206),
#  ('Edmund Dantez', 1206),
#  ('Lawrence Daquila', 1206),
#  ('Theresa Darling', 1206),
#  ('Eddie Das', 1206),
#  ('Richard Date', 1206),
#  ('Seraphime Davidoff', 1206),
#  ('Jack Davies', 1206),
#  ('Denise De Lacey', 1206),
#  ('Anna De Linsky', 1206),
#  ('Angelo De Meo', 1206),
#  ('Lola De Ronda', 1206),
#  ('Gabriel De Valle', 1206),
#  ('Diana Deane', 1206),
#  ('Helen Dee', 1206),
#  ('Deena', 1206),
#  ('George Deere', 1206),
#  ('Douglas Degioia', 1206),
#  ('Maria Deglar', 1206),
#  ('Manuela DeHerey', 1206),
#  ('Maria Delgado', 1206),
#  ('La Verne Dell', 1206),
#  ('Emory Dennis', 1206),
#  ('Angela DeWitt', 1206),
#  ('Maya Kaur Dhillon', 1206),
#  ('Sterling Dillard', 1206),
#  ('Franklin Dix', 1206),
#  ('Edward Gary Dodds', 1206),
#  ('Bobby Dominguez', 1206),
#  ('William Dominguez', 1206),
#  ('William Donnelly', 1206),
#  ('Clint Dorrington', 1206),
#  ('Diane Dorsay', 1206),
#  ('Julie Dorsey', 1206),
#  ('Al Dowling', 1206),
#  ('Jack Downs', 1206),
#  ('Fanny Drabin', 1206),
#  ('Morris Drabin', 1206),
#  ('Barbara Drake', 1206),
#  ('Helene Drake', 1206),
#  ('John Drake', 1206),
#  ('Dewey Drapeau', 1206),
#  ('Joe Draper', 1206),
#  ('Harry Duff', 1206),
#  ('Gordon Dumont', 1206),
#  ('Renald Dupont', 1206),
#  ('Heidi Duval', 1206),
#  ('Bob Dyer', 1206),
#  ('Joan Dyer', 1206),
#  ('Mitchell Dylong', 1206),
#  ('Elaine Earl', 1206),
#  ('Ina Edell', 1206),
#  ('Ed Edmonson', 1206),
#  ('Jerry Elliott', 1206),
#  ('Calvin Emery', 1206),
#  ('Helen Enriquez', 1206),
#  ('Frank Erickson', 1206),
#  ('Maude Erickson', 1206),
#  ('Madge Erwin', 1206),
#  ('Miguel Esquembre', 1206),
#  ('Marcello Estorres', 1206),
#  ('Bob Evans', 1206),
#  ('Henry Faber', 1206),
#  ('James Fakato', 1206),
#  ('Antonio Farfan', 1206),
#  ('Felix Felton', 1206),
#  ('Tony Fillion', 1206),
#  ('John Fioff', 1206),
#  ('Carlo Fiore', 1206),
#  ('Gene Foley', 1206),
#  ('Clarence Fong', 1206),
#  ('Richard Fong', 1206),
#  ('Yut Man Fong', 1206),
#  ('Raymond Fontes', 1206),
#  ('Helen Foster', 1206),
#  ('Harold Francis', 1206),
#  ('Oscar Freeburg', 1206),
#  ('Milton Freibrun', 1206),
#  ('Wilma Friedman', 1206),
#  ('John Fritz', 1206),
#  ('Shilia Fritz', 1206),
#  ('Virginia Fuentes', 1206),
#  ('Janice Fujinani', 1206),
#  ('Tommy Fujiwara', 1206),
#  ('Koshihiro Fukdo', 1206),
#  ('Jay Fuller', 1206),
#  ('Sumi Funo', 1206),
#  ('John Furukawa', 1206),
#  ('Yoneka Furukawa', 1206),
#  ('Carol Ann Gainey', 1206),
#  ('Michael Gainey', 1206),
#  ('Juliana Galic', 1206),
#  ('Al Gallagher', 1206),
#  ('Elias Gamboa', 1206),
#  ('Charles Garcia', 1206),
#  ('Diana Garrison', 1206),
#  ('Edward Gee', 1206),
#  ('June Gee', 1206),
#  ('Toc Yee Gee', 1206),
#  ('Wong Kim Gee', 1206),
#  ('Wayne Geer', 1206),
#  ('Anita Gegna', 1206),
#  ('Curley Gibson', 1206),
#  ('Elaine Gilbert', 1206),
#  ('Leon Gill', 1206),
#  ('Njon Tuey Gin', 1206),
#  ('May Ginn', 1206),
#  ('Noreen Ginn', 1206),
#  ('Kay Ginoza', 1206),
#  ('Wong Git', 1206),
#  ('Mar Suey Gong', 1206),
#  ('Quon Gong', 1206),
#  ('Soledad Gonzales', 1206),
#  ('Charles Gonzalez', 1206),
#  ('Allen Goode', 1206),
#  ('Alora Gooding', 1206),
#  ('Verne Goodrich', 1206),
#  ('Lee Teu Gook', 1206),
#  ('Mickey Gotanda', 1206),
#  ('Oxy Goto', 1206),
#  ('Violet Goulet', 1206),
#  ('Betty Graeff', 1206),
#  ('Rita Graeff', 1206),
#  ('Joan Graffeo', 1206),
#  ('Grace Grant', 1206),
#  ('Valeri Gratton', 1206),
#  ('Eleanora Norina Greco', 1206),
#  ('Suzanne Greco', 1206),
#  ('David Greene', 1206),
#  ('David Greenwood', 1206),
#  ('Karla Gribbel', 1206),
#  ('Sei Jeri Groves', 1206),
#  ('Vic Groves', 1206),
#  ('Edward Grubb', 1206),
#  ('Jesus Guerra', 1206),
#  ('Tenmana Guerra', 1206),
#  ('Marilyn Gustafson', 1206),
#  ('Georgina Gutierrez', 1206),
#  ('Edward Ha', 1206),
#  ('Paul Haakon', 1206),
#  ('Betty Hall', 1206),
#  ('Mahgoub Hanaf', 1206),
#  ('Maria Hanson', 1206),
#  ('Doc Harnett', 1206),
#  ('James Hasagawa', 1206),
#  ('George Hashimoto', 1206),
#  ('Gus Hashimoto', 1206),
#  ('Lauren Hastings', 1206),
#  ('William Hayden', 1206),
#  ('Frank Heaney', 1206),
#  ('Bonnie Henjum', 1206),
#  ('Charles Hennecke', 1206),
#  ('Clarence Hennecke', 1206),
#  ('Robert Hennes', 1206),
#  ('Allen Herb', 1206),
#  ('Gitanillo Heredia', 1206),
#  ('George Higa', 1206),
#  ('Sue Hikawa', 1206),
#  ('Jimmy Hing', 1206),
#  ('Yoshio Hiraga', 1206),
#  ('Hiroshi Hisamune', 1206),
#  ('Fun Ho', 1206),
#  ('Lee Yuen Hock', 1206),
#  ('Yoshyo Hohamura', 1206),
#  ('Syd Holtby', 1206),
#  ('Yee Jock Hom', 1206),
#  ('Kenny Homabe', 1206),
#  ('Midori Homano', 1206),
#  ('Hans Hopf', 1206),
#  ('John Hoskin', 1206),
#  ('Gretchen Houser', 1206),
#  ('Ken Hovey', 1206),
#  ('Gladys Howe', 1206),
#  ('Lee Yuen Hoy', 1206),
#  ('Madelon Hubbard', 1206),
#  ('Warren Huff', 1206),
#  ('Roddy Hughes', 1206),
#  ('Tom Humphrey', 1206),
#  ('Frank Hunt', 1206),
#  ('Yoneo Iguchi', 1206),
#  ('Joe Iino', 1206),
#  ('Taruko Ikari', 1206),
#  ('Kazuo Ikida', 1206),
#  ('Kay Imamura', 1206),
#  ('Omaru Imazaki', 1206),
#  ('David Inez', 1206),
#  ('Leona Irvin', 1206),
#  ('Leona Irwin', 1206),
#  ('Yoshio Ishibashi', 1206),
#  ('Tom Ishikura', 1206),
#  ('Ray Ishimatsu', 1206),
#  ('Kinuko Ann Ito', 1206),
#  ('Roy Iwaki', 1206),
#  ('Jacqueline Jackler', 1206),
#  ('Diane Jackson', 1206),
#  ('Marjorie Jackson', 1206),
#  ('Charles James', 1206),
#  ('Idell James', 1206),
#  ('Mary Jan', 1206),
#  ('Sushila Janadas', 1206),
#  ('Dolly Jarvis', 1206),
#  ('Joan Jerrae', 1206),
#  ('Robert Jewett', 1206),
#  ('Antonio Jiminez', 1206),
#  ('Dee Ho Joe', 1206),
#  ('Todd Joko', 1206),
#  ('Sallie Jones', 1206),
#  ('Winfield Jones', 1206),
#  ('Raymond Joyer', 1206),
#  ('Fred Kajikawa', 1206),
#  ('Gee Toy Kam', 1206),
#  ('Yukimi Kamaka', 1206),
#  ('Joe Kameshita', 1206),
#  ('Stanley Kamijama', 1206),
#  ('Madelynne Kane', 1206),
#  ('Morris Kaneshire', 1206),
#  ('Mamie Karaki', 1206),
#  ('Harumi Kashaka', 1206),
#  ('Ken Kato', 1206),
#  ('George Katsuhiro', 1206),
#  ('George Kawashima', 1206),
#  ('Tak Kawashima', 1206),
#  ('Valentine Kekipi', 1206),
#  ('Jodi Kelley', 1206),
#  ('Fannie Kennerly', 1206),
#  ('Eleanor Kent', 1206),
#  ('Joseph Gee Key', 1206),
#  ('Allan Kila', 1206),
#  ('Anita King', 1206),
#  ('Grace King', 1206),
#  ('Ken Kinoshita', 1206),
#  ('Shinya Kito', 1206),
#  ('Max Kleven', 1206),
#  ...]

# %%
# Checking actors with degrees in given partition
G.degree(parts[0])
# Out:
# DegreeView({'Tom Hanks': 1506, 'Erik von Detten': 327, 'Cody Dorkin': 157, 'Robin Williams': 1714, 'Bonnie Hunt': 836, 'Marcus Klemp': 91, 'Geraldo Rivera': 491, 'Johnny Luckett': 557, 'Ryan Wotherspoon': 169, 'Loretta Devine': 600, 'Brandon Hammond': 474, 'Lamont Johnson': 317, 'Theo': 37, 'Ken Love': 37, 'Cordell Conway': 37, 'Hope Brown': 37, 'Delaina Hlavin': 168, 'Luis Sharpe': 37, 'Ezra Swerdlow': 37, 'Ellin La Var': 102, 'Patricia Anne Fox': 37, 'Wally Bujack': 37, 'William Bolander': 134, 'Kacee DeMasi': 953, 'Tom Hedrick': 37, 'Donyell Hinton': 37, 'Bob Huff': 150, 'Angela Kenzslowe': 37, 'Kelly Preston': 925, 'Juliet Rose Serrato': 178, 'Rebecca Chambers': 54, 'April Ortiz': 131, 'Kathy Anthony': 54, 'Adrian Canzoneri': 54, 'Stephanie Miller': 54, 'Jay Wolpert': 123, 'Ann Walker': 175, 'Sandra Silvestri': 54, 'William Akey': 110, 'Jonathan Emerson': 209, 'Seth Kaplan': 54, 'Chase Colwell': 54, 'Tony Simotes': 301, 'Linda DeScenna': 54, 'Heidi Averill': 54, 'Chelsea Lynn': 54, 'Sue Colwell': 54, 'Rodrigo Botero': 54, 'Vince Lozano': 251, 'Caroline Lagerfelt': 141, 'Ilene Waterstone': 54, 'Wendy Worthington': 198, 'Dorian Spencer': 101, 'Roxanne Beckford': 54, 'Peter Spears': 83, 'Mychael Bates': 193, 'Jerri Rose White': 54, 'Shannon Kennedy': 54, 'Casey Boersma': 89, 'Katie Pierce': 54, 'Dylan Boersma': 89, 'Jonathan Selstad': 54, 'Thomas Selstad': 54, 'Christian Boeving': 206, 'Kellie Hudson': 54, 'Ashlyn Messick': 183, 'Kayley Messick': 183, 'David Novak': 376, 'Kylie Travis': 61, 'Jon Voight': 1457, 'Tom Sizemore': 1639, 'Amy Brenneman': 314, 'Kevin Gage': 416, 'Danny Trejo': 910, 'Jerry Trimble': 154, 'Ricky Harris': 425, 'Tone Loc': 409, 'Ray Buktenica': 120, 'Jeremy Piven': 1053, 'Xander Berkeley': 1477, 'Rick Avery': 766, 'Brad Baldridge': 81, 'Andrew Camuccio': 131, 'Brian Camuccio': 131, 'Max Daniels': 297, 'Thomas Elfmont': 81, 'Kimberly Flynn': 175, 'Steven Ford': 775, 'Farrah Forke': 123, 'Hannes Fritsch': 129, 'Amanda Graves': 81, 'Emily Graves': 81, 'Niki Haris': 162, 'Ted Harvey': 81, 'Patricia Healy': 230, 'Cindy Katz': 194, 'Brian Libby': 614, 'Bill McIntosh': 446, 'Dan Martin': 369, 'Paul Moyer': 81, 'Mario Roberts': 797, 'Phillip Robinson': 81, 'Rainelle Saunders': 137, 'Kai Soremekun': 81, 'Rey Verdugo': 81, 'Yvonne Zima': 297, 'Anthony Backman': 548, 'Monica Lee Bellais': 390, 'Peter Blackwell': 81, 'Trevor Coppola': 300, 'Bud Cort': 778, 'Michele Edison': 280, 'Mick Gould': 81, 'Mary Kircher': 330, 'Darin Mangan': 341, 'Andre McCoy': 189, 'Robert Miranda': 641, 'Iva Franks Singer': 274, 'Jimmy Star': 1879, 'Gloria Straube': 345, 'Viviane Vives': 209, 'Tim Werner': 169, 'Greg Kinnear': 724, 'Angie Dickinson': 493, 'Patrick Bruel': 132, 'Paul Giamatti': 1482, 'Phil Nee': 223, 'Susan Browning': 278, 'Dale Resteghini': 1122, 'Jonathan Taylor Thomas': 305, 'Brad Renfro': 416, 'Rachael Leigh Cook': 645, 'Lanny Flaherty': 476, 'Heath Lamberts': 43, 'Joey Stinson': 76, 'Blake Heron': 55, 'Adrian Roberts': 179, 'Tiffany Lynn Clark': 43, 'Bronwen Murray': 43, 'Paul Kropfl': 98, 'Tommy Lamey': 43, 'Mathew Valencia': 69, 'Rosemary Alexander': 81, 'Sherry Hursey': 107, 'Tamara Mello': 279, 'Toby Ganger': 84, 'Austin Kottke': 181, 'Katherine Zarimba': 43, 'Emmy Collins': 918, 'Wade Woods': 76, 'Michelle Arthur': 181, 'Michael Douglas': 1003, 'Samantha Mathis': 389, 'Shawna Waldron': 78, 'Nina Siemaszko': 473, 'Joshua Malina': 383, 'Clement von Franckenstein': 402, 'John Mahon': 517, 'Kurt Boesen': 164, 'Andrew Steel': 105, 'Jordan Lund': 708, 'Richard McGonagle': 519, 'Alice Kushida': 198, 'Renee Faia': 119, 'Kathryn Ish': 78, 'Kamilah Martin': 78, 'Augie Blunt': 173, 'Thom Barry': 899, 'Steve Gonzales': 414, 'Karen Maruyama': 181, 'Nancy Kandal': 78, 'Jack Gilroy': 78, 'Matthew Saks': 321, 'Brian Coffee': 78, 'Rick Garcia': 529, 'Aaron Sorkin': 105, 'Kymberly Newberry': 259, 'Arthur Senzy': 401, 'Jorge Noa': 116, 'Maud Winchester': 461, 'Jeffrey Anderson': 78, 'Suzanne Michaels': 177, 'David Drew Gallagher':  ...
