# %%
forceatlas2 = ForceAtlas2(
                        # Behavior alternatives
                        outboundAttractionDistribution=True,  # Dissuade hubs
                        linLogMode=False,  # NOT IMPLEMENTED
                        adjustSizes=False,  # Prevent overlap (NOT IMPLEMENTED)
                        edgeWeightInfluence=1.0,

                        # Performance
                        jitterTolerance=1.0,  # Tolerance
                        barnesHutOptimize=True,
                        barnesHutTheta=1.0,
                        multiThreaded=False,  # NOT IMPLEMENTED

                        # Tuning
                        scalingRatio=2,
                        strongGravityMode=False,
                        gravity=1.5,

                        # Log
                        verbose=True)

# %% [markdown]
# # **Reading in the data**

# %%
import pandas as pd
import numpy as np
import re
import networkx as nx
import matplotlib.pyplot as plt
from fa2 import ForceAtlas2
import community
import itertools
import networkx.algorithms.community as nx_comm
from networkx.algorithms import bipartite
import re
import csv
from fa2 import ForceAtlas2
import community


folder = "../Movie Dataframe with Ratings/"
df1 = pd.read_pickle(folder+"networkData1.pkl")
df2 = pd.read_pickle(folder+"networkData2.pkl")
df3 = pd.read_pickle(folder+"networkData3.pkl")

frames = [df1, df2, df3]
moviesDf = pd.concat(frames, axis=0, ignore_index=True)

# %%
actor_column = list(moviesDf["Actors"].to_numpy())
actors = [actor for cast in actor_column for actor in cast]
duplicates = set(actors) & set(moviesDf["MovieTitle"].to_numpy())
duplicates

# Removing movies where an Actor is called the same
moviesDf.drop(moviesDf[moviesDf['MovieTitle'].isin(duplicates)].index, inplace = True)

# %% [markdown]
# **Extracting relevant columns**

# %%
genres = (moviesDf['Genres'].to_numpy())
rating_column = moviesDf['Rating'].to_numpy()
genre_column = [re.findall(r"'name': '(.*?)'}", s) for s in genres]
title_column = moviesDf["MovieTitle"].to_numpy()
actor_column = list(moviesDf["Actors"].to_numpy())


#Only using 5 actors
#actor_column5 = []
#for actors in (actor_column):
#    actor_column5.append(actors[:5])
#actor_column = actor_column5
    
actorsDistinct = [*set([actor for cast in actor_column for actor in cast])]

# %% [markdown]
# # Creating the graph

# %% [markdown]
# **Generating the bipartite network of Actors and Movies**

# %%
G = nx.Graph()

#G.add_nodes_from(title_column, bipartite=0)
for i, title in enumerate((title_column)):
    G.add_node(title, bipartite=0, Genres = genre_column[i])
    
G.add_nodes_from(actorsDistinct, bipartite=1)


for i, movie in enumerate(title_column):
    # Adding links between each movie and its actors
    G.add_edges_from(list(zip(itertools.repeat(movie), actor_column[i])))

# %%
# Out:
# 'Jumanji'

# %%
bipartite.is_bipartite(G)
# Out:
# True

# %% [markdown]
# **Basic stats**

# %%
print(f'Nodes: {G.number_of_nodes()}')
print(f'Edges: {G.number_of_edges()}\n')
# Out:
# Nodes: 137704
# Edges: 255020

# %% [markdown]
# **Extracting the projected Actor Network and the Movie Network from the biparite graph**

# %%
actorNodes = {n for n, d in G.nodes(data=True) if d["bipartite"] == 1}
movieNodes = {n for n, d in G.nodes(data=True) if d["bipartite"] == 0}

actorNetwork = bipartite.weighted_projected_graph(G, actorNodes, ratio = False)
movieNetwork = bipartite.weighted_projected_graph(G, movieNodes, ratio = False)

# %%
print(f'Actor network stats')
print(f'Nodes: {actorNetwork.number_of_nodes()}')
print(f'Edges: {actorNetwork.number_of_edges()}\n')

print(f'Movie network stats')
print(f'Nodes: {movieNetwork.number_of_nodes()}')
print(f'Edges: {movieNetwork.number_of_edges()}\n')
# Out:
# Actor network stats
# Nodes: 131746
# Edges: 8086719
#
# Movie network stats
# Nodes: 5958
# Edges: 468645

# %% [markdown]
# # Testing stuff

# %%
movieEdges = sorted(nx.get_edge_attributes(movieNetwork, 'weight').items(), key=lambda x: x[1], reverse = True)
actorEdges = sorted(nx.get_edge_attributes(actorNetwork, 'weight').items(), key=lambda x: x[1], reverse = True)

# %%
movieDegrees = sorted(movieNetwork.degree(weight='weight'), key=lambda x: x[1], reverse=True)
actorDegrees = sorted(actorNetwork.degree(weight='weight'), key=lambda x: x[1], reverse=True)

# %% [markdown]
# # Extracting backbone of network

# %%
from backbone import *

# %%
actorAlphaNetwork = disparity_filter(actorNetwork)
movieAlphaNetwork = disparity_filter(movieNetwork)

# %%
#alphaActor = 0.1
alphaActor = 0.12
actorNetworkBackbone = nx.Graph([(u, v, d) for u, v, d in actorAlphaNetwork.edges(data=True) if d['alpha'] < alphaActor])
alphaMovie = 0.12
movieNetworkBackbone = nx.Graph([(u, v, d) for u, v, d in movieAlphaNetwork.edges(data=True) if d['alpha'] < alphaMovie])

# %%
#sorted(nx.get_edge_attributes(actorNetworkBackbone, 'alpha').items(), key=lambda x: x[1], reverse = False)
#sorted(nx.get_edge_attributes(actorNetworkBackbone, 'weight').items(), key=lambda x: x[1], reverse = False)

# %%
print(f'Actor network backbone stats')
print(f'Nodes: {actorNetworkBackbone.number_of_nodes()}')
print(f'Edges: {actorNetworkBackbone.number_of_edges()}\n')

print(f'Movie network backbone stats')
print(f'Nodes: {movieNetworkBackbone.number_of_nodes()}')
print(f'Edges: {movieNetworkBackbone.number_of_edges()}\n')
# Out:
# Actor network backbone stats
# Nodes: 5802
# Edges: 23271
#
# Movie network backbone stats
# Nodes: 3860
# Edges: 13205

# %%
movieBackboneDegrees = sorted(movieNetworkBackbone.degree(weight='weight'), key=lambda x: x[1], reverse=True)
actorBackboneDegrees = sorted(actorNetworkBackbone.degree(weight='weight'), key=lambda x: x[1], reverse=True)
actorBackboneDegreesValues = [val for name, val in actorBackboneDegrees]
movieBackboneDegreesValues = [val for name, val in movieBackboneDegrees]

# %%
# Binning actors
b = np.arange(np.min(actorBackboneDegreesValues),np.max(actorBackboneDegreesValues),1)
actorFreq, actorBins = np.histogram(actorBackboneDegreesValues, bins = b);
#p_k_sune = [i/np.sum(freq) for i in freq]

# Binning Movies
b = np.arange(np.min(movieBackboneDegreesValues),np.max(movieBackboneDegreesValues),1)
movieFreq, movieBins = np.histogram(movieBackboneDegreesValues, bins = b);
#p_k_sune = [i/np.sum(freq) for i in freq]

# Plotting
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,4))
fig.tight_layout()
ax1.set_title('Actor Network', fontsize = 20)
ax1.set_xlabel('k', fontsize = 14)
ax1.set_ylabel('$count$', fontsize = 14)
ax1.bar(actorBins[:-1], actorFreq, color = 'purple');
ax1.set_xlim(0,100);

ax2.set_title('Movie Network', fontsize = 20)
ax2.set_xlabel('k', fontsize = 14)
ax2.set_ylabel('$count$', fontsize = 14)
ax2.bar(movieBins[:-1], movieFreq, color = 'purple');
ax2.set_xlim(0,100);
plt.show()

# %% [markdown]
# # Plotting network Actors

# %%
# Removing nodes with very small degree (might be illegal)
remove = [node for node,degree in dict(actorNetworkBackbone.degree()).items() if degree < 4]
actorNetworkBackbone.remove_nodes_from(remove)

# %%
# Extracting largest connected component
nodes = max(nx.connected_components(actorNetworkBackbone), key=len)
actorNetworkBackbone = actorNetworkBackbone.subgraph(nodes).copy()

# %%
positions = forceatlas2.forceatlas2_networkx_layout(actorNetworkBackbone, pos=None, iterations=100);
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:05<00:00, 19.17it/s]
# BarnesHut Approximation  took  1.46  seconds
# Repulsion forces  took  3.59  seconds
# Gravitational forces  took  0.02  seconds
# Attraction forces  took  0.02  seconds
# AdjustSpeedAndApplyForces step  took  0.06  seconds

# %%
d = dict(actorNetworkBackbone.degree).values()
scale = 1
node_size = [degree*scale for degree in d]

# %%
# Best partition found with louvain algorithm
partition = community.best_partition(actorNetworkBackbone, random_state = 1, randomize = False)

# Defining values for the color spectrum
maxval = np.max(list(partition.values())) 
cmap=plt.cm.Spectral
node_color = [cmap(v/maxval) for v in partition.values()]

# Plotting
fig = plt.figure(1,figsize=(20,12)) 
nx.draw_networkx_nodes(actorNetworkBackbone, pos = positions, node_color=node_color, alpha=0.9, node_size = node_size);
nx.draw_networkx_edges(actorNetworkBackbone, pos = positions, alpha=0.04);

# For legend creation only
for v in set(partition.values()):
    plt.scatter([],[], c=[cmap(v/maxval)], label='Community {}'.format(v))

plt.title('Actor Network nodes colored by community', fontsize = 20)
plt.legend(loc='upper left', prop={'size': 14})
plt.savefig('actorNetwork.png')
plt.show()

# %%
# rearanging found partition
partsActor = []
for i in range(0, len(set(partition.values()))):
    partsActor.append([])
    
for actor, com in partition.items():
    partsActor[com].append(actor)

#sorting based on biggest communities
partsActorSorted = partsActor
partsActorSorted.sort(key=len, reverse = True)

# %% [markdown]
# # Plotting network Movies

# %%
# Removing nodes with very small degree (might be illegal)
remove = [node for node,degree in dict(movieNetworkBackbone.degree()).items() if degree < 6]
movieNetworkBackbone.remove_nodes_from(remove)

# %%
# Extracting largest connected component
nodes = max(nx.connected_components(movieNetworkBackbone), key=len)
movieNetworkBackbone = movieNetworkBackbone.subgraph(nodes).copy()

# %%
positions = forceatlas2.forceatlas2_networkx_layout(movieNetworkBackbone, pos=None, iterations=100);
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:03<00:00, 31.80it/s]
# BarnesHut Approximation  took  1.30  seconds
# Repulsion forces  took  1.75  seconds
# Gravitational forces  took  0.01  seconds
# Attraction forces  took  0.01  seconds
# AdjustSpeedAndApplyForces step  took  0.04  seconds

# %%
d = dict(movieNetworkBackbone.degree).values()
scale = 4
node_size = [degree*scale for degree in d]

# %%
# Best partition found with louvain algorithm
partition = community.best_partition(movieNetworkBackbone, random_state = 1, randomize = False)

# Defining values for the color spectrum
maxval = np.max(list(partition.values())) 
cmap=plt.cm.Spectral
node_color = [cmap(v/maxval) for v in partition.values()]

# Plotting
plt.figure(1,figsize=(20,12)) 
nx.draw_networkx_nodes(movieNetworkBackbone, pos = positions, node_color=node_color, alpha=0.9, node_size = node_size);
nx.draw_networkx_edges(movieNetworkBackbone, pos = positions, alpha=0.04);

# For legend creation only
for v in set(partition.values()):
    plt.scatter([],[], c=[cmap(v/maxval)], label='Community {}'.format(v))

plt.title('Movie Network nodes colored by community', fontsize = 20)
plt.legend(loc='upper left', prop={'size': 14})
plt.savefig('movieNetwork.png')
plt.show()

# %%
# rearanging found partition
partsMovie = []
for i in range(0, len(set(partition.values()))):
    partsMovie.append([])
    
for actor, com in partition.items():
    partsMovie[com].append(actor)
    
#sorting based on biggest communities
partsMovieSorted = partsMovie
partsMovieSorted.sort(key=len, reverse = True)

# %% [markdown]
# # Analysing found communities

# %%
communitySizeActor = [len(com) for com in partsActor]
communitySizeMovie = [len(com) for com in partsMovie]
print(communitySizeActor)
print(communitySizeMovie)
# Out:
# [288, 245, 241, 238, 181, 110, 96, 91, 88, 60, 48, 48, 47, 38, 37, 31, 28, 23, 19, 17, 16, 14, 12, 12]
# [344, 169, 152, 147, 126, 112, 72, 41, 31, 22, 21, 20, 19, 12, 9]

# %%
for i in partsActor:
    print(i[:5])
# Out:
# ['Franklyn Farnum', 'Leoda Richards', 'Bert Stevens', 'Brandon Beach', 'Norman Stevans']
# ['Julia Faye', 'Chuck Hamilton', 'Dorothy Vernon', 'William Meader', 'Jack Lemmon']
# ['Marshall Dancing Elk Lucas', 'Michael Rapaport', 'Jack Warden', 'Brion James', 'Woody Allen']
# ['John Gielgud', 'Guy Standeven', 'Harry Fielder', 'Trevor Howard', 'Desmond Llewelyn']
# ['Bert Moorhouse', 'Leo White', 'James Stewart', 'James Flavin', 'George Anderson']
# ['Jack Riley', 'Tress MacNeille', 'Michael Bell', 'Whoopi Goldberg', 'Kath Soucie']
# ['Sean Stone', 'Oliver Stone', 'Biff Yeager', 'Ed Pansullo', 'Del Zamora']
# ['Danny Nero', 'Bob Harks', 'Stan Rodarte', 'Hank Robinson', 'Conrad Hurtt']
# ['Peter Jason', 'Allan Graf', 'Greg Bronson', 'Dennis Quaid', 'Luis Contreras']
# ['John Candy', 'James Rebhorn', 'Randy Quaid', 'Daniel von Bargen', 'Matthew Lillard']
# ['Lin Shaye', 'Chris Elliott', 'Scott Grimes', 'Don Keith Opper', 'Edward Chiodo']
# ['Anjelica Huston', 'Jack Nicholson', 'Christina Ricci', 'Christopher Lloyd', 'Burt Reynolds']
# ['Larry Miller', 'Jane Morris', 'Patrick Richwood', 'Tracy Reiner', 'Kathleen Marshall']
# ['Dennis Hopper', 'James Westerfield', 'Fred MacMurray', 'Buster Keaton', 'Harvey Lembeck']
# ['Michael McKean', 'Phil Hartman', 'Jon Lovitz', 'Adam Sandler', 'Geoffrey Blake']
# ['John Landis', 'Frank Oz', 'Richard Hunt', 'Jim Henson', 'David Stone']
# ['Grace Lee Whitney', 'Joel Marston', 'Ryal Haakenson', 'Brent Spiner', 'Arnold Schwarzenegger']
# ['Clint Eastwood', 'Bill McKinney', 'Sondra Locke', 'Roy Jenson', 'Geoffrey Lewis']
# ['Stanley Townsend', 'Sean Lawlor', 'Brendan Gleeson', 'Oliver Maguire', 'Gerard McSorley']
# ['Judy Landon', 'Dee Turnell', 'Luigi Faccuito', 'Madge Blake', 'Jimmy Thompson']
# ['Taylor Negron', 'Scott Thomson', 'Bruce Mahler', 'Michael Winslow', 'Arthur Batanides']
# ['Charles McKeown', 'Ray Cooper', 'Eric Idle', 'Terry Gilliam', 'Neil Innes']
# ['Orlando Delbert', 'Marc Macaulay', 'Antoni Corone', 'Al Quinn', 'Deborah Smith Ford']
# ['Kenneth Branagh', 'Michael Maloney', 'Kenneth W Caravan', 'Helena Bonham Carter', 'Richard Briers']

# %%
print(f'Actor network backbone stats')
print(f'Nodes: {actorNetworkBackbone.number_of_nodes()}')
print(f'Edges: {actorNetworkBackbone.number_of_edges()}\n')

print(f'Movie network backbone stats')
print(f'Nodes: {movieNetworkBackbone.number_of_nodes()}')
print(f'Edges: {movieNetworkBackbone.number_of_edges()}\n')
# Out:
# Actor network backbone stats
# Nodes: 2028
# Edges: 18202
#
# Movie network backbone stats
# Nodes: 1297
# Edges: 8805

# %%
movieBackboneDegrees = sorted(movieNetworkBackbone.degree(), key=lambda x: x[1], reverse=True)
actorBackboneDegrees = sorted(actorNetworkBackbone.degree(), key=lambda x: x[1], reverse=True)

# %%
actorBackboneDegrees
# Out:
# [('Bert Stevens', 280),
#  ('Sam Harris', 255),
#  ('Norman Stevans', 216),
#  ('Arthur Tovey', 214),
#  ('Bess Flowers', 212),
#  ('James Gonzalez', 190),
#  ('Hans Moebus', 184),
#  ('Jeffrey Sayre', 177),
#  ('Herschel Graham', 177),
#  ('Harold Miller', 172),
#  ('John Roy', 166),
#  ('Michael Jeffers', 166),
#  ('Rudy Germane', 165),
#  ('Dick Cherney', 164),
#  ('Stuart Holmes', 163),
#  ('Frank McLure', 161),
#  ('Franklyn Farnum', 160),
#  ('Paul Power', 155),
#  ('Paul Bradley', 154),
#  ('Stuart Hall', 154),
#  ('Robert Locke Lorraine', 146),
#  ('Fred Rapport', 143),
#  ('Joe Ploski', 143),
#  ('Chet Brandenburg', 139),
#  ('Chuck Hamilton', 138),
#  ('Charles Morton', 135),
#  ('Shep Houghton', 134),
#  ('William Meader', 134),
#  ('Cosmo Sardo', 131),
#  ('Leoda Richards', 130),
#  ('George Bruggeman', 129),
#  ('Raoul Freeman', 129),
#  ('Paul Cristo', 125),
#  ('Guy Standeven', 123),
#  ('Frank Baker', 122),
#  ('Jimmie Horan', 119),
#  ('Thomas Martin', 116),
#  ('Robert Haines', 115),
#  ('Scott Seaton', 112),
#  ('Brandon Beach', 111),
#  ('Bernard Sell', 111),
#  ('Benjie Bancroft', 111),
#  ('Steve Carruthers', 111),
#  ('Charles Fogel', 106),
#  ('John Rice', 105),
#  ('George Ford', 105),
#  ('Mike Lally', 103),
#  ('Oliver Cross', 102),
#  ('Waclaw Rekwart', 101),
#  ('Richard LaMarr', 101),
#  ('Hal Taggart', 100),
#  ('Leslie Sketchley', 99),
#  ('Jack Perrin', 99),
#  ('Walter Bacon', 98),
#  ('Joseph Glick', 98),
#  ('John Marlin', 96),
#  ('Lars Hensen', 96),
#  ('Donald Kerr', 93),
#  ('Al Bain', 91),
#  ('Cap Somers', 91),
#  ('King Lockwood', 90),
#  ('Fred Wood', 90),
#  ('Jack Chefe', 89),
#  ('Beulah Christian', 89),
#  ('Kenneth Gibson', 89),
#  ('Ray Spiker', 88),
#  ('George Holmes', 88),
#  ('Joe Evans', 87),
#  ('Duke Fishman', 87),
#  ('Joe Gray', 86),
#  ('Sailor Vincent', 85),
#  ('Clark Ross', 84),
#  ('Murray Pollack', 84),
#  ('Harry Wilson', 83),
#  ('Dick Gordon', 83),
#  ('Tony Regan', 82),
#  ('Bert Moorhouse', 81),
#  ('Leon Alton', 81),
#  ('George DeNormand', 78),
#  ('Tex Brodus', 77),
#  ('George Nardelli', 76),
#  ('Chalky Williams', 76),
#  ('Chuck Hicks', 76),
#  ('Joe Gilbert', 75),
#  ('Robert Robinson', 75),
#  ('Sammy Shack', 74),
#  ('Ralph Brooks', 74),
#  ('Brick Sullivan', 73),
#  ('Boyd Cabeen', 73),
#  ('Sol Murgi', 72),
#  ('Colin Kenny', 72),
#  ('Perk Lazelle', 71),
#  ('Forbes Murray', 71),
#  ('Jack Deery', 70),
#  ('Wilbur Mack', 70),
#  ('Harry Denny', 70),
#  ('James Conaty', 69),
#  ('Ben Frommer', 69),
#  ('Mike Morelli', 69),
#  ('Aileen Lewis', 68),
#  ('Suzanne Ridgway', 68),
#  ('Albert Cavens', 67),
#  ('Harry Fielder', 66),
#  ('John Barton', 66),
#  ('Mathew McCue', 65),
#  ('Mabel Smaney', 65),
#  ('Marion Gray', 65),
#  ('Max Wagner', 64),
#  ('Bob Harks', 63),
#  ('Charles Sullivan', 63),
#  ('Minta Durfee', 63),
#  ('Michael Cirillo', 63),
#  ('Frank Mills', 63),
#  ('Jack Gordon', 62),
#  ('Gertrude Astor', 62),
#  ('Victor Romito', 62),
#  ('Danny Borzage', 62),
#  ('Dan Dowling', 61),
#  ('Ron Nyman', 61),
#  ('Eumenio Blanco', 61),
#  ('Stephen Soldi', 61),
#  ('Bobby Gilbert', 60),
#  ('Robert Cole', 60),
#  ('Leota Lorraine', 60),
#  ('Derek Lyons', 59),
#  ('Jose Portugal', 59),
#  ('John Alban', 59),
#  ('Victor Harrington', 58),
#  ('Philo McCullough', 58),
#  ('Herman Hack', 58),
#  ('Fred Aldrich', 58),
#  ('Nick Borgani', 57),
#  ('Joseph La Cava', 57),
#  ('Al Bridge', 57),
#  ('Charles Perry', 56),
#  ('Pat Flaherty', 56),
#  ('Frank Welker', 55),
#  ('Juba Kennerley', 54),
#  ('Dick Johnstone', 54),
#  ('Bud Cokes', 54),
#  ('Alan Harris', 53),
#  ('Barry Norton', 53),
#  ('Johnny Kern', 53),
#  ('Robert Hitchcock', 52),
#  ('Hank Robinson', 51),
#  ('John Tatham', 51),
#  ('Nina Borget', 51),
#  ('Jack Tornek', 51),
#  ('Ken DuMain', 51),
#  ('Greg Bronson', 50),
#  ('Jack Kenny', 49),
#  ('Peter Renaday', 49),
#  ('Charles Horvath', 49),
#  ('Mickie McGowan', 49),
#  ('James Carlisle', 48),
#  ('Dorothy Vernon', 47),
#  ('Tom Ferrandini', 47),
#  ('Bob Whitney', 47),
#  ('Paul Frees', 47),
#  ('Hector Elizondo', 47),
#  ('Lester Dorr', 47),
#  ('Phil Proctor', 46),
#  ('Frank Oz', 46),
#  ('Chester Hayes', 46),
#  ('Frank Sinatra', 46),
#  ('Adolph Faylauer', 45),
#  ('Cyril Ring', 45),
#  ('Danny Sands', 45),
#  ('Oscar Blank', 45),
#  ('Russell Custer', 45),
#  ('Alphonso DuBois', 45),
#  ('Bob Bergen', 45),
#  ('Mary Bayless', 44),
#  ('Nora Bush', 44),
#  ('Willie Bloom', 44),
#  ('Jack Angel', 44),
#  ('Roy Damron', 43),
#  ('Hank Mann', 43),
#  ('Bob Reeves', 42),
#  ('Jack Perry', 42),
#  ('Jack Berle', 42),
#  ('Sean Gildea', 42),
#  ('Desmond Llewelyn', 41),
#  ('Roy Beck', 41),
#  ('Don Anderson', 41),
#  ('George Calliga', 41),
#  ('Jack Gardner', 41),
#  ('Harry Evans', 41),
#  ('Al Haskell', 41),
#  ('Kathleen Marshall', 41),
#  ('Bill Beauchene', 41),
#  ('Zen Gesner', 41),
#  ('Brian Mone', 41),
#  ('John Indrisano', 40),
#  ('Ethan Laidlaw', 40),
#  ('Barbara Marshall', 40),
#  ('Lew Davis', 40),
#  ('Lewis Alexander', 39),
#  ('Maxwell Craig', 39),
#  ('Anthony Redondo', 39),
#  ('James Flavin', 39),
#  ('Kathryn Janssen', 39),
#  ('Tex Holden', 39),
#  ('Jan Rabson', 39),
#  ('Sherry Lynn', 39),
#  ('Larry Steers', 39),
#  ('Kay Garrett', 38),
#  ('Julie Paris', 38),
#  ('Kath Soucie', 37),
#  ('Paul Russell', 37),
#  ('Phil Bloom', 37),
#  ('Ernesto Molinari', 37),
#  ('John Ratzenberger', 37),
#  ('Loretta Russell', 37),
#  ('Florence Wix', 37),
#  ('Allan Kent', 37),
#  ('John Stroehman', 37),
#  ('Terry Mullany', 37),
#  ('Tom Leasca', 37),
#  ('Rob Moran', 37),
#  ('Gerry Judge', 36),
#  ('Lee Phelps', 36),
#  ('Danny Murphy', 36),
#  ('Jackie Flynn', 36),
#  ('Lin Shaye', 35),
#  ('Burnell Tucker', 35),
#  ('Al Roberts', 35),
#  ('Luigi Faccuito', 35),
#  ('Roy Lansford', 35),
#  ('Stanley Andrews', 35),
#  ('Docky', 35),
#  ('Edwin Rochelle', 34),
#  ('Ethelreda Leopold', 34),
#  ('Lulu Mae Bohrman', 34),
#  ('Eddie Smith', 34),
#  ('George Tracy', 34),
#  ('Buddy Roosevelt', 34),
#  ('Gino Corrado', 34),
#  ('Curt Furberg', 33),
#  ('Jimmy Dime', 33),
#  ('Peter Eastman', 33),
#  ('Chuck Hayward', 33),
#  ('Rodger Bumpass', 33),
#  ('Frank Moran', 33),
#  ('Marvin Braverman', 33),
#  ('Marshall Dancing Elk Lucas', 32),
#  ('Woody Allen', 32),
#  ('George Hilsdon', 32),
#  ('Frank Hagney', 32),
#  ('Don Ames', 32),
#  ('Eddie Kane', 32),
#  ('John Wayne', 32),
#  ('Eric Wilton', 32),
#  ('Eugene Borden', 32),
#  ('Frank Campanella', 32),
#  ('Steve Restivo', 32),
#  ('Diane Frazen', 32),
#  ('John Adams', 31),
#  ('Jane Morris', 31),
#  ('Helen Dickson', 31),
#  ('Byron Foulger', 31),
#  ('Patrick Pinney', 31),
#  ('Scott Marshall', 31),
#  ('Herbie Flynn', 31),
#  ('Steve Tyler', 31),
#  ('Daniel Greene', 31),
#  ('Brian Stuebe', 31),
#  ('Warren Tashjian', 31),
#  ('Ralph Moratz', 30),
#  ('Alfred Hitchcock', 30),
#  ('Robert Strong', 30),
#  ('King Mojave', 30),
#  ('Milton Kibbee', 30),
#  ('Dale Van Sickel', 30),
#  ('Paul King', 30),
#  ('Tracy Reiner', 30),
#  ('Jennifer Darling', 30),
#  ('Pierre Watkin', 30),
#  ('Chester Jones', 29),
#  ('Bob Simmons', 29),
#  ('George Leech', 29),
#  ('Glen Walters', 29),
#  ('Paul Kruger', 29),
#  ('Carl Sklover', 29),
#  ('Jack Stoney', 29),
#  ('Shane Rimmer', 29),
#  ('Herbert Evans', 29),
#  ('Andy Romano', 29),
#  ('Shannon Wilcox', 29),
#  ('Charles Sherlock', 28),
#  ('Mike Mazurki', 28),
#  ('Wilson Wood', 28),
#  ('Mushy Callahan', 28),
#  ('Ann Doran', 28),
#  ('Eddie Fetherston', 28),
#  ('Mona Marshall', 28),
#  ('Lois Maxwell', 27),
#  ('Pauline Chamberlain', 27),
#  ('Bunny Seaman', 27),
#  ('Joe Garcio', 27),
#  ('Harry Tenbrook', 27),
#  ('Patrick Richwood', 27),
#  ('Bill Farmer', 27),
#  ('James Stewart', 27),
#  ('Sam Ash', 27),
#  ('John Dennis', 27),
#  ('Jerry Brutsche', 27),
#  ('Frankie Avalon', 27),
#  ('Lori Sigrist', 27),
#  ('Terri Sigrist', 27),
#  ('Paul Pelletier', 27),
#  ('George Bedard', 27),
#  ('Ernie Rice', 26),
#  ('Herb Vigran', 26),
#  ('Maurice Marks', 26),
#  ('Lane Chandler', 26),
#  ('Jack Pennick', 26),
#  ('Peter Diamond', 26),
#  ('Daniel Nunez', 26),
#  ('Richard Kipling', 26),
#  ('Kelsey Jordan', 26),
#  ('Thomas Jordan', 26),
#  ('Paul Tuerpe', 25),
#  ('Fred Stroud', 25),
#  ('Spencer Chan', 25),
#  ('Harry Cording', 25),
#  ('Edmund Cobb', 25),
#  ('John George', 25),
#  ('Jim Cummings', 25),
#  ('Dick Wessel', 25),
#  ('Walter Henry', 25),
#  ('Kenny Baker', 25),
#  ('Chuck Roberson', 25),
#  ('William Demarest', 25),
#  ('Irving Bacon', 25),
#  ('Wesley Gale', 25),
#  ('James Millican', 25),
#  ('Chester Conklin', 25),
#  ('Luree Holmes', 25),
#  ('Garry Marshall', 25),
#  ('Bernard Lee', 24),
#  ('Jack Mower', 24),
#  ('Bert May', 24),
#  ('Dee Turnell', 24),
#  ('Jack Daly', 24),
#  ('Duke Green', 24),
#  ('Steve Whitmire', 24),
#  ('Dave Goelz', 24),
#  ('Harvey Keenan', 24),
#  ('Jeanne Lafayette', 24),
#  ('Torben Meyer', 24),
#  ('Edward Earle', 24),
#  ('John Ince', 24),
#  ('Jack Low', 24),
#  ('Robert Clotworthy', 24),
#  ('Ed Garner', 24),
#  ('Lucinda Crosby', 24),
#  ('John Turturro', 23),
#  ('Steve Buscemi', 23),
#  ('Steve Kahan', 23),
#  ('Aidan Harrington', 23),
#  ('Ernest Blyth', 23),
#  ('Robert Rietty', 23),
#  ('Philip Stewart', 23),
#  ('Clint Howard', 23),
#  ('Paul Herman', 23),
#  ('Ian Wolfe', 23),
#  ('Richard Elmore', 23),
#  ('Monya Andre', 23),
#  ('Cary Grant', 23),
#  ('Frank Radcliffe', 23),
#  ('Kenneth Edelson', 23),
#  ('Alberta Nelson', 23),
#  ('Annette Funicello', 23),
#  ('Harvey Lembeck', 23),
#  ('Bud Markowitz', 23),
#  ('Jeff Michalski', 23),
#  ('Preston Thomas', 23),
#  ('Cynthia Farrelly Gesner', 23),
#  ('Melinda Farrelly', 23),
#  ('Jimmy Shay', 23),
#  ('Libby Langdon', 23),
#  ('Adam Sandler', 22),
#  ('Alf Casha', 22),
#  ('Ralph Montgomery', 22),
#  ('Sayre Dearing', 22),
#  ('Charles Cirillo', 22),
#  ('Tom Smith', 22),
#  ('Lucile Sewall', 22),
#  ('Tom Coleman', 22),
#  ('John Quijada', 22),
#  ('John Doumanian', 22),
#  ('Jack Purvis', 22),
#  ('Jody McCrea', 22),
#  ('Michael Nader', 22),
#  ('Johnny Fain', 22),
#  ('Bob Harvey', 22),
#  ('Tom Hines', 22),
#  ('Hillary Matthews', 22),
#  ('Fred Machon', 21),
#  ('Gil Perkins', 21),
#  ('Sig Frohlich', 21),
#  ('Jerry Nelson', 21),
#  ('Ernie Flatt', 21),
#  ('Mary Kay Bergman', 21),
#  ('Guy Hemric', 21),
#  ('Allen Fife', 21),
#  ('Ned Wynn', 21),
#  ('Nicholas Greenbury', 21),
#  ('Andrew Greenbury', 21),
#  ('Richard Tyson', 21),
#  ('Paul McMichael', 20),
#  ('Michael Bell', 20),
#  ('Mary Ellen Trainor', 20),
#  ('Joe Pesci', 20),
#  ('Paul Weston', 20),
#  ('Reg Thomason', 20),
#  ('Tony Dante', 20),
#  ('Patrick Halpin', 20),
#  ('Eleanore Vogel', 20),
#  ('Robert Buckingham', 20),
#  ('Kathleen Freeman', 20),
#  ('Steven Brill', 20),
#  ('George Spence', 20),
#  ('George Hoagland', 20),
#  ('Chick Fowles', 20),
#  ('Edward Biby', 20),
#  ('Robert Dudley', 20),
#  ('Tony Sirico', 20),
#  ('John Tyrrell', 20),
#  ('Clint Eastwood', 19),
#  ('Robert De Niro', 19),
#  ('Mel Gibson', 19),
#  ('Nikki Van der Zyl', 19),
#  ('Manny Michael', 19),
#  ('Marianne Stone', 19),
#  ('Eric Kent', 19),
#  ('Frederick Kelsey', 19),
#  ('Harold Coyne', 19),
#  ('Peter McRobbie', 19),
#  ('Tracey Walter', 19),
#  ('Alan Hewitt', 19),
#  ('Ward Bond', 19),
#  ('Russell Meeker', 19),
#  ('John Pedrini', 19),
#  ('Anton Northpole', 19),
#  ('Ray Pourchot', 19),
#  ('Allen Covert', 19),
#  ('Harvey Parry', 19),
#  ('John Hollis', 19),
#  ('Tina Simmons', 19),
#  ('Debi Derryberry', 19),
#  ('George Holdcroft', 19),
#  ('Bobby Barber', 19),
#  ('Leonard Mudie', 19),
#  ('Ralph Volkie', 19),
#  ('Bill Raisch', 19),
#  ('Brian McConnachie', 19),
#  ('Tony Darrow', 19),
#  ('Corey Burton', 19),
#  ('Danny Mann', 19),
#  ('Mary Hughes', 19),
#  ('Salli Sachse', 19),
#  ('Patti Chandler', 19),
#  ('Linda Bent', 19),
#  ('Ronnie Dayton', 19),
#  ('Victor Travis', 19),
#  ('Roger Moore', 18),
#  ('Larry Miller', 18),
#  ('Blaine Turner', 18),
#  ('Eddie Baker', 18),
#  ('Garry Owen', 18),
#  ('Paul Ravel', 18),
#  ('Ralph Dunn', 18),
#  ('Al Hill', 18),
#  ('Mike Mahoney', 18),
#  ('Charles Coburn', 18),
#  ('Fred Fisher', 18),
#  ('Ralph Gambina', 18),
#  ('Tom Steele', 18),
#  ('Robert Greig', 18),
#  ('Henry Roquemore', 18),
#  ('Sheldon Jett', 18),
#  ('Vernon Dent', 18),
#  ('Gene Morgan', 18),
#  ('Owen Song', 18),
#  ('Damon Hines', 17),
#  ('James Oliver', 17),
#  ('Jill Goldston', 17),
#  ('Ella Ethridge', 17),
#  ('Harry Tyler', 17),
#  ('Robert Foulk', 17),
#  ('Gail Bonney', 17),
#  ('Audrey Betz', 17),
#  ('Anne Kunde', 17),
#  ('Peter Dante', 17),
#  ('Charles Irwin', 17),
#  ('Nico Stevens', 17),
#  ('Gene Hackman', 17),
#  ('George Simmons', 17),
#  ('Harrison Ford', 17),
#  ('Alf Mangan', 17),
#  ('Esther Michelson', 17),
#  ('Stanley Blystone', 17),
#  ('Don Feldstein', 17),
#  ('Spike Lee', 16),
#  ('Jay Della', 16),
#  ('Marian Collier', 16),
#  ('John Ketteringham', 16),
#  ('Ron Gregory', 16),
#  ('Emile Stemmler', 16),
#  ('Marjorie Bennett', 16),
#  ('Kermit Maynard', 16),
#  ('Robert Street', 16),
#  ('Ken Clayton', 16),
#  ('Ray Garvey', 16),
#  ('Norman Chancer', 16),
#  ('Johnny Rossi', 16),
#  ('John Clifford', 16),
#  ('Ellen Corby', 16),
#  ('Bert Spencer', 16),
#  ('Charles Soldani', 16),
#  ('Richard Alexander', 16),
#  ('Jack Regas', 16),
#  ('Jean Del Val', 16),
#  ('Jim Ward', 16),
#  ('Will Coogan', 16),
#  ('Al Pacino', 15),
#  ('Danny Glover', 15),
#  ('Walter Gotell', 15),
#  ('Jim Henson', 15),
#  ('Ron Dean', 15),
#  ('Jack Gargan', 15),
#  ('Slim Gaut', 15),
#  ('Judy Landon', 15),
#  ('Jack Montgomery', 15),
#  ('Eric Alden', 15),
#  ('Grace Lee Whitney', 15),
#  ('George Blagoi', 15),
#  ('Talia Shire', 15),
#  ('John Witherspoon', 15),
#  ('Marc McClure', 15),
#  ('Victor Argo', 15),
#  ('Arnold Roberts', 15),
#  ('David Prowse', 15),
#  ('Anthony Daniels', 15),
#  ('Lew Hooper', 15),
#  ('Paul Eiding', 15),
#  ('Peter Burroughs', 15),
#  ('William Shatner', 15),
#  ('James Doohan', 15),
#  ('Mabel Etherington', 15),
#  ('Wilson Benge', 15),
#  ('Jane Crowley', 15),
#  ('George Magrill', 15),
#  ('Neil Ross', 15),
#  ('Lori Marshall', 15),
#  ('Michael Winslow', 15),
#  ('Bubba Smith', 15),
#  ('Majel Barrett', 15),
#  ('Jimmy Conlin', 15),
#  ('Robert Warwick', 15),
#  ('Victor Potel', 15),
#  ('Rob Schneider', 15),
#  ('Rance Howard', 14),
#  ('Ebonie Smith', 14),
#  ('Darlene Love', 14),
#  ('Traci Wolfe', 14),
#  ('Jack Lemmon', 14),
#  ('Pat Ryan', 14),
#  ('Kenneth Coombs', 14),
#  ('Tony Clarkin', 14),
#  ('Chris Adcock', 14),
#  ('Philip Van Zandt', 14),
#  ('Joe Flynn', 14),
#  ('Kit Guard', 14),
#  ('Emory Parnell', 14),
#  ('Harvey Karels', 14),
#  ('Al Leong', 14),
#  ('James Earl Jones', 14),
#  ('Alec Guinness', 14),
#  ('Carrie Fisher', 14),
#  ('Mike Edmonds', 14),
#  ('Joe Ranft', 14),
#  ('Brian Henson', 14),
#  ('Brent Dunsford', 14),
#  ('Earle Hodgins', 14),
#  ('Brooks Benedict', 14),
#  ('Fritz Ford', 14),
#  ('Rod McGaughy', 14),
#  ('Frank Austin', 14),
#  ('Edward Arnold', 14),
#  ('Bess Wade', 14),
#  ('Kathryn Wilson', 14),
#  ('Iris Adrian', 14),
#  ('Howard Erskine', 14),
#  ('John Macchia', 14),
#  ('Mickey Dora', 14),
#  ('John Ashley', 14),
#  ('Leonard Nimoy', 14),
#  ('John Cleese', 14),
#  ('Charles Napier', 14),
#  ('Bill Applebaum', 14),
#  ('Lynda Goodfriend', 14),
#  ('George Gaynes', 14),
#  ('David Graf', 14),
#  ('Marion Ramsey', 14),
#  ('Arthur Hoyt', 14),
#  ('Julius Tannen', 14),
#  ('Harry Rosenthal', 14),
#  ('Walter Koenig', 14),
#  ('Nancy Farrelly', 14),
#  ('Jim Blake', 14),
#  ('Clem Franek', 14),
#  ('Kevin Smith', 14),
#  ('Jason Mewes', 14),
#  ('Walter Flanagan', 14),
#  ('Scott Mosier', 14),
#  ('Frank Vincent', 13),
#  ('Michael Imperioli', 13),
#  ('Danny Wynands', 13),
#  ('Sean Connery', 13),
#  ('Bob Raymond', 13),
#  ('Colin McKenzie', 13),
#  ('Ira Wheeler', 13),
#  ('Larry Duran', 13),
#  ('Frank Wilcox', 13),
#  ('George Golden', 13),
#  ('Wheaton Chambers', 13),
#  ('Lillian Culver', 13),
#  ('Edward Andrews', 13),
#  ('Phil Schumacher', 13),
#  ('Ed Haskett', 13),
#  ('Sol Gorss', 13),
#  ('Jack Perkins', 13),
#  ('Edward Hearn', 13),
#  ('Marcel De la Brosse', 13),
#  ('Daniel Elam', 13),
#  ('Jeff Silk', 13),
#  ('Susan Breslau', 13),
#  ('Charlotte Zucker', 13),
#  ('Peter Evans', 13),
#  ('Jack Dearlove', 13),
#  ('Emilio Estevez', 13),
#  ('Harry Strang', 13),
#  ('David Ahdar', 13),
#  ('Paul Maxey', 13),
#  ('George Lloyd', 13),
#  ('Alberto Morin', 13),
#  ('Ray Weamer', 13),
#  ('David Ogden Stiers', 13),
#  ('Donald Fullilove', 13),
#  ('Richard Steven Horvitz', 13),
#  ('Cathy Cavadini', 13),
#  ('Dorothy Tuttle', 13),
#  ('Arthur Batanides', 13),
#  ('Lance Kinsey', 13),
#  ('Steve Guttenberg', 13),
#  ('Ted Billings', 13),
#  ('Charles Chaplin', 13),
#  ('George Takei', 13),
#  ('Nichelle Nichols', 13),
#  ('DeForest Kelley', 13),
#  ('Cheech Marin', 12),
#  ('Kenneth Branagh', 12),
#  ('June Smaney', 12),
#  ('Bill Baldwin', 12),
#  ('Rocky Taylor', 12),
#  ('Fred Haggerty', 12),
#  ('Barrie Holland', 12),
#  ('Jack Armstrong', 12),
#  ('Peter Brace', 12),
#  ('Robin Burns', 12),
#  ('Joie Lee', 12),
#  ('Robert Minkoff', 12),
#  ('Clyde McLeod', 12),
#  ('Joe Brooks', 12),
#  ('Ernie Adams', 12),
#  ('Jimmie Dundee', 12),
#  ('Gary Bohn', 12),
#  ('David Thursby', 12),
#  ('Fred Graham', 12),
#  ('Denis Lawson', 12),
#  ('Mark Hamill', 12),
#  ('Peter Mayhew', 12),
#  ('Deep Roy', 12),
#  ('Kathryn Mullen', 12),
#  ('Louise Gold', 12),
#  ('Madge Blake', 12),
#  ('George Huggins', 12),
#  ('Richard Deacon', 12),
#  ('Bob Hope', 12),
#  ('Rudy Bowman', 12),
#  ('Pat West', 12),
#  ('Ken Curtis', 12),
#  ('John Breen', 12),
#  ('Burt Young', 12),
#  ('Leyland Hodgson', 12),
#  ('Miguel Nino', 12),
#  ('Gary Goetzman', 12),
#  ('Ricky Jay', 12),
#  ('Joy Rosenthal', 12),
#  ('Greg Lewis', 12),
#  ('Bonnie Aarons', 12),
#  ('Ira Glick', 12),
#  ('Sandra Taylor', 12),
#  ('Jerry James', 12),
#  ('Steven Geray', 12),
#  ('Jason Lee', 12),
#  ('Charles Lane', 12),
#  ('Fred Astaire', 12),
#  ('Blake Clark', 12),
#  ('Harvey Keitel', 11),
#  ('Phil Hawn', 11),
#  ('Larry Clardy', 11),
#  ('Joe Palma', 11),
#  ('Geoffrey Keen', 11),
#  ('Ben Affleck', 11),
#  ('Peter Sellers', 11),
#  ('Joe Phelps', 11),
#  ('Alf Joint', 11),
#  ('Tommy Lee Jones', 11),
#  ('Andreanna Veith', 11),
#  ('Tim Robbins', 11),
#  ('Joseph Mell', 11),
#  ('George Boyce', 11),
#  ('William Forrest', 11),
#  ('Mae Marsh', 11),
#  ('Marc Wilder', 11),
#  ('Harry Harvey', 11),
#  ('Liam Dunn', 11),
#  ('Brian Tochi', 11),
#  ('Margot Kidder', 11),
#  ('Wallace Shawn', 11),
#  ('Leslie Nielsen', 11),
#  ('Jack Sharp', 11),
#  ('Peter Whitman', 11),
#  ('Dorothy Adams', 11),
#  ('Bob Perry', 11),
#  ('Dewey Robinson', 11),
#  ('Richard George', 11),
#  ('Chester Clute', 11),
#  ('Eddy Chandler', 11),
#  ('Olaf Hytten', 11),
#  ('Cecil Combs', 11),
#  ('Dean Jones', 11),
#  ('Marilyn Monroe', 11),
#  ('Charles Halton', 11),
#  ('Linda Harmon', 11),
#  ('Don Rickles', 11),
#  ('Carl Weathers', 11),
#  ('Terry Gilliam', 11),
#  ('Michael Palin', 11),
#  ('Carol DePasquale', 11),
#  ('Jack Wallace', 11),
#  ('Leslie Easterbrook', 11),
#  ('Michael Dorn', 11),
#  ('Paul Lazar', 11),
#  ('Paul Newlan', 11),
#  ('Allen Soule', 11),
#  ('John Farley', 11),
#  ('Mark Miosky', 11),
#  ('Brad Blank', 11),
#  ('Zachary Weintraub', 11),
#  ('John Candy', 10),
#  ('James Ritz', 10),
#  ('Christopher Lloyd', 10),
#  ('Whoopi Goldberg', 10),
#  ('Liev Schreiber', 10),
#  ('Roger Jackson', 10),
#  ('David Arquette', 10),
#  ('Caroline Aaron', 10),
#  ('Paul Beradi', 10),
#  ('Dick Miller', 10),
#  ('Richard Briers', 10),
#  ('Dom DeLuise', 10),
#  ('Jon Lovitz', 10),
#  ('Mike Myers', 10),
#  ('Ayesha Orange', 10),
#  ('Seth Green', 10),
#  ('Mindy Sterling', 10),
#  ('Burt Bacharach', 10),
#  ('Michael York', 10),
#  ('Robert Wagner', 10),
#  ('Rob Lowe', 10),
#  ('Michael McDonald', 10),
#  ('Joe Wadham', 10),
#  ('Kirk Thornton', 10),
#  ('Greg Rhinelander', 10),
#  ('Strother Martin', 10),
#  ('Sam Bagley', 10),
#  ('Murray Alper', 10),
#  ('Frank Faylen', 10),
#  ('Dan White', 10),
#  ('Howard Culver', 10),
#  ('Elliott Reid', 10),
#  ('John Qualen', 10),
#  ('Patrick Wayne', 10),
#  ('Al Kunde', 10),
#  ('Roy Jenson', 10),
#  ('Geoffrey Lewis', 10),
#  ('Dwight Ewell', 10),
#  ('Brent Spiner', 10),
#  ('Jim Meskimen', 10),
#  ('Mike Reynell', 10),
#  ('Derek Chafer', 10),
#  ('Lee Unkrich', 10),
#  ('Gerard McSorley', 10),
#  ('Del Watson', 10),
#  ('Jim Michael', 10),
#  ('Herman Belmonte', 10),
#  ('Eric Mayne', 10),
#  ('Charles Seel', 10),
#  ('Carleton Young', 10),
#  ('Fred Perce', 10),
#  ('Sam Finn', 10),
#  ('Francine Henderson', 10),
#  ('Buddy Bryan', 10),
#  ('William Schallert', 10),
#  ('Loulette Sablon', 10),
#  ('Buster Keaton', 10),
#  ('Maurice Sonnenberg', 10),
#  ('Dan Moran', 10),
#  ('Douglas McGrath', 10),
#  ('Ramsey Faragallah', 10),
#  ('Jess Harnell', 10),
#  ('Susan Blu', 10),
#  ('Tony Burton', 10),
#  ('Kenneth Utt', 10),
#  ('Lou Evans', 10),
#  ('Patrick Stewart', 10),
#  ('Judith Baldwin', 10),
#  ('Emmett Vogan', 10),
#  ('Stephen Dowling', 10),
#  ('Shaun Weiss', 10),
#  ('Garette Ratliff Henson', 10),
#  ('Matt Doherty', 10),
#  ('Joshua Jackson', 10),
#  ('Jim Roche', 10),
#  ('Sheila Meyers', 10),
#  ('Shirley Glickman', 10),
#  ('Bill Chatham', 10),
#  ('Jean Harrison', 10),
#  ('Betty Hannon', 10),
#  ('Janet Lavis', 10),
#  ('Marietta Elliott', 10),
#  ('Jean Arthur', 10),
#  ('Eric Blore', 10),
#  ('Heinie Conklin', 10),
#  ('Benito Stefanelli', 10),
#  ('Aldo Sambrell', 10),
#  ('Antonio Molino Rojo', 10),
#  ('Lorenzo Robledo', 10),
#  ('Kevin Nealon', 10),
#  ('Bobcat Goldthwait', 10),
#  ('Tim Kazurinsky', 10),
#  ('Andrew Paris', 10),
#  ('Jonathan Loughran', 10),
#  ('Nancy Byers', 10),
#  ('Jesse Peter', 10),
#  ('Sylvester Stallone', 9),
#  ('Matthew Lillard', 9),
#  ('Courteney Cox', 9),
#  ('Lawrence Hecht', 9),
#  ('Neve Campbell', 9),
#  ('Lynn McRee', 9),
#  ('Wes Craven', 9),
#  ('Jamie Kennedy', 9),
#  ('George Lane Cooper', 9),
#  ('Matt Damon', 9),
#  ('Chris Parsons', 9),
#  ('Chris Elliott', 9),
#  ('Roddy McDowall', 9),
#  ('Jimmy Charters', 9),
#  ('Hal Galili', 9),
#  ('Jack Mandeville', 9),
#  ('Steve Blum', 9),
#  ('Giancarlo Esposito', 9),
#  ('Richard Hunt', 9),
#  ('Hayden Rorke', 9),
#  ('Charles Ferguson', 9),
#  ('Alvy Moore', 9),
#  ('John Cliff', 9),
#  ('Olan Soule', 9),
#  ('Nicky Blair', 9),
#  ('Harry Carter', 9),
#  ('Diane Keaton', 9),
#  ('Mike Starr', 9),
#  ('Dan Vadis', 9),
#  ('Shirley Anthony', 9),
#  ('Richard Nixon', 9),
#  ('David de Keyser', 9),
#  ('Christopher Malcolm', 9),
#  ('Robert Picardo', 9),
#  ('Christopher Reeve', 9),
#  ('Jackie Cooper', 9),
#  ('Robbie Barnett', 9),
#  ('Burton Zucker', 9),
#  ('David Zucker', 9),
#  ('Jeff Wright', 9),
#  ('Mel Brooks', 9),
#  ('Ira Miller', 9),
#  ('James Payne', 9),
#  ('Hugh Elton', 9),
#  ('Charles Tannen', 9),
#  ('Sid Troy', 9),
#  ('Selmer Jackson', 9),
#  ('Mark Russell', 9),
#  ('James Burke', 9),
#  ('Eddie Parker', 9),
#  ('John Zimeas', 9),
#  ('Kansas Moehring', 9),
#  ('Addison Richards', 9),
#  ('Bill Lee', 9),
#  ('Timothy Jerome', 9),
#  ('Wayne Knight', 9),
#  ('Stu Nahan', 9),
#  ('Karin Calabro', 9),
#  ('Carol Williard', 9),
#  ('Gene Barge', 9),
#  ('Christopher Kaldor', 9),
#  ('Diana Kent', 9),
#  ('Bruce Mahler', 9),
#  ('Claude Rains', 9),
#  ('Marguerite Moreau', 9),
#  ('Jack White', 9),
#  ('Elden Henson', 9),
#  ('Holmes Herbert', 9),
#  ('Earl Warren', 9),
#  ('Paul Butler', 9),
#  ('Jonathan Katz', 9),
#  ('Jordan Lage', 9),
#  ('Jerry Graff', 9),
#  ('Lionel Mark Smith', 9),
#  ('Clark Gregg', 9),
#  ('Mark Lenard', 9),
#  ('Tom Morga', 9),
#  ('Vincent Pereira', 9),
#  ('Elizabeth Jordan', 9),
#  ('Danny Nero', 8),
#  ('Allan Graf', 8),
#  ('Cheryl Howard', 8),
#  ('Michael Badalucco', 8),
#  ('Bill Henderson', 8),
#  ('Victor Tourjansky', 8),
#  ('Tim Condren', 8),
#  ('Arnold Montey', 8),
#  ('Jimmy Yuill', 8),
#  ('Ian Holm', 8),
#  ('Steven Randazzo', 8),
#  ('Dan Aykroyd', 8),
#  ('Ian Wilson', 8),
#  ('Michael McKean', 8),
#  ('John Cusack', 8),
#  ('John Ventimiglia', 8),
#  ('Peter Castellotti', 8),
#  ('Mia Farrow', 8),
#  ('Christopher Walken', 8),
#  ('Danny DeVito', 8),
#  ('Bill Nunn', 8),
#  ('Hank Jones', 8),
#  ('Bing Russell', 8),
#  ('Gregory Gaye', 8),
#  ('George Anderson', 8),
#  ('Robert Carson', 8),
#  ('James Seay', 8),
#  ('Rex Lease', 8),
#  ('Joel Marston', 8),
#  ('David Armstrong', 8),
#  ('Herbert Lytton', 8),
#  ('Ottola Nesmith', 8),
#  ('Bobby McGee', 8),
#  ('Tim Herlihy', 8),
#  ('Sondra Locke', 8),
#  ('John Hugh McKnight', 8),
#  ('Gary Wright', 8),
#  ('Len Felber', 8),
#  ('Bob Pepper', 8),
#  ('Raven Grey Eagle', 8),
#  ('Quentin Pierre', 8),
#  ('Angus MacInnes', 8),
#  ('Jeff Pidgeon', 8),
#  ('Malcolm Dixon', 8),
#  ('Charles McKeown', 8),
#  ('Warwick Davis', 8),
#  ('Mike Quinn', 8),
#  ('Caroll Spinney', 8),
#  ('George Kennedy', 8),
#  ('Al Ferguson', 8),
#  ('Anna Lee', 8),
#  ('Abdullah Abbas', 8),
#  ('Cyril Delevanti', 8),
#  ('Jean Ransome', 8),
#  ('Herman Boden', 8),
#  ('Jack Shea', 8),
#  ('Caryl Lincoln', 8),
#  ('Elvis Presley', 8),
#  ('Arthur Dulac', 8),
#  ('Bob Folkerson', 8),
#  ('Francis McDonald', 8),
#  ...]

# %%
list(bipartite.maximum_matching(G, partsActor[-2]))
# Out:
# ['Brett Rice',
#  'Marc Macaulay',
#  'Richard Fitzpatrick',
#  'Al Quinn',
#  'Antoni Corone',
#  'Deborah Smith Ford',
#  'Johnathan Hodges',
#  'Afemo Omilami',
#  'Kitty Kavey',
#  'Orlando Delbert',
#  'Trish Dempsey',
#  'David Dwyer',
#  'Out of Sight',
#  'Just Cause',
#  'Rocky V',
#  'The War',
#  'Big Trouble',
#  'Fair Game',
#  'Up Close & Personal',
#  'The Perez Family',
#  'Analyze This',
#  'Gordy',
#  'Two If by Sea',
#  'Fluke']

# %%
partsActor[-1]
# Out:
# ['Kenneth Branagh',
#  'Michael Maloney',
#  'Kenneth W Caravan',
#  'Helena Bonham Carter',
#  'Richard Briers',
#  'Edward Jewesbury',
#  'Jimmy Yuill',
#  'Richard Clifford',
#  'Emma Thompson',
#  'Brian Blessed',
#  'Ian Holm',
#  'Patrick Doyle']

# %%
genrelist = nx.get_node_attributes(G, 'Genres')

# %%
com = partsMovie[6]
genreAtt = G.nodes(data='Genres')
for movie in com:
    print(f'{movie:<40}{genreAtt[movie][0]}')
# Out:
# Final Fantasy: The Spirits Within       Adventure
# Casual Sex?                             Comedy
# Gross Anatomy                           Comedy
# The Crow                                Fantasy
# Oliver & Company                        Animation
# Men at Work                             Comedy
# 黑侠                                      Action
# Some Kind of Wonderful                  Drama
# Dinosaur                                Animation
# もののけ姫                                   Adventure
# The Lion King                           Family
# Lilo & Stitch                           Animation
# Jaws: The Revenge                       Adventure
# The Fabulous Baker Boys                 Music
# Amazon Women on the Moon                Comedy
# Babe: Pig in the City                   Adventure
# Small Soldiers                          Comedy
# Toy Story                               Animation
# The Prince of Egypt                     Adventure
# Eight Crazy Nights                      Comedy
# The Iron Giant                          Adventure
# 千と千尋の神隠し                                Fantasy
# Treasure Planet                         Adventure
# The Hunchback of Notre Dame             Drama
# Anastasia                               Animation
# Beauty and the Beast                    Romance
# The Road to El Dorado                   Adventure
# Quest for Camelot                       Fantasy
# Theodore Rex                            Fantasy
# Toy Story 2                             Animation
# Hercules                                Animation
# Tarzan                                  Adventure
# We're Back! A Dinosaur's Story          Animation
# Spirit: Stallion of the Cimarron        Western
# An American Tail: Fievel Goes West      Adventure
# Monsters, Inc.                          Animation
# Osmosis Jones                           Adventure
# A Bug's Life                            Adventure
# The Little Mermaid                      Animation
# A Goofy Movie                           Romance
# Jimmy Neutron: Boy Genius               Action
# Mulan                                   Animation
# Space Jam                               Animation
# Ice Age                                 Animation
# The Emperor's New Groove                Adventure
# Cats Don't Dance                        Animation
# となりのトトロ                                 Fantasy
# Who Framed Roger Rabbit                 Fantasy
# The Rescuers Down Under                 Adventure
# The Transformers: The Movie             Animation
# Little Nemo: Adventures In Slumberland  Adventure
# Bio-Dome                                Comedy
# Moulin Rouge!                           Drama
# Muriel's Wedding                        Drama
# Oscar and Lucinda                       Drama
# Fatal Attraction                        Romance
# The Pagemaster                          Fantasy
# Aladdin and the King of Thieves         Adventure
# The Powerpuff Girls Movie               Animation
# Return to Never Land                    Adventure
# アキラ                                     Science Fiction
# The Rugrats Movie                       Animation
# Rugrats in Paris: The Movie             Adventure
# Recess: School's Out                    Science Fiction
# Innerspace                              Action
# The Howling                             Drama
# Gremlins 2: The New Batch               Comedy
# The 'Burbs                              Comedy
# Babe                                    Fantasy
# Runaway                                 Thriller
# Metropolis                              Animation
# The Return of Jafar                     Family
