# %%
forceatlas2 = ForceAtlas2(
                        # Behavior alternatives
                        outboundAttractionDistribution=True,  # Dissuade hubs
                        linLogMode=False,  # NOT IMPLEMENTED
                        adjustSizes=False,  # Prevent overlap (NOT IMPLEMENTED)
                        edgeWeightInfluence=1.0,

                        # Performance
                        jitterTolerance=1.0,  # Tolerance
                        barnesHutOptimize=True,
                        barnesHutTheta=1.0,
                        multiThreaded=False,  # NOT IMPLEMENTED

                        # Tuning
                        scalingRatio=2,
                        strongGravityMode=False,
                        gravity=1.5,

                        # Log
                        verbose=True)

# %% [markdown]
# # **Reading in the data**

# %%
import pandas as pd
import numpy as np
import re
import networkx as nx
import matplotlib.pyplot as plt
from fa2 import ForceAtlas2
import community
import itertools
import networkx.algorithms.community as nx_comm
from networkx.algorithms import bipartite
import re
import csv
from fa2 import ForceAtlas2
import community


folder = "../Movie Dataframe with Ratings/"
df1 = pd.read_pickle(folder+"networkData1.pkl")
df2 = pd.read_pickle(folder+"networkData2.pkl")
df3 = pd.read_pickle(folder+"networkData3.pkl")

frames = [df1, df2, df3]
moviesDf = pd.concat(frames, axis=0, ignore_index=True)

# %%
actor_column = list(moviesDf["Actors"].to_numpy())
actors = [actor for cast in actor_column for actor in cast]
duplicates = set(actors) & set(moviesDf["MovieTitle"].to_numpy())
duplicates

# Removing movies where an Actor is called the same
moviesDf.drop(moviesDf[moviesDf['MovieTitle'].isin(duplicates)].index, inplace = True)

# %% [markdown]
# **Extracting relevant columns**

# %%
genres = (moviesDf['Genres'].to_numpy())
rating_column = moviesDf['Rating'].to_numpy()
genre_column = [re.findall(r"'name': '(.*?)'}", s) for s in genres]
title_column = moviesDf["MovieTitle"].to_numpy()
actor_column = list(moviesDf["Actors"].to_numpy())


#Only using 5 actors
#actor_column5 = []
#for actors in (actor_column):
#    actor_column5.append(actors[:5])
#actor_column = actor_column5
    
actorsDistinct = [*set([actor for cast in actor_column for actor in cast])]

# %%
for i,genre in enumerate(genre_column):
    try:
        genre[0]
    except:
        genre_column[i] = ['No genre']

# %% [markdown]
# # Creating the graph

# %% [markdown]
# **Generating the bipartite network of Actors and Movies**

# %%
G = nx.Graph()

#G.add_nodes_from(title_column, bipartite=0)
for i, title in enumerate((title_column)):
    G.add_node(title, bipartite=0, Genre = genre_column[i][0])
    
G.add_nodes_from(actorsDistinct, bipartite=1)


for i, movie in enumerate(title_column):
    # Adding links between each movie and its actors
    G.add_edges_from(list(zip(itertools.repeat(movie), actor_column[i])))

# %%
bipartite.is_bipartite(G)
# Out:
# True

# %% [markdown]
# **Basic stats**

# %%
print(f'Nodes: {G.number_of_nodes()}')
print(f'Edges: {G.number_of_edges()}\n')
# Out:
# Nodes: 137704
# Edges: 255020

# %% [markdown]
# **Extracting the projected Actor Network and the Movie Network from the biparite graph**

# %%
actorNodes = {n for n, d in G.nodes(data=True) if d["bipartite"] == 1}
movieNodes = {n for n, d in G.nodes(data=True) if d["bipartite"] == 0}

actorNetwork = bipartite.weighted_projected_graph(G, actorNodes, ratio = False)
movieNetwork = bipartite.weighted_projected_graph(G, movieNodes, ratio = False)

# %%
print(f'Actor network stats')
print(f'Nodes: {actorNetwork.number_of_nodes()}')
print(f'Edges: {actorNetwork.number_of_edges()}\n')

print(f'Movie network stats')
print(f'Nodes: {movieNetwork.number_of_nodes()}')
print(f'Edges: {movieNetwork.number_of_edges()}\n')
# Out:
# Actor network stats
# Nodes: 131746
# Edges: 8086719
#
# Movie network stats
# Nodes: 5958
# Edges: 468645

# %% [markdown]
# # Testing stuff

# %%
movieEdges = sorted(nx.get_edge_attributes(movieNetwork, 'weight').items(), key=lambda x: x[1], reverse = True)
actorEdges = sorted(nx.get_edge_attributes(actorNetwork, 'weight').items(), key=lambda x: x[1], reverse = True)

# %%
movieDegrees = sorted(movieNetwork.degree(weight='weight'), key=lambda x: x[1], reverse=True)
actorDegrees = sorted(actorNetwork.degree(weight='weight'), key=lambda x: x[1], reverse=True)

movieDegrees
# Out:
# [('Around the World in Eighty Days', 3528),
#  ('Calamity Jane', 1677),
#  ('Mighty Joe Young', 1664),
#  ('4 for Texas', 1504),
#  ('Gentlemen Prefer Blondes', 1497),
#  ('My Man Godfrey', 1490),
#  ('The Band Wagon', 1437),
#  ('Giant', 1419),
#  ('Designing Woman', 1413),
#  ('Titanic', 1326),
#  ('Witness for the Prosecution', 1321),
#  ('North by Northwest', 1299),
#  ('Pocketful of Miracles', 1297),
#  ("Ocean's Eleven", 1288),
#  ('The Manchurian Candidate', 1286),
#  ('The Great Race', 1279),
#  ('The Man Who Shot Liberty Valance', 1242),
#  ('The Bad and the Beautiful', 1224),
#  ('Inherit the Wind', 1200),
#  ('An Affair to Remember', 1191),
#  ('Monsieur Verdoux', 1171),
#  ('White Christmas', 1169),
#  ('A Place in the Sun', 1152),
#  ('The Player', 1145),
#  ('How to Murder Your Wife', 1124),
#  ('Our Man Flint', 1087),
#  ('A Night to Remember', 1082),
#  ('The Computer Wore Tennis Shoes', 1079),
#  ('The Greatest Show on Earth', 1076),
#  ('Sabrina', 1041),
#  ('Auntie Mame', 1040),
#  ('Guys and Dolls', 1025),
#  ('Independence Day', 1021),
#  ('Mr. Smith Goes to Washington', 1014),
#  ('Blazing Saddles', 1009),
#  ('The War of the Worlds', 1007),
#  ('When Worlds Collide', 991),
#  ("Singin' in the Rain", 991),
#  ('Some Like It Hot', 990),
#  ('Hamlet', 985),
#  ('Nixon', 971),
#  ('Gypsy', 967),
#  ('Funny Face', 967),
#  ('Pal Joey', 939),
#  ('Lured', 939),
#  ('Citizen Kane', 931),
#  ("You Can't Take It With You", 922),
#  ('Funny Girl', 920),
#  ('Celebrity', 909),
#  ('Houseboat', 907),
#  ('JFK', 906),
#  ('Friendly Persuasion', 905),
#  ('Sweet Smell of Success', 905),
#  ('Torn Curtain', 904),
#  ('The Perils of Pauline', 895),
#  ("There's No Business Like Show Business", 894),
#  ('The Fan', 884),
#  ('To Catch a Thief', 876),
#  ('The Thrill of It All', 871),
#  ('Meet John Doe', 869),
#  ('Harry and Walter Go To New York', 868),
#  ('Written on the Wind', 865),
#  ('Spartacus', 855),
#  ('Man on the Moon', 851),
#  ('I Want to Live!', 851),
#  ('The Harder They Fall', 848),
#  ('The Day the Earth Stood Still', 846),
#  ('Born on the Fourth of July', 842),
#  ('Elmer Gantry', 840),
#  ('Gilda', 837),
#  ('Limelight', 833),
#  ('Young Frankenstein', 833),
#  ('Father of the Bride', 831),
#  ('The Barefoot Executive', 830),
#  ('The Nutty Professor', 827),
#  ('My Fair Lady', 824),
#  ('Superman II', 820),
#  ('Amazon Women on the Moon', 818),
#  ('Apollo 13', 815),
#  ('Saboteur', 812),
#  ('Magnolia', 801),
#  ("It's a Wonderful Life", 799),
#  ('The Godfather: Part II', 787),
#  ("All the King's Men", 785),
#  ('Miracle on 34th Street', 779),
#  ('The Happiest Millionaire', 776),
#  ('Gus', 775),
#  ('The Towering Inferno', 774),
#  ('Casino Royale', 774),
#  ('Mars Attacks!', 772),
#  ('Airplane II: The Sequel', 769),
#  ('The Lady Eve', 768),
#  ('The Great Dictator', 767),
#  ('Pearl Harbor', 766),
#  ('And the Band Played On', 766),
#  ('Armageddon', 765),
#  ('Bulworth', 761),
#  ('Edtv', 761),
#  ('Royal Wedding', 757),
#  ('The Kid Stays in the Picture', 756),
#  ('The Big Sleep', 754),
#  ('Strangers on a Train', 750),
#  ('Lethal Weapon 4', 746),
#  ('Primary Colors', 746),
#  ('Cradle Will Rock', 743),
#  ('Return of the Jedi', 740),
#  ('G.I. Blues', 737),
#  ('Enemy of the State', 737),
#  ('Doctor Dolittle', 737),
#  ('GoodFellas', 731),
#  ('Cape Fear', 731),
#  ('Ragtime', 729),
#  ('The Naked Gun 33⅓: The Final Insult', 727),
#  ('The Eddy Duchin Story', 725),
#  ('Son of Flubber', 724),
#  ("It's a Mad, Mad, Mad, Mad World", 723),
#  ('Thirteen Days', 721),
#  ('Con Air', 721),
#  ('To Kill a Mockingbird', 718),
#  ('Osmosis Jones', 715),
#  ('Cat Ballou', 711),
#  ('The Best Years of Our Lives', 708),
#  ('Dick Tracy', 706),
#  ('The Paleface', 705),
#  ('Mulan', 703),
#  ('Ali', 703),
#  ('Superman', 702),
#  ('The Man Who Knew Too Much', 701),
#  ('The Absent-Minded Professor', 699),
#  ('The Benny Goodman Story', 698),
#  ('Little Nicky', 698),
#  ('Chinatown', 694),
#  ('Mary Poppins', 692),
#  ('The Grapes of Wrath', 686),
#  ('Heat', 681),
#  ('The Adventures of Rocky & Bullwinkle', 676),
#  ('The Pride of the Yankees', 676),
#  ('Seven Days in May', 674),
#  ('Hercules', 672),
#  ('Forrest Gump', 667),
#  ('Ed Wood', 664),
#  ('Frankie and Johnny', 663),
#  ('Voyage of the Damned', 663),
#  ('Austin Powers in Goldmember', 662),
#  ('Boogie Nights', 662),
#  ('Toy Story 2', 661),
#  ('Body and Soul', 659),
#  ('The Poseidon Adventure', 658),
#  ('Catch Me If You Can', 658),
#  ('The Bonfire of the Vanities', 658),
#  ('Laura', 657),
#  ('Space Jam', 657),
#  ('Last Action Hero', 657),
#  ('The Sting', 654),
#  ('East of Eden', 654),
#  ('Godzilla', 653),
#  ('The Unsinkable Molly Brown', 653),
#  ('Top Secret!', 653),
#  ('The Paper', 650),
#  ('Cop Land', 648),
#  ('History of the World: Part I', 647),
#  ('Shadows and Fog', 646),
#  ('That Thing You Do!', 646),
#  ('Irma la Douce', 644),
#  ("They Shoot Horses, Don't They?", 642),
#  ('Escape from the Planet of the Apes', 642),
#  ('The Glass Bottom Boat', 641),
#  ('Gone with the Wind', 636),
#  ('L.A. Confidential', 636),
#  ('The Dirty Dozen', 635),
#  ('The Cotton Club', 633),
#  ('Deconstructing Harry', 632),
#  ('Batman', 632),
#  ('Ghosts of Mississippi', 631),
#  ('Rat Race', 631),
#  ('Imitation of Life', 630),
#  ('Angel on My Shoulder', 629),
#  ('The Hudsucker Proxy', 628),
#  ('I Love Trouble', 625),
#  ('Reds', 625),
#  ('Pillow Talk', 625),
#  ('A Civil Action', 622),
#  ('The Adventures of Robin Hood', 621),
#  ('The Sound of Music', 621),
#  ('Planet of the Apes', 620),
#  ('Anastasia', 620),
#  ('Roustabout', 619),
#  ('Foreign Correspondent', 618),
#  ("She's Having a Baby", 617),
#  ('The Blues Brothers', 616),
#  ('All About Eve', 616),
#  ('The Hunchback of Notre Dame', 614),
#  ('The Palm Beach Story', 614),
#  ('Fear and Loathing in Las Vegas', 614),
#  ('The Shaggy D.A.', 612),
#  ('Gone in Sixty Seconds', 608),
#  ('The Inspector General', 607),
#  ('Shampoo', 605),
#  ('Airport', 603),
#  ('Casino', 601),
#  ('Dead Reckoning', 601),
#  ('Traffic', 600),
#  ('Contact', 598),
#  ('Clear and Present Danger', 595),
#  ('Johnny Dangerously', 594),
#  ('The Way We Were', 594),
#  ('Dear God', 594),
#  ('Maverick', 593),
#  ('Natural Born Killers', 593),
#  ("The Man Who Wasn't There", 592),
#  ('New York Stories', 592),
#  ('The Associate', 592),
#  ('Brother Can You Spare A Dime', 590),
#  ('Austin Powers: The Spy Who Shagged Me', 588),
#  ('Postcards from the Edge', 587),
#  ('Quest for Camelot', 586),
#  ('Quiz Show', 586),
#  ('Get Shorty', 586),
#  ('Who Framed Roger Rabbit', 584),
#  ('Monsters, Inc.', 584),
#  ('In & Out', 582),
#  ('On Our Merry Way', 581),
#  ('Private Parts', 581),
#  ('Up Close & Personal', 580),
#  ('Hangmen Also Die!', 579),
#  ('The Paradine Case', 578),
#  ('Volcano', 576),
#  ('Radio Days', 575),
#  ("Brewster's Millions", 575),
#  ("A Bug's Life", 575),
#  ('Mr. & Mrs. Smith', 573),
#  ('Herbie Rides Again', 571),
#  ('Young Doctors in Love', 571),
#  ('Force of Evil', 571),
#  ('Minority Report', 570),
#  ("The Devil's Advocate", 569),
#  ('Shaft', 568),
#  ('In Old California', 567),
#  ('Babes in Toyland', 566),
#  ('The Apartment', 565),
#  ('Gandhi', 563),
#  ('North', 562),
#  ('Impact', 562),
#  ('Casablanca', 562),
#  ('Scrooged', 562),
#  ('The Man from Down Under', 561),
#  ('River of No Return', 561),
#  ('The Empire Strikes Back', 561),
#  ('Eraser', 560),
#  ('The Last Time I Saw Paris', 560),
#  ('Deep Impact', 556),
#  ('Them!', 556),
#  ('Sleepers', 554),
#  ('Planes, Trains and Automobiles', 554),
#  ('Trading Places', 553),
#  ('Dr. Dolittle 2', 553),
#  ('My Fellow Americans', 552),
#  ('Rio Bravo', 552),
#  ("National Lampoon's Loaded Weapon 1", 552),
#  ("Blackbeard's Ghost", 551),
#  ('Night Falls on Manhattan', 551),
#  ("A Hard Day's Night", 547),
#  ('Bad Company', 547),
#  ('Executive Decision', 546),
#  ('Billy Jack Goes to Washington', 545),
#  ('The Greatest Story Ever Told', 545),
#  ("Hang 'em High", 544),
#  ('Wag the Dog', 544),
#  ('Gremlins 2: The New Batch', 544),
#  ('The Shadow', 544),
#  ('The Fighting Seabees', 543),
#  ('Diamonds Are Forever', 543),
#  ('Mildred Pierce', 542),
#  ('Ghostbusters', 542),
#  ('Meteor', 541),
#  ('Wild in the Country', 541),
#  ('Town & Country', 540),
#  ('The Big Bus', 540),
#  ('Small Soldiers', 540),
#  ('Bob Roberts', 537),
#  ('A.I. Artificial Intelligence', 536),
#  ('Any Given Sunday', 536),
#  ('One-Eyed Jacks', 535),
#  ('What Planet Are You From?', 535),
#  ('Sunset Boulevard', 534),
#  ('Die Hard', 534),
#  ('Looking for Richard', 533),
#  ('Spider-Man', 533),
#  ('Batman & Robin', 532),
#  ('The Prince of Egypt', 532),
#  ('Summer of Sam', 531),
#  ('Money Train', 530),
#  ('The Elephant Man', 529),
#  ('The Birdcage', 527),
#  ("Fathers' Day", 526),
#  ('Mrs. Parker and the Vicious Circle', 525),
#  ('True Crime', 525),
#  ('Days of Wine and Roses', 525),
#  ('Men in Black', 523),
#  ('Dave', 522),
#  ("Breakfast at Tiffany's", 522),
#  ('High Noon', 521),
#  ('The Rock', 521),
#  ('The Longest Day', 520),
#  ('The American President', 519),
#  ('Psycho', 519),
#  ('Tora! Tora! Tora!', 518),
#  ('An American in Paris', 518),
#  ('Hero', 517),
#  ('Spaceballs', 517),
#  ('Midway', 517),
#  ('The Incredible Mr. Limpet', 516),
#  ('True Romance', 516),
#  ('48 Hrs.', 516),
#  ('In the Line of Fire', 516),
#  ('The Majestic', 515),
#  ('Wall Street', 515),
#  ('Road to Utopia', 514),
#  ('Airplane!', 514),
#  ('Speechless', 514),
#  ('The Swarm', 514),
#  ('The Insider', 513),
#  ('Tarzan', 512),
#  ('Any Which Way You Can', 512),
#  ('Batman Forever', 512),
#  ("Jumpin' Jack Flash", 510),
#  ('Almost Famous', 510),
#  ('Topaz', 510),
#  ('Notorious', 509),
#  ('Santa Fe Trail', 507),
#  ('Vertigo', 504),
#  ('Eight Crazy Nights', 504),
#  ('Clockers', 503),
#  ('Fight Club', 502),
#  ('The Sum of All Fears', 501),
#  ('The Horse Soldiers', 501),
#  ('Star Wars', 500),
#  ('Radioland Murders', 500),
#  ('Ghostbusters II', 499),
#  ('Splash', 499),
#  ('Air Force One', 499),
#  ("I'll Never Forget What's'isname", 498),
#  ('True Grit', 498),
#  ("Carlito's Way", 498),
#  ('Innerspace', 495),
#  ('The Graduate', 494),
#  ('Armed and Dangerous', 494),
#  ('Starship Troopers', 494),
#  ('Desperately Seeking Susan', 494),
#  ('Batman Returns', 493),
#  ('The Cheap Detective', 491),
#  ('Morons from Outer Space', 491),
#  ('City Hall', 491),
#  ('Brannigan', 491),
#  ('Earth vs. the Flying Saucers', 490),
#  ('Running Scared', 490),
#  ('The Other Sister', 490),
#  ('Airport 1975', 489),
#  ('Pretty Woman', 489),
#  ('Jungle Fever', 488),
#  ('Pulp Fiction', 488),
#  ('Zoolander', 488),
#  ('Jingle All the Way', 487),
#  ('The Iron Giant', 487),
#  ('The Out-of-Towners', 487),
#  ('Wild Bill', 486),
#  ('Speed', 486),
#  ('The Replacements', 486),
#  ('Dodsworth', 486),
#  ('Fletch', 485),
#  ('Raiders of the Lost Ark', 485),
#  ('No Way Out', 484),
#  ("Who's That Girl", 483),
#  ('Billy Bathgate', 483),
#  ('California Suite', 481),
#  ('The Rocketeer', 480),
#  ('Beverly Hills Cop III', 478),
#  ("Gentleman's Agreement", 477),
#  ('Cannonball Run II', 477),
#  ('Lonely Are the Brave', 476),
#  ('Flash Gordon', 476),
#  ('Die Hard 2', 476),
#  ('For the Boys', 475),
#  ('X: The Man with the X-Ray Eyes', 475),
#  ('Ransom', 474),
#  ('The First Wives Club', 473),
#  ('American Gigolo', 473),
#  ('Short Cuts', 472),
#  ('Mickey Blue Eyes', 472),
#  ('Coneheads', 472),
#  ('Donnie Brasco', 471),
#  ('Play It to the Bone', 471),
#  ('Beaches', 471),
#  ('The Jackal', 470),
#  ('Ninotchka', 470),
#  ('The Spy Who Loved Me', 469),
#  ('Jerry Maguire', 469),
#  ('Showtime', 469),
#  ('The Thomas Crown Affair', 469),
#  ('Philadelphia', 468),
#  ('Tango & Cash', 468),
#  ('The Siege', 468),
#  ('The Cable Guy', 467),
#  ('Gloria', 467),
#  ('Beverly Hills Cop II', 467),
#  ('Me, Myself & Irene', 466),
#  ('Amistad', 466),
#  ('Eight Men Out', 466),
#  ('Gremlins', 465),
#  ('The Godfather', 465),
#  ('Gods and Generals', 463),
#  ('How to Marry a Millionaire', 463),
#  ("Charlie's Angels", 463),
#  ('Annie Hall', 463),
#  ('Voyage to the Bottom of the Sea', 461),
#  ('Once Upon a Time in America', 459),
#  ('The Green Mile', 459),
#  ('Bullets Over Broadway', 458),
#  ('Jay and Silent Bob Strike Back', 458),
#  ('The Naked Gun: From the Files of Police Squad!', 458),
#  ('Anchors Aweigh', 458),
#  ('Mr. Deeds', 456),
#  ('Spy Hard', 456),
#  ('Heartburn', 456),
#  ('The Royal Tenenbaums', 455),
#  ('The Right Stuff', 455),
#  ('Men in Black II', 455),
#  ('The Package', 455),
#  ('Working Girl', 454),
#  ('The Muppet Movie', 454),
#  ('Addams Family Values', 453),
#  ('Red Heat', 453),
#  ('The Million Dollar Duck', 453),
#  ('The Asphalt Jungle', 453),
#  ('Joe Dirt', 453),
#  ('Superman III', 452),
#  ('It Could Happen to You', 451),
#  ('Brazil', 451),
#  ('Crimson Tide', 450),
#  ('Random Hearts', 450),
#  ('Mad City', 450),
#  ('Extreme Measures', 450),
#  ('The Red Badge of Courage', 450),
#  ('The Horse in the Gray Flannel Suit', 449),
#  ('I Woke Up Early The Day I Died', 449),
#  ("Wayne's World 2", 449),
#  ('The Hurricane', 448),
#  ('Loving You', 448),
#  ("Donovan's Reef", 448),
#  ('To Be or Not to Be', 447),
#  ('Red Dragon', 446),
#  ('The Country Bears', 446),
#  ('Awakenings', 446),
#  ('Theodore Rex', 445),
#  ('Virtuosity', 445),
#  ('How Green Was My Valley', 444),
#  ('Raging Bull', 444),
#  ('Honky Tonk Freeway', 443),
#  ("Heaven's Gate", 443),
#  ('Love Affair', 442),
#  ("There's Something About Mary", 442),
#  ('The Young Lions', 442),
#  ('Rounders', 442),
#  ('The Firm', 441),
#  ('Austin Powers: International Man of Mystery', 441),
#  ('How the Grinch Stole Christmas', 441),
#  ('Mighty Aphrodite', 441),
#  ('Frenzy', 440),
#  ('Dark Command', 440),
#  ('My Blue Heaven', 440),
#  ('Marnie', 439),
#  ('Runaway Bride', 439),
#  ('The Little Mermaid', 439),
#  ('The Real Blonde', 438),
#  ('The Godfather: Part III', 438),
#  ('Oh, God!', 438),
#  ('Blow', 437),
#  ('From Russia with Love', 437),
#  ('Demetrius and the Gladiators', 437),
#  ('I Am Sam', 437),
#  ("I'm All Right Jack", 436),
#  ("Sullivan's Travels", 436),
#  ('The Love Bug', 436),
#  ('Fear Strikes Out', 435),
#  ('The Fugitive', 435),
#  ('Get Bruce!', 435),
#  ('Superman IV: The Quest for Peace', 434),
#  ('King Creole', 434),
#  ('Death to Smoochy', 434),
#  ('Girl 6', 434),
#  ('Stripes', 433),
#  ('One Fine Day', 433),
#  ("We're Back! A Dinosaur's Story", 433),
#  ('Being John Malkovich', 433),
#  ('The Mummy', 433),
#  ('Frankenstein', 432),
#  ('BASEketball', 432),
#  ('Kingpin', 431),
#  ('Collateral Damage', 431),
#  ('Now, Voyager', 430),
#  ('The Hunt for Red October', 430),
#  ('Britannia Hospital', 429),
#  ('Evolution', 429),
#  ('Beautiful', 428),
#  ('The Talk of the Town', 427),
#  ('The Silence of the Lambs', 427),
#  ('Tune in Tomorrow...', 427),
#  ('Heartbreakers', 427),
#  ('The Big Lebowski', 427),
#  ('Road to Singapore', 426),
#  ('A Time to Kill', 425),
#  ("Pee-wee's Big Adventure", 425),
#  ('Cadillac Man', 425),
#  ('Monkeybone', 424),
#  ('Rollerball', 424),
#  ('American Pie 2', 424),
#  ('Stardust Memories', 424),
#  ('Born Yesterday', 424),
#  ('Species', 423),
#  ('Falling Down', 423),
#  ('Rising Sun', 423),
#  ('The Road to El Dorado', 422),
#  ('The Rugrats Movie', 422),
#  ('Total Recall', 421),
#  ('Treasure Planet', 421),
#  ('Married to the Mob', 421),
#  ('Pollyanna', 421),
#  ('Die Hard: With a Vengeance', 420),
#  ('Scarlet Street', 420),
#  ('Star Trek III: The Search for Spock', 420),
#  ('Conspiracy Theory', 420),
#  ('Everyone Says I Love You', 419),
#  ('The Great White Hype', 419),
#  ('Little Women', 419),
#  ('Exit to Eden', 418),
#  ('The Thin Red Line', 418),
#  ('Beauty and the Beast', 418),
#  ('Seconds', 418),
#  ('54', 417),
#  ('Gettysburg', 417),
#  ('The Purple Rose of Cairo', 417),
#  ('Coyote Ugly', 417),
#  ('The Bodyguard', 416),
#  ('Nothing in Common', 416),
#  ('Cats & Dogs', 416),
#  ('The Pope of Greenwich Village', 415),
#  ('Inspector Gadget', 415),
#  ('The Impostors', 413),
#  ('Bringing Out the Dead', 413),
#  ('Demolition Man', 413),
#  ('Patch Adams', 413),
#  ('Beverly Hills Cop', 412),
#  ('Under Siege 2: Dark Territory', 411),
#  ('Mrs. Miniver', 411),
#  ('20,000 Leagues Under the Sea', 411),
#  ('Pursued', 410),
#  ('Sister Act 2: Back in the Habit', 410),
#  ('The Champ', 410),
#  ("Things to Do in Denver When You're Dead", 409),
#  ('The Peacemaker', 409),
#  ('Sneakers', 409),
#  ('Police Academy 2: Their First Assignment', 409),
#  ('Sweet Charity', 408),
#  ('Herbie Goes Bananas', 408),
#  ('Liar Liar', 407),
#  ('Hot Shots! Part Deux', 407),
#  ("Krippendorf's Tribe", 407),
#  ('Stuart Saves His Family', 406),
#  ('Star Trek VI: The Undiscovered Country', 406),
#  ('Basquiat', 406),
#  ('My Favorite Year', 405),
#  ('Lethal Weapon 2', 405),
#  ('The Adventures of Buckaroo Banzai Across the 8th Dimension', 404),
#  ('In Like Flint', 404),
#  ('The Grifters', 404),
#  ('True Confessions', 404),
#  ("Don't Bother to Knock", 404),
#  ('Every Which Way But Loose', 403),
#  ('Bound by Honor', 402),
#  ('Back to the Future', 402),
#  ('King of New York', 401),
#  ('Serpico', 401),
#  ('Newsies', 401),
#  ('Hannibal', 401),
#  ('The Negotiator', 401),
#  ('Babe: Pig in the City', 400),
#  ('Sleepless in Seattle', 399),
#  ('Midnight in the Garden of Good and Evil', 399),
#  ('Enigma', 399),
#  ('I Shot Andy Warhol', 398),
#  ('Lulu on the Bridge', 398),
#  ('The Great Ziegfeld', 398),
#  ('Heaven Can Wait', 398),
#  ('Outbreak', 398),
#  ('Mississippi Burning', 398),
#  ('Sister Act', 398),
#  ('The Independent', 397),
#  ('Young Guns II', 397),
#  ('Last Exit to Brooklyn', 397),
#  ('Holiday Inn', 397),
#  ('Mercury Rising', 397),
#  ('MouseHunt', 396),
#  ("Airport '77", 396),
#  ("Jane Austen's Mafia!", 396),
#  ('The Lion King', 396),
#  ('The Big Trees', 396),
#  ('Big Business', 396),
#  ('Life Stinks', 396),
#  ('Lethal Weapon', 395),
#  ('Holy Man', 395),
#  ('Forget Paris', 395),
#  ('Duel in the Sun', 394),
#  ('Steal Big Steal Little', 393),
#  ('Dial M for Murder', 393),
#  ('Rush Hour', 393),
#  ('Se7en', 392),
#  ('Silkwood', 392),
#  ('Paint Your Wagon', 392),
#  ('Caddyshack II', 391),
#  ('Conquest of the Planet of the Apes', 391),
#  ('Pinocchio', 391),
#  ('Lethal Weapon 3', 391),
#  ('Airheads', 391),
#  ('The Princess Diaries', 391),
#  ('Gun Shy', 391),
#  ('Great Expectations', 391),
#  ('Abbott and Costello Meet the Mummy', 391),
#  ('The Two Jakes', 390),
#  ('Saving Private Ryan', 390),
#  ('Blast from the Past', 390),
#  ('Fallen', 390),
#  ('A Star Is Born', 390),
#  ('Three Fugitives', 389),
#  ('Scream 2', 389),
#  ('The Best Little Whorehouse in Texas', 388),
#  ('Hook', 388),
#  ('An American Tail: Fievel Goes West', 388),
#  ('An American Werewolf in London', 388),
#  ('Ready to Rumble', 388),
#  ('Apocalypse Now', 387),
#  ('The Truman Show', 387),
#  ('Oliver & Company', 387),
#  ('Nurse Betty', 387),
#  ('Mission: Impossible', 387),
#  ('Sunset', 387),
#  ('Twins', 387),
#  ('Jimmy Neutron: Boy Genius', 387),
#  ('Crimes and Misdemeanors', 387),
#  ('The Shining', 386),
#  ('The Juror', 386),
#  ('The Eagle Has Landed', 386),
#  ('G.I. Jane', 386),
#  ('The Falcon and the Snowman', 385),
#  ('The Harvey Girls', 385),
#  ('On the Town', 385),
#  ('K-PAX', 385),
#  ('Twin Peaks: Fire Walk with Me', 384),
#  ("Dead Men Don't Wear Plaid", 384),
#  ('Pandemonium', 384),
#  ('The Apple Dumpling Gang Rides Again', 384),
#  ('Do the Right Thing', 383),
#  ('The Gambler', 383),
#  ('Thunderball', 383),
#  ('Lolita', 383),
#  ('Trial by Jury', 383),
#  ('Geronimo: An American Legend', 383),
#  ('Singles', 382),
#  ('Forces of Nature', 382),
#  ('Fire Down Below', 382),
#  ('Orange County', 381),
#  ("My Best Friend's Wedding", 381),
#  ('The Fifth Element', 380),
#  ('Mystery Men', 380),
#  ('Lilo & Stitch', 380),
#  ('Back to the Future Part II', 380),
#  ('The Flamingo Kid', 380),
#  ('Alice', 379),
#  ('Tombstone', 379),
#  ('Midnight Run', 379),
#  ('Little Shop of Horrors', 378),
#  ('Phantom of the Opera', 378),
#  ('Blue Steel', 378),
#  ('Say Anything...', 378),
#  ('Scream 3', 378),
#  ('Gangs of New York', 378),
#  ('U.S. Marshals', 378),
#  ('L.A. Story', 377),
#  ("The Emperor's New Groove", 377),
#  ('The Fisher King', 377),
#  ('Basic Instinct', 377),
#  ('Anywhere But Here', 377),
#  ('Escape from L.A.', 376),
#  ("I'm Gonna Git You Sucka", 376),
#  ("I'll Do Anything", 376),
#  ('The Pelican Brief', 376),
#  ('Robin Hood: Men in Tights', 376),
#  ('Colors', 376),
#  ('Meet Wally Sparks', 376),
#  ('Predator 2', 376),
#  ('Lost Highway', 376),
#  ('For Love of the Game', 375),
#  ('The Shawshank Redemption', 375),
#  ('Smashing Time', 375),
#  ('3 Ninjas Knuckle Up', 375),
#  ('A Countess from Hong Kong', 375),
#  ('The 6th Day', 375),
#  ('Adaptation.', 375),
#  ('Mr. Jones', 374),
#  ('Blind Date', 374),
#  ('A View to a Kill', 374),
#  ('Frances', 373),
#  ('Kiss the Girls', 373),
#  ('A League of Their Own', 373),
#  ('Fatal Beauty', 373),
#  ('The Dream Team', 373),
#  ('The Lost World: Jurassic Park', 373),
#  ('Plenty', 373),
#  ('Bright Lights, Big City', 373),
#  ('How To Make An American Quilt', 372),
#  ('Far and Away', 372),
#  ('Escape from New York', 372),
#  ('The Adventures of Pluto Nash', 371),
#  ('The Muse', 371),
#  ("Recess: School's Out", 371),
#  ('Eye for an Eye', 370),
#  ('Murder in the First', 370),
#  ('What Women Want', 370),
#  ('Stars & Bars', 370),
#  ('Last Man Standing', 369),
#  ('Hanky Panky', 369),
#  ('The Apple Dumpling Gang', 369),
#  ('Waterworld', 369),
#  ('Somebody to Love', 369),
#  ('Bound for Glory', 368),
#  ('Primal Fear', 368),
#  ('Brubaker', 368),
#  ('Everything You Always Wanted to Know About Sex *But Were Afraid to Ask',
#   368),
#  ('Daredevil', 368),
#  ('The Parent Trap', 367),
#  ('The Man from Elysian Fields', 367),
#  ('The Fabulous Baker Boys', 367),
#  ('Legally Blonde', 367),
#  ('It Happened One Night', 367),
#  ('The Curse of the Jade Scorpion', 367),
#  ('Showgirls', 366),
#  ('The Kid', 366),
#  ('Senseless', 365),
#  ('Pacific Heights', 365),
#  ('Harlem Nights', 364),
#  ('Patriot Games', 364),
#  ('Toy Story', 364),
#  ('Mr. Wonderful', 363),
#  ('The Great Muppet Caper', 363),
#  ('The Flintstones in Viva Rock Vegas', 362),
#  ('Under Siege', 361),
#  ('Homer and Eddie', 361),
#  ('Ace Ventura: Pet Detective', 361),
#  ('The Jerk', 361),
#  ('Never Been Kissed', 361),
#  ('Big', 361),
#  ("Jacob's Ladder", 361),
#  ('The Odd Couple II', 361),
#  ('Changing Lanes', 360),
#  ('Analyze This', 360),
#  ('Touch', 360),
#  ('Braveheart', 359),
#  ('Cool Hand Luke', 359),
#  ('The Philadelphia Story', 359),
#  ('Time Bandits', 359),
#  ('S1m0ne', 359),
#  ('Star Trek: Generations', 359),
#  ('The Day the Earth Caught Fire', 358),
#  ('Nashville', 358),
#  ("The Concorde... Airport '79", 358),
#  ('Mommie Dearest', 357),
#  ('Another 48 Hrs.', 357),
#  ('Analyze That', 357),
#  ('Face/Off', 357),
#  ('For Love or Money', 357),
#  ('Crazy in Alabama', 357),
#  ('The Thin Man', 357),
#  ('Jo Jo Dancer, Your Life Is Calling', 356),
#  ("Prizzi's Honor", 356),
#  ('Kiss of Death', 356),
#  ('Above the Law', 356),
#  ('Close Encounters of the Third Kind', 356),
#  ('Village of the Damned', 356),
#  ('The Money Pit', 356),
#  ("Ferris Bueller's Day Off", 356),
#  ('For Your Eyes Only', 355),
#  ('The Man with Two Brains', 355),
#  ('Shallow Hal', 355),
#  ('Six Degrees of Separation', 355),
#  ('Bell, Book and Candle', 354),
#  ('The Client', 354),
#  ('Nutty Professor II: The Klumps', 354),
#  ('Backdraft', 354),
#  ('Blue Hawaii', 354),
#  ('Congo', 354),
#  ('Super Mario Bros.', 354),
#  ('Glory', 354),
#  ('Fearless', 353),
#  ('The Alamo', 353),
#  ("Cat's Eye", 353),
#  ('The Lost Weekend', 352),
#  ('Robin Hood: Prince of Thieves', 352),
#  ('Trees Lounge', 352),
#  ('Angus', 352),
#  ('Tough Guys', 352),
#  ('Big Trouble', 352),
#  ('A Clockwork Orange', 351),
#  ('The Long Riders', 351),
#  ('Naked in New York', 351),
#  ('Kingdom Come', 351),
#  ('Big Daddy', 351),
#  ('Class', 350),
#  ('Eddie', 350),
#  ('Get Carter', 350),
#  ('Copycat', 350),
#  ('Canadian Bacon', 350),
#  ('Courage Under Fire', 350),
#  ('3000 Miles to Graceland', 350),
#  ('The Usual Suspects', 350),
#  ('O Brother, Where Art Thou?', 349),
#  ("Isn't She Great", 349),
#  ('RoboCop 3', 349),
#  ('The Last Temptation of Christ', 349),
#  ('Keeping the Faith', 349),
#  ('An Alan Smithee Film: Burn, Hollywood, Burn', 349),
#  ('Night Shift', 349),
#  ('Bird', 349),
#  ('Judge Dredd', 348),
#  ('The Couch Trip', 348),
#  ('Home Alone', 348),
#  ('Prêt-à-Porter', 347),
#  ("Pete's Dragon", 347),
#  ('The Wedding Singer', 347),
#  ('Twelve Monkeys', 347),
#  ('Honeymoon in Vegas', 346),
#  ('The Beverly Hillbillies', 346),
#  ('Goodbye Lover', 346),
#  ('Miss Congeniality', 346),
#  ('...All the Marbles', 346),
#  ('To Die For', 346),
#  ('Tucker: The Man and His Dream', 346),
#  ('The Deadly Mantis', 346),
#  ('The Replacement Killers', 345),
#  ('Mulholland Falls', 345),
#  ('Tootsie', 345),
#  ('Buffy the Vampire Slayer', 345),
#  ('Ghost World', 345),
#  ('Universal Soldier', 345),
#  ('As Good as It Gets', 345),
#  ('Dad', 344),
#  ('The Living Daylights', 344),
#  ('Final Fantasy: The Spirits Within', 344),
#  ('Tapeheads', 344),
#  ('Star Wars: Episode I - The Phantom Menace', 344),
#  ('One Night Stand', 343),
#  ('Space Cowboys', 343),
#  ('Blues Brothers 2000', 343),
#  ('Roadside Prophets', 343),
#  ('The Million Dollar Hotel', 343),
#  ('The Postman', 343),
#  ('Small Time Crooks', 343),
#  ('Jeffrey', 342),
#  ('Gross Anatomy', 342),
#  ('Taxi Driver', 342),
#  ('The Kentucky Fried Movie', 342),
#  ('Mixed Nuts', 342),
#  ('Under the Rainbow', 342),
#  ('Dunston Checks In', 341),
#  ('Out of the Past', 341),
#  ('The Quick and the Dead', 341),
#  ('True Lies', 341),
#  ('Field of Dreams', 341),
#  ('The Animal', 341),
#  ('The Mirror Has Two Faces', 340),
#  ('Almost Heroes', 340),
#  ('John Q', 340),
#  ('A Goofy Movie', 340),
#  ('A Perfect World', 340),
#  ('Hans Christian Andersen', 340),
#  ('Sea of Love', 340),
#  ('Larger Than Life', 340),
#  ('Extreme Prejudice', 339),
#  ('Dog Day Afternoon', 339),
#  ('Rain Man', 339),
#  ('The Specialist', 339),
#  ('Rocky II', 339),
#  ('The Fly', 339),
#  ('The Flintstones', 339),
#  ('Tomorrow Never Dies', 338),
#  ("Miller's Crossing", 338),
#  ('Westworld', 338),
#  ('Grace of My Heart', 338),
#  ('The Sweetest Thing', 338),
#  ('Living Out Loud', 338),
#  ('Ice Age', 338),
#  ('Sgt. Bilko', 337),
#  ('Fatal Instinct', 337),
#  ('Reality Bites', 337),
#  ('The Yards', 337),
#  ('The Natural', 337),
#  ('Bean', 337),
#  ('Antz', 336),
#  ('S.O.B.', 336),
#  ('Life', 336),
#  ('Indiana Jones and the Last Crusade', 336),
#  ('Not Another Teen Movie', 336),
#  ('Dead Man Walking', 336),
#  ('A Beautiful Mind', 336),
#  ('Cleopatra', 335),
#  ('Surviving Picasso', 335),
#  ('Rebel Without a Cause', 335),
#  ('Soapdish', 335),
#  ('The Color of Money', 335),
#  ('The Patriot', 335),
#  ('Coming to America', 335),
#  ('Vegas Vacation', 334),
#  ('M*A*S*H', 334),
#  ('RoboCop', 334),
#  ('Pie in the Sky', 334),
#  ("Bill & Ted's Bogus Journey", 334),
#  ('Even Cowgirls Get the Blues', 334),
#  ('Harry Potter and the Chamber of Secrets', 334),
#  ('Tank Girl', 334),
#  ('Dirty Work', 333),
#  ('Catchfire', 333),
#  ('Wolf', 333),
#  ('Rocky III', 333),
#  ('Freejack', 333),
#  ('This Is Spinal Tap', 333),
#  ('Murder at 1600', 333),
#  ('Daylight', 333),
#  ('Rollercoaster', 332),
#  ('Blue in the Face', 332),
#  ('The Onion Field', 332),
#  ('The Man Who Knew Too Little', 332),
#  ('The January Man', 332),
#  ('Stir Crazy', 331),
#  ('Home Alone 2: Lost in New York', 331),
#  ('The Family Man', 331),
#  ('Shadow Conspiracy', 331),
#  ('Five Corners', 331),
#  ('Easy Money', 331),
#  ('Fried Green Tomatoes', 331),
#  ('The Charge of the Light Brigade', 330),
#  ('The Transformers: The Movie', 330),
#  ('Bedknobs and Broomsticks', 330),
#  ('Hot to Trot', 330),
#  ('The Quiet Man', 330),
#  ('Funny Lady', 330),
#  ('Change of Habit', 329),
#  ('Loser', 329),
#  ('Mr. Saturday Night', 329),
#  ('Falling in Love', 329),
#  ("Harry Potter and the Philosopher's Stone", 329),
#  ('The Incredible Shrinking Woman', 329),
#  ('Indecent Proposal', 328),
#  ('Cecil B. Demented', 328),
#  ('Snow Falling on Cedars', 327),
#  ('They Made Me a Criminal', 327),
#  ('To Wong Foo, Thanks for Everything! Julie Newmar', 327),
#  ('The Omen', 327),
#  ('National Security', 327),
#  ('Turbulence', 326),
#  ('Monkey Business', 326),
#  ('The Glenn Miller Story', 326),
#  ('Family Business', 326),
#  ('The Brother from Another Planet', 326),
#  ("The Mirror Crack'd", 325),
#  ('Ri¢hie Ri¢h', 325),
#  ('Broken Arrow', 325),
#  ('Fast Times at Ridgemont High', 325),
#  ('The Naked Gun 2½: The Smell of Fear', 325),
#  ('Sid & Nancy', 325),
#  ('Shall We Dance', 325),
#  ('Action Jackson', 324),
#  ("On Her Majesty's Secret Service", 324),
#  ('Jury Duty', 324),
#  ('The Muppets Take Manhattan', 324),
#  ('Mother Night', 324),
#  ('Strange Days', 324),
#  ('Desperate Measures', 324),
#  ('Fort Apache, the Bronx', 323),
#  ('Pennies from Heaven', 323),
#  ('High School High', 323),
#  ('Dumb and Dumber', 323),
#  ('Howard the Duck', 323),
#  ('Prince of the City', 322),
#  ('Training Day', 322),
#  ('Marked for Death', 322),
#  ('The Object of My Affection', 321),
#  ('Requiem for a Dream', 321),
#  ('The Manhattan Project', 321),
#  ('He Walked by Night', 321),
#  ('Big Trouble in Little China', 321),
#  ('Rock Star', 321),
#  ('The Big Picture', 321),
#  ...]

# %% [markdown]
# # Extracting backbone of network

# %%
from backbone import *

# %%
actorAlphaNetwork = disparity_filter(actorNetwork)
movieAlphaNetwork = disparity_filter(movieNetwork)

# %%
#alphaActor = 0.1
alphaActor = 0.12
actorNetworkBackbone = nx.Graph([(u, v, d) for u, v, d in actorAlphaNetwork.edges(data=True) if d['alpha'] < alphaActor])
alphaMovie = 0.12
movieNetworkBackbone = nx.Graph([(u, v, d) for u, v, d in movieAlphaNetwork.edges(data=True) if d['alpha'] < alphaMovie])

# %%
#sorted(nx.get_edge_attributes(actorNetworkBackbone, 'alpha').items(), key=lambda x: x[1], reverse = False)
#sorted(nx.get_edge_attributes(actorNetworkBackbone, 'weight').items(), key=lambda x: x[1], reverse = False)

# %%
print(f'Actor network backbone stats')
print(f'Nodes: {actorNetworkBackbone.number_of_nodes()}')
print(f'Edges: {actorNetworkBackbone.number_of_edges()}\n')

print(f'Movie network backbone stats')
print(f'Nodes: {movieNetworkBackbone.number_of_nodes()}')
print(f'Edges: {movieNetworkBackbone.number_of_edges()}\n')
# Out:
# Actor network backbone stats
# Nodes: 5820
# Edges: 23473
#
# Movie network backbone stats
# Nodes: 3840
# Edges: 13045

# %%
movieBackboneDegrees = sorted(movieNetworkBackbone.degree(weight='weight'), key=lambda x: x[1], reverse=True)
actorBackboneDegrees = sorted(actorNetworkBackbone.degree(weight='weight'), key=lambda x: x[1], reverse=True)
actorBackboneDegreesValues = [val for name, val in actorBackboneDegrees]
movieBackboneDegreesValues = [val for name, val in movieBackboneDegrees]

# %%
# Binning actors
b = np.arange(np.min(actorBackboneDegreesValues),np.max(actorBackboneDegreesValues),1)
actorFreq, actorBins = np.histogram(actorBackboneDegreesValues, bins = b);
#p_k_sune = [i/np.sum(freq) for i in freq]

# Binning Movies
b = np.arange(np.min(movieBackboneDegreesValues),np.max(movieBackboneDegreesValues),1)
movieFreq, movieBins = np.histogram(movieBackboneDegreesValues, bins = b);
#p_k_sune = [i/np.sum(freq) for i in freq]

# Plotting
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,4))
fig.tight_layout()
ax1.set_title('Actor Network', fontsize = 20)
ax1.set_xlabel('k', fontsize = 14)
ax1.set_ylabel('$count$', fontsize = 14)
ax1.bar(actorBins[:-1], actorFreq, color = 'purple');
ax1.set_xlim(0,100);

ax2.set_title('Movie Network', fontsize = 20)
ax2.set_xlabel('k', fontsize = 14)
ax2.set_ylabel('$count$', fontsize = 14)
ax2.bar(movieBins[:-1], movieFreq, color = 'purple');
ax2.set_xlim(0,100);
plt.show()

# %% [markdown]
# # Plotting network Actors

# %%
# Removing nodes with very small degree (might be illegal)
remove = [node for node,degree in dict(actorNetworkBackbone.degree()).items() if degree < 4]
actorNetworkBackbone.remove_nodes_from(remove)

# %%
# Extracting largest connected component
nodes = max(nx.connected_components(actorNetworkBackbone), key=len)
actorNetworkBackbone = actorNetworkBackbone.subgraph(nodes).copy()

# %%
positions = forceatlas2.forceatlas2_networkx_layout(actorNetworkBackbone, pos=None, iterations=100);
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:09<00:00, 10.24it/s]
# BarnesHut Approximation  took  5.56  seconds
# Repulsion forces  took  4.00  seconds
# Gravitational forces  took  0.02  seconds
# Attraction forces  took  0.03  seconds
# AdjustSpeedAndApplyForces step  took  0.07  seconds

# %%
d = dict(actorNetworkBackbone.degree).values()
scale = 1
node_size = [degree*scale for degree in d]

# %%
# Best partition found with louvain algorithm
partition = community.best_partition(actorNetworkBackbone, random_state = 1, randomize = False)

# Defining values for the color spectrum
maxval = np.max(list(partition.values())) 
cmap=plt.cm.Spectral
node_color = [cmap(v/maxval) for v in partition.values()]

# Plotting
fig = plt.figure(1,figsize=(20,12)) 
nx.draw_networkx_nodes(actorNetworkBackbone, pos = positions, node_color=node_color, alpha=0.9, node_size = node_size);
nx.draw_networkx_edges(actorNetworkBackbone, pos = positions, alpha=0.04);

# For legend creation only
for v in set(partition.values()):
    plt.scatter([],[], c=[cmap(v/maxval)], label='Community {}'.format(v))

plt.title('Actor Network nodes colored by community', fontsize = 20)
plt.legend(loc='upper left', prop={'size': 14})
plt.savefig('actorNetwork.png')
plt.show()

# %%
# rearanging found partition
partsActor = []
for i in range(0, len(set(partition.values()))):
    partsActor.append([])
    
for actor, com in partition.items():
    partsActor[com].append(actor)

#sorting based on biggest communities
partsActorSorted = partsActor
partsActorSorted.sort(key=len, reverse = True)

# %% [markdown]
# # Plotting network Movies

# %%
# Removing nodes with very small degree (might be illegal)
remove = [node for node,degree in dict(movieNetworkBackbone.degree()).items() if degree < 6]
movieNetworkBackbone.remove_nodes_from(remove)

# %%
# Extracting largest connected component
nodes = max(nx.connected_components(movieNetworkBackbone), key=len)
movieNetworkBackbone = movieNetworkBackbone.subgraph(nodes).copy()

# %%
positions = forceatlas2.forceatlas2_networkx_layout(movieNetworkBackbone, pos=None, iterations=100);
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 22.01it/s]
# BarnesHut Approximation  took  2.59  seconds
# Repulsion forces  took  1.86  seconds
# Gravitational forces  took  0.01  seconds
# Attraction forces  took  0.01  seconds
# AdjustSpeedAndApplyForces step  took  0.03  seconds

# %%
d = dict(movieNetworkBackbone.degree).values()
scale = 4
node_size = [degree*scale for degree in d]

# %%
# Best partition found with louvain algorithm
partition = community.best_partition(movieNetworkBackbone, random_state = 1, randomize = False)

# Defining values for the color spectrum
maxval = np.max(list(partition.values())) 
cmap=plt.cm.Spectral
node_color = [cmap(v/maxval) for v in partition.values()]

# Plotting
plt.figure(1,figsize=(20,12)) 
nx.draw_networkx_nodes(movieNetworkBackbone, pos = positions, node_color=node_color, alpha=0.9, node_size = node_size);
nx.draw_networkx_edges(movieNetworkBackbone, pos = positions, alpha=0.04);

# For legend creation only
for v in set(partition.values()):
    plt.scatter([],[], c=[cmap(v/maxval)], label='Community {}'.format(v))

plt.title('Movie Network nodes colored by community', fontsize = 20)
plt.legend(loc='upper left', prop={'size': 14})
plt.savefig('movieNetwork.png')
plt.show()

# %%
# rearanging found partition
partsMovie = []
for i in range(0, len(set(partition.values()))):
    partsMovie.append([])
    
for actor, com in partition.items():
    partsMovie[com].append(actor)
    
#sorting based on biggest communities
partsMovieSorted = partsMovie
partsMovieSorted.sort(key=len, reverse = True)

# %% [markdown]
# # Analysing found communities

# %%
communitySizeActor = [len(com) for com in partsActor]
communitySizeMovie = [len(com) for com in partsMovie]
print(communitySizeActor)
print(communitySizeMovie)
# Out:
# [360, 253, 238, 200, 171, 166, 111, 98, 95, 48, 47, 36, 31, 23, 22, 19, 19, 16, 16, 14, 13, 12, 12, 12]
# [299, 174, 148, 137, 120, 104, 93, 44, 44, 23, 20, 19, 19, 14, 13, 11]

# %%
for i in partsActor:
    print(i[:5])
# Out:
# ['Benjie Bancroft', 'Gertrude Astor', 'Frank Baker', 'George Bruggeman', 'Sam Harris']
# ['Marshall Dancing Elk Lucas', 'Joseph Rigano', 'Tony Darrow', 'Vinny Vella', 'John Turturro']
# ['Chris Webb', 'John Clifford', 'John Tatham', 'Guy Standeven', 'Derek Chafer']
# ['Vincent Schiavelli', 'Anjelica Huston', 'Parker Posey', 'Richard Riehle', 'Greg Bronson']
# ['David Thursby', 'James Stewart', 'John Tyrrell', 'Frank Puglia', 'Eric Mayne']
# ['John Wayne', 'Ken Curtis', 'Anna Lee', 'Tom Smith', 'Jack Montgomery']
# ['Kirk Thornton', 'Mars', 'Bob Papenbrook', 'Jackie Chan', 'Robert Axelrod']
# ['Dean Martin', 'Paul Newman', 'Robert Buckingham', 'Roddy McDowall', 'Richard Farnsworth']
# ['Miguel Sandoval', 'Tim Robbins', 'Sy Richardson', 'Del Zamora', 'Ed Pansullo']
# ['Willie Garson', 'Richard Jenkins', 'Sean Gildea', 'Jackie Flynn', 'Lin Shaye']
# ['Sandra Taylor', 'Jane Morris', 'Kathleen Marshall', 'Garry Marshall', 'Allan Kent']
# ['Don Rickles', 'Andy Romano', 'Mary Hughes', 'Frank Alesia', 'Ronnie Dayton']
# ['Frank Oz', 'Quentin Pierre', 'Alan Flyng', 'David Stone', 'Terence Mustoo']
# ['Ted White', 'Jeff Bridges', 'Clint Eastwood', 'Bill McKinney', 'Dan Vadis']
# ['Brent Spiner', 'Leonard Nimoy', 'Joel Marston', 'Grace Lee Whitney', 'Patrick Stewart']
# ['Joe Chrest', 'Mike Malone', 'Jason Lee', 'Don Cheadle', 'Joey Lauren Adams']
# ['Brendan Gleeson', 'Ronan Wilmot', 'Sean McGinley', 'John Kavanagh', 'Pat Leavy']
# ['Ernie Flatt', 'Judy Landon', 'Luigi Faccuito', 'Alex Goudovitch', 'Dee Turnell']
# ['Arthur Batanides', 'Leslie Easterbrook', 'Marion Ramsey', 'Michael Winslow', 'George Gaynes']
# ['Jim Broadbent', 'Peter Vaughan', 'Terry Gilliam', 'Michael Palin', 'John Cleese']
# ['Bill Lee', 'James MacDonald', 'Don Barclay', 'Queenie Leonard', 'Thurl Ravenscroft']
# ['Charles Chaplin', 'Henry Bergman', 'Wyn Ritchie Evans', 'Tiny Sandford', 'Granville Redmond']
# ['Marc Macaulay', 'Antoni Corone', 'Brett Rice', 'Orlando Delbert', 'Richard Fitzpatrick']
# ['Ian Holm', 'Kenneth Branagh', 'Emma Thompson', 'Edward Jewesbury', 'Richard Clifford']

# %%
print(f'Actor network backbone stats')
print(f'Nodes: {actorNetworkBackbone.number_of_nodes()}')
print(f'Edges: {actorNetworkBackbone.number_of_edges()}\n')

print(f'Movie network backbone stats')
print(f'Nodes: {movieNetworkBackbone.number_of_nodes()}')
print(f'Edges: {movieNetworkBackbone.number_of_edges()}\n')
# Out:
# Actor network backbone stats
# Nodes: 2032
# Edges: 18355
#
# Movie network backbone stats
# Nodes: 1282
# Edges: 8666

# %%
movieBackboneDegrees = sorted(movieNetworkBackbone.degree(), key=lambda x: x[1], reverse=True)
actorBackboneDegrees = sorted(actorNetworkBackbone.degree(), key=lambda x: x[1], reverse=True)

# %%
com = partsMovie[6]
genreAtt = G.nodes(data='Genre')
for movie in com:
    print(f'{movie:<40}{genreAtt[movie]}')
# Out:
# Who Framed Roger Rabbit                 Fantasy
# The Pagemaster                          Fantasy
# Anastasia                               Animation
# Mulan                                   Animation
# Jimmy Neutron: Boy Genius               Action
# The Little Mermaid                      Animation
# Toy Story 2                             Animation
# We're Back! A Dinosaur's Story          Animation
# The Hunchback of Notre Dame             Drama
# The Transformers: The Movie             Animation
# A Goofy Movie                           Romance
# Hercules                                Animation
# Tarzan                                  Adventure
# Space Jam                               Animation
# Aladdin and the King of Thieves         Adventure
# The Rescuers Down Under                 Adventure
# Babe: Pig in the City                   Adventure
# The Fabulous Baker Boys                 Music
# A Bug's Life                            Adventure
# Small Soldiers                          Comedy
# Wayne's World 2                         Music
# Amazon Women on the Moon                Comedy
# Gremlins 2: The New Batch               Comedy
# Innerspace                              Action
# Little Nemo: Adventures In Slumberland  Adventure
# The 'Burbs                              Comedy
# The Howling                             Drama
# The Master of Disguise                  Comedy
# Mr. Deeds                               Comedy
# Eight Crazy Nights                      Comedy
# Little Nicky                            Comedy
# Big Daddy                               Comedy
# Bulletproof                             Action
# The Waterboy                            Comedy
# The Wedding Singer                      Romance
# Deuce Bigalow: Male Gigolo              Comedy
# Casual Sex?                             Comedy
# Coneheads                               Comedy
# Men at Work                             Comedy
# Superstar                               Comedy
# Osmosis Jones                           Adventure
# The Dream Team                          Comedy
# Tommy Boy                               Comedy
# The Wrong Guy                           Action
# Dirty Work                              Comedy
# Billy Madison                           Comedy
# Airheads                                Comedy
# Oscar and Lucinda                       Drama
# Happy Gilmore                           Comedy
# Bio-Dome                                Comedy
# Quest for Camelot                       Fantasy
# Theodore Rex                            Fantasy
# 千と千尋の神隠し                                Fantasy
# Treasure Planet                         Adventure
# The Road to El Dorado                   Adventure
# The Emperor's New Groove                Adventure
# The Iron Giant                          Adventure
# Monsters, Inc.                          Animation
# The Prince of Egypt                     Adventure
# An American Tail: Fievel Goes West      Adventure
# Spirit: Stallion of the Cimarron        Western
# Toy Story                               Animation
# The Lion King                           Family
# となりのトトロ                                 Fantasy
# Beauty and the Beast                    Romance
# Cats Don't Dance                        Animation
# Ice Age                                 Animation
# Lilo & Stitch                           Animation
# Recess: School's Out                    Science Fiction
# アキラ                                     Science Fiction
# The Rugrats Movie                       Animation
# もののけ姫                                   Adventure
# The Return of Jafar                     Family
# Return to Never Land                    Adventure
# Rugrats in Paris: The Movie             Adventure
# Oliver & Company                        Animation
# Gross Anatomy                           Comedy
# Fatal Attraction                        Romance
# Jaws: The Revenge                       Adventure
# Some Kind of Wonderful                  Drama
# Final Fantasy: The Spirits Within       Adventure
# Runaway                                 Thriller
# Dinosaur                                Animation
# The Crow                                Fantasy
# Babe                                    Fantasy
# Joe Dirt                                Mystery
# Going Overboard                         Comedy
# The Animal                              Action
# 黑侠                                      Action
# Moulin Rouge!                           Drama
# Muriel's Wedding                        Drama
# Metropolis                              Animation
# The Powerpuff Girls Movie               Animation

# %%
#pd.to_pickle(partsActor, 'ActorCommunities.pkl')

# %% [markdown]
# # Clustering by genre

# %%
movieNodes = list(movieNetworkBackbone.nodes())
movieNodes
# Out:
# ['Nothing Personal',
#  "Angela's Ashes",
#  'The General',
#  'The Van',
#  'The Butcher Boy',
#  'In the Name of the Father',
#  'The Commitments',
#  'Into the West',
#  'Frankenstein',
#  'Henry V',
#  'Chariots of Fire',
#  "Peter's Friends",
#  'Much Ado About Nothing',
#  'Hamlet',
#  'Bride of Frankenstein',
#  'The Ghost of Frankenstein',
#  'Time Bandits',
#  'Harry Potter and the Chamber of Secrets',
#  'Moll Flanders',
#  'The Long Good Friday',
#  'Braveheart',
#  "Widows' Peak",
#  "Some Mother's Son",
#  'Gandhi',
#  'Batman',
#  'A Clockwork Orange',
#  'Indiana Jones and the Last Crusade',
#  'Raiders of the Lost Ark',
#  'This Is My Father',
#  'Far and Away',
#  'The Paper',
#  'Parenthood',
#  'Edtv',
#  'Apollo 13',
#  'Grand Theft Auto',
#  'Splash',
#  'Gung Ho',
#  'Quadrophenia',
#  'Billy Bathgate',
#  'GoodFellas',
#  'Kiss of Death',
#  'Last Exit to Brooklyn',
#  'New York Stories',
#  'Somebody to Love',
#  'The Bonfire of the Vanities',
#  'The Cotton Club',
#  'Apocalypse Now',
#  'Trading Places',
#  'School Daze',
#  'Serpico',
#  "What's Love Got to Do with It",
#  "The Devil's Advocate",
#  'Moscow on the Hudson',
#  'Ali',
#  'The January Man',
#  'Born on the Fourth of July',
#  'Notting Hill',
#  'Gangs of New York',
#  'Brazil',
#  'Jabberwocky',
#  'Who Framed Roger Rabbit',
#  'Life of Brian',
#  'Morons from Outer Space',
#  'The Elephant Man',
#  'And Now for Something Completely Different',
#  'Robin Hood: Prince of Thieves',
#  'Lifeforce',
#  'Voyage of the Damned',
#  'The Man Who Knew Too Little',
#  'Shakespeare in Love',
#  'The Jackal',
#  'First Knight',
#  'Keep the Aspidistra Flying',
#  'Four Weddings and a Funeral',
#  'The Saint',
#  'Reds',
#  'Topsy-Turvy',
#  'This World, Then the Fireworks',
#  'Radioland Murders',
#  'Little Shop of Horrors',
#  'The Pagemaster',
#  'Anastasia',
#  'Mulan',
#  'Jimmy Neutron: Boy Genius',
#  'The Little Mermaid',
#  'A View to a Kill',
#  'Toy Story 2',
#  "We're Back! A Dinosaur's Story",
#  'Star Wars',
#  'The Hunchback of Notre Dame',
#  'Return of the Jedi',
#  'The Transformers: The Movie',
#  'A Goofy Movie',
#  'Superman III',
#  'The Empire Strikes Back',
#  'Hercules',
#  'The Living Daylights',
#  'Tarzan',
#  'Space Jam',
#  'The Fourth Protocol',
#  'Aladdin and the King of Thieves',
#  'The Rescuers Down Under',
#  'Circle of Friends',
#  'An Awfully Big Adventure',
#  'A Further Gesture',
#  'Trainspotting',
#  'Erik the Viking',
#  'Monty Python Live at the Hollywood Bowl',
#  'Monty Python and the Holy Grail',
#  'The Missionary',
#  'The Fifth Element',
#  'Zoolander',
#  'Star Wars: Episode I - The Phantom Menace',
#  'Tomorrow Never Dies',
#  'Force 10 from Navarone',
#  'The Spy Who Loved Me',
#  'Frenzy',
#  'Plenty',
#  'Superman II',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Rain Man',
#  'Dick Tracy',
#  "Harry Potter and the Philosopher's Stone",
#  'Labyrinth',
#  'Flash Gordon',
#  'Mountains of the Moon',
#  'The World Is Not Enough',
#  'Spider-Man',
#  'Batman & Robin',
#  'Babe: Pig in the City',
#  'Nixon',
#  'Heaven & Earth',
#  'Bulworth',
#  'The Falcon and the Snowman',
#  'JFK',
#  'The Man Who Saw Tomorrow',
#  'Amistad',
#  'Steal This Movie',
#  'For Love or Money',
#  'And the Band Played On',
#  'Natural Born Killers',
#  'Any Given Sunday',
#  'Contact',
#  'Forrest Gump',
#  'True Believer',
#  'Wall Street',
#  'Hot Shots! Part Deux',
#  'Brother Can You Spare A Dime',
#  'Analyze That',
#  'Timecop',
#  'Stay Tuned',
#  'Girls! Girls! Girls!',
#  'G.I. Blues',
#  'The Nutty Professor',
#  'Mary Poppins',
#  'Loving You',
#  'River of No Return',
#  'Roustabout',
#  'Fun in Acapulco',
#  'Beloved',
#  'The Silence of the Lambs',
#  'Philadelphia',
#  'Married to the Mob',
#  'Twelve Monkeys',
#  'Something Wild',
#  'Ghostbusters II',
#  'Beverly Hills Cop',
#  'U.S. Marshals',
#  'Catch Me If You Can',
#  'Eddie',
#  'Private Parts',
#  'The First Wives Club',
#  'Random Hearts',
#  'The Associate',
#  'Forget Paris',
#  'The Godfather',
#  'Donnie Brasco',
#  'The Godfather: Part III',
#  'Dog Day Afternoon',
#  'The Godfather: Part II',
#  'Grand Canyon',
#  'Lethal Weapon 4',
#  'Lethal Weapon 3',
#  'The Fabulous Baker Boys',
#  'Lethal Weapon 2',
#  'The Fugitive',
#  'Ri¢hie Ri¢h',
#  'Under Siege',
#  'Steal Big Steal Little',
#  'Code of Silence',
#  'The Package',
#  'Above the Law',
#  'Miracle on 34th Street',
#  'Risky Business',
#  'Summer of Sam',
#  'Do the Right Thing',
#  'King of New York',
#  'Fear of a Black Hat',
#  'Jungle Fever',
#  'Tales from the Hood',
#  'Coming to America',
#  'Sprung',
#  'Get on the Bus',
#  'The Running Man',
#  "Mo' Better Blues",
#  "Carlito's Way",
#  'Shaft',
#  'Shadows and Fog',
#  'Two Weeks Notice',
#  'Celebrity',
#  'Boomerang',
#  'The Five Heartbeats',
#  'House Party',
#  "I'm Gonna Git You Sucka",
#  'Harlem Nights',
#  'The Meteor Man',
#  'Hollywood Shuffle',
#  'House Party 3',
#  "Don't Be a Menace to South Central While Drinking Your Juice in the Hood",
#  'Next Friday',
#  'Friday',
#  'Inside Moves',
#  'Necessary Roughness',
#  'The Client',
#  'A Perfect World',
#  'Blast from the Past',
#  'Rent-a-Cop',
#  'Life',
#  'Goldfinger',
#  'Diamonds Are Forever',
#  'The Man with the Golden Gun',
#  "On Her Majesty's Secret Service",
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#  'The Road to Hong Kong',
#  'Casino Royale',
#  'A Night to Remember',
#  'A Countess from Hong Kong',
#  'Outland',
#  'For Your Eyes Only',
#  'The Dirty Dozen',
#  'From Russia with Love',
#  'Dr. No',
#  'Live and Let Die',
#  'Moonraker',
#  'Thunderball',
#  'Lolita',
#  'The Pope of Greenwich Village',
#  'Loser',
#  'Independence Day',
#  'Dave',
#  'The Eagle Has Landed',
#  'The Shining',
#  'Ragtime',
#  'Eye of the Needle',
#  'Top Secret!',
#  'Supergirl',
#  'The Day of the Triffids',
#  "A Hard Day's Night",
#  'The Day the Earth Caught Fire',
#  "I'll Never Forget What's'isname",
#  'Two Way Stretch',
#  "I'm All Right Jack",
#  'A Beautiful Mind',
#  'Spy Game',
#  'Mission: Impossible',
#  'The Longest Day',
#  'The Dead Pool',
#  'Every Which Way But Loose',
#  'Pale Rider',
#  'Escape from the Planet of the Apes',
#  'A Fish Called Wanda',
#  'Spartacus',
#  'The Champ',
#  'Chinatown',
#  'The Sting',
#  'Harry and Walter Go To New York',
#  'Blazing Saddles',
#  'Superman',
#  'The Smallest Show on Earth',
#  'The Lavender Hill Mob',
#  'The Ladykillers',
#  'Village of the Damned',
#  'Lawrence of Arabia',
#  "The Mirror Crack'd",
#  'Victim',
#  'The Abominable Dr. Phibes',
#  'Brannigan',
#  'Victor/Victoria',
#  'S.O.B.',
#  'Midway',
#  'Around the World in Eighty Days',
#  'Rising Sun',
#  'Escape from L.A.',
#  'RoboCop 3',
#  'The Fan',
#  'Blade',
#  'Fierce Creatures',
#  'Superman IV: The Quest for Peace',
#  'Batman Returns',
#  'The Monster Club',
#  '2001: A Space Odyssey',
#  'The Ipcress File',
#  'Quatermass II',
#  'The Mummy',
#  'Road to Utopia',
#  'Road to Singapore',
#  'Road to Zanzibar',
#  'The Guns of Navarone',
#  'Oliver!',
#  'The Charge of the Light Brigade',
#  'A Man for All Seasons',
#  'Smashing Time',
#  'The Omen',
#  'An American Werewolf in London',
#  'The Rock',
#  'Armageddon',
#  'Enemy of the State',
#  'The Truman Show',
#  'Metro',
#  'Con Air',
#  'Copycat',
#  'Gone in Sixty Seconds',
#  'G.I. Jane',
#  'Air Force One',
#  'Pearl Harbor',
#  'In the Line of Fire',
#  'Last Action Hero',
#  'Aliens',
#  "The Razor's Edge",
#  'Meteor',
#  'Shampoo',
#  'The Towering Inferno',
#  'The Manchurian Candidate',
#  'Conquest of the Planet of the Apes',
#  'Auntie Mame',
#  'The Poseidon Adventure',
#  'Herbie Goes Bananas',
#  'Airplane II: The Sequel',
#  'The Barefoot Executive',
#  'Torn Curtain',
#  "The Concorde... Airport '79",
#  'The Shaggy D.A.',
#  'The Big Bus',
#  'Billy Jack Goes to Washington',
#  'Topaz',
#  'Gus',
#  'Who Dares Wins',
#  'Cleopatra',
#  'Captain Horatio Hornblower R.N.',
#  'The Man Who Knew Too Much',
#  'The Ruling Class',
#  'Barry Lyndon',
#  'Titanic',
#  'Saving Private Ryan',
#  'The Naked Gun 2½: The Smell of Fear',
#  'The Naked Gun: From the Files of Police Squad!',
#  'The Naked Gun 33⅓: The Final Insult',
#  'Ghost',
#  "My Best Friend's Wedding",
#  'High School High',
#  'Rat Race',
#  'The Big Sleep',
#  'The Great Muppet Caper',
#  'The Greatest Story Ever Told',
#  'War and Peace',
#  'Twins',
#  'Rollerball',
#  'Barabbas',
#  'Britannia Hospital',
#  'L.A. Confidential',
#  'Last Man Standing',
#  'Running Scared',
#  'Armed and Dangerous',
#  "The Secret Policeman's Other Ball",
#  'North by Northwest',
#  'Laura',
#  'The Eddy Duchin Story',
#  'Houseboat',
#  'The Paradine Case',
#  'The Glass Bottom Boat',
#  'The Absent-Minded Professor',
#  'The Thrill of It All',
#  'Imitation of Life',
#  'Monsieur Verdoux',
#  'Designing Woman',
#  'Gentlemen Prefer Blondes',
#  'Vertigo',
#  'The Horse in the Gray Flannel Suit',
#  '4 for Texas',
#  'Strangers on a Train',
#  'When Worlds Collide',
#  'An Affair to Remember',
#  'Earth vs. the Flying Saucers',
#  'How to Marry a Millionaire',
#  'The Bad and the Beautiful',
#  'How to Murder Your Wife',
#  'Saboteur',
#  'The Greatest Show on Earth',
#  'Guys and Dolls',
#  'Calamity Jane',
#  'Giant',
#  'Funny Face',
#  "Singin' in the Rain",
#  'To Catch a Thief',
#  'Pal Joey',
#  'White Christmas',
#  'King Creole',
#  'A Place in the Sun',
#  'Marnie',
#  'Sweet Smell of Success',
#  'I Want to Live!',
#  'The Last Time I Saw Paris',
#  'The War of the Worlds',
#  'The Day the Earth Stood Still',
#  'All About Eve',
#  'The Computer Wore Tennis Shoes',
#  'Pillow Talk',
#  'Father of the Bride',
#  'Notorious',
#  'My Man Godfrey',
#  'East of Eden',
#  'Inherit the Wind',
#  "Breakfast at Tiffany's",
#  "There's No Business Like Show Business",
#  'Coffy',
#  'The Big Combo',
#  'My Fair Lady',
#  'Sabrina',
#  'The Sound of Music',
#  'The Band Wagon',
#  'Rear Window',
#  'Some Like It Hot',
#  'The Harder They Fall',
#  "The Bishop's Wife",
#  'Wild in the Country',
#  'Days of Wine and Roses',
#  'Elmer Gantry',
#  'Witness for the Prosecution',
#  'Pocketful of Miracles',
#  'Herbie Rides Again',
#  'Them!',
#  'Star Wars: Episode II - Attack of the Clones',
#  'Clash of the Titans',
#  'The Dark Crystal',
#  'Planes, Trains and Automobiles',
#  'Oh, God!',
#  'Fallen',
#  'Devil in a Blue Dress',
#  'Girl 6',
#  'Heaven Can Wait',
#  '48 Hrs.',
#  'Goodbye Lover',
#  'Executive Decision',
#  'The Birdcage',
#  "A Bug's Life",
#  "Blackbeard's Ghost",
#  'Irma la Douce',
#  'The Odd Couple',
#  'The Paleface',
#  'The Man from Down Under',
#  'Friendly Persuasion',
#  'The Man Who Shot Liberty Valance',
#  'Rio Bravo',
#  'Our Man Flint',
#  'Gypsy',
#  'One-Eyed Jacks',
#  'Sunset Boulevard',
#  '20,000 Leagues Under the Sea',
#  'The Horse Soldiers',
#  'Funny Girl',
#  'Demetrius and the Gladiators',
#  'Royal Wedding',
#  'The Unsinkable Molly Brown',
#  'The Great Race',
#  'The Perils of Pauline',
#  'The Inspector General',
#  "All the King's Men",
#  'The Asphalt Jungle',
#  'To Kill a Mockingbird',
#  'The Red Badge of Courage',
#  'Force of Evil',
#  'Like Mike',
#  'Wag the Dog',
#  'Old School',
#  'Changing Lanes',
#  'Boys and Girls',
#  'Men in Black II',
#  'Primary Colors',
#  'Daredevil',
#  'Legally Blonde',
#  'Get Shorty',
#  'Planet of the Apes',
#  "Charlie's Angels",
#  'American Pie 2',
#  'Traffic',
#  'That Thing You Do!',
#  'Full Frontal',
#  'Minority Report',
#  'Rock Star',
#  'Almost Famous',
#  'Galaxy Quest',
#  'Austin Powers in Goldmember',
#  'Small Soldiers',
#  'Radio Days',
#  'Fiddler on the Roof',
#  'Cadillac Man',
#  'Enigma',
#  'Maverick',
#  'Die Hard: With a Vengeance',
#  'The Desert Rats',
#  'Ben-Hur',
#  '醉拳二',
#  '超级计划',
#  '双龙会',
#  '警察故事4之簡單任務',
#  'The Cable Guy',
#  'Trekkies',
#  'Mighty Joe Young',
#  'Godzilla',
#  'Not Another Teen Movie',
#  'Desperate Measures',
#  'Mars Attacks!',
#  'Universal Soldier',
#  'Ghosts of Mississippi',
#  'Thirteen Days',
#  'Man on the Moon',
#  'Death to Smoochy',
#  'Volcano',
#  'The Adventures of Rocky & Bullwinkle',
#  'BASEketball',
#  'The Patriot',
#  "Gone Fishin'",
#  'The Firm',
#  'The Kid Stays in the Picture',
#  'Prince of the City',
#  'Now, Voyager',
#  'Mildred Pierce',
#  'The Palm Beach Story',
#  'Gilda',
#  'Foreign Correspondent',
#  'Mrs. Miniver',
#  'Casablanca',
#  'Blood on the Sun',
#  'Love Is a Many-Splendored Thing',
#  'South Pacific',
#  'Looking for Richard',
#  "Fathers' Day",
#  'Get Bruce!',
#  'Under the Rainbow',
#  'The Happiest Millionaire',
#  'Duel in the Sun',
#  'The Philadelphia Story',
#  'Tora! Tora! Tora!',
#  'Son of Flubber',
#  'The Incredible Mr. Limpet',
#  'Seven Days in May',
#  'In Like Flint',
#  'Bedknobs and Broomsticks',
#  'The Million Dollar Duck',
#  'X: The Man with the X-Ray Eyes',
#  'The Graduate',
#  'The Lost World: Jurassic Park',
#  'The Big Lebowski',
#  'The Hurricane',
#  'It Could Happen to You',
#  'Serendipity',
#  'In & Out',
#  'Action Jackson',
#  'Predator 2',
#  'Red Heat',
#  'The Long Riders',
#  "Brewster's Millions",
#  'Geronimo: An American Legend',
#  'Another 48 Hrs.',
#  'Tango & Cash',
#  'The Beverly Hillbillies',
#  "Wayne's World 2",
#  'Austin Powers: The Spy Who Shagged Me',
#  'This Is Spinal Tap',
#  'Best in Show',
#  "Jumpin' Jack Flash",
#  'Amazon Women on the Moon',
#  'Halloween II',
#  'The Brady Bunch Movie',
#  'The Replacements',
#  'Red Dragon',
#  'Shadow Conspiracy',
#  'Gods and Generals',
#  'Cecil B. Demented',
#  'Liberty Heights',
#  'The Watcher',
#  'Clear and Present Danger',
#  'Along Came a Spider',
#  'Hannibal',
#  'Quiz Show',
#  'City Hall',
#  'The New Guy',
#  'The Life of David Gale',
#  'The Rookie',
#  'American Outlaws',
#  'Miss Congeniality',
#  'Road Trip',
#  'The Faculty',
#  'Where the Heart Is',
#  'My Cousin Vinny',
#  'Desperately Seeking Susan',
#  'My Fellow Americans',
#  'The Goonies',
#  'Any Which Way You Can',
#  'Conspiracy Theory',
#  'Lethal Weapon',
#  'Assassins',
#  'Gremlins 2: The New Batch',
#  'Innerspace',
#  'Little Nemo: Adventures In Slumberland',
#  "The 'Burbs",
#  'The Howling',
#  'The Shawshank Redemption',
#  'Sunshine State',
#  'Awakenings',
#  'Rocky V',
#  'RoboCop 2',
#  'Freejack',
#  'Stuart Saves His Family',
#  'Rules of Engagement',
#  'Collateral Damage',
#  'The Postman',
#  'A Civil Action',
#  'A.I. Artificial Intelligence',
#  'The Sum of All Fears',
#  'Magnolia',
#  'Showtime',
#  'The Contender',
#  'The Sweetest Thing',
#  'The Master of Disguise',
#  'Mr. Deeds',
#  'Kung Pow: Enter the Fist',
#  'Eight Crazy Nights',
#  'Little Nicky',
#  'Big Daddy',
#  'The Peacemaker',
#  'The Juror',
#  'The Mirror Has Two Faces',
#  'Ransom',
#  'Money Train',
#  'Rounders',
#  'Night Falls on Manhattan',
#  'Under Siege 2: Dark Territory',
#  'The Replacement Killers',
#  'Casino',
#  'Free Willy 2 - The Adventure Home',
#  'The Shadow',
#  'What Planet Are You From?',
#  'Rapid Fire',
#  'Rush Hour',
#  'Big Trouble in Little China',
#  'Scrooged',
#  'Die Hard',
#  'Clockers',
#  'Dead Presidents',
#  'He Got Game',
#  'The Addiction',
#  'Love Affair',
#  'Cradle Will Rock',
#  'Working Girl',
#  'Annie Hall',
#  "She's Having a Baby",
#  'Ghostbusters',
#  'The Fly II',
#  'Disturbing Behavior',
#  'Elvira, Mistress of the Dark',
#  "Pee-wee's Big Adventure",
#  "Cheech & Chong's Next Movie",
#  'Pandemonium',
#  'Orange County',
#  'Passion Fish',
#  'Pushing Tin',
#  'A Time to Kill',
#  'The American President',
#  'Fear and Loathing in Las Vegas',
#  '8MM',
#  'The Hudsucker Proxy',
#  "Miller's Crossing",
#  'Holy Man',
#  "There's Something About Mary",
#  'All About the Benjamins',
#  'Big Trouble',
#  'Bully',
#  'Out of Sight',
#  'Cobb',
#  'Blue Chips',
#  'Play It to the Bone',
#  'Johnny Dangerously',
#  'Airplane!',
#  'The Kentucky Fried Movie',
#  'Trixie',
#  'A Guy Thing',
#  'Me, Myself & Irene',
#  'On Our Merry Way',
#  "Pot o' Gold",
#  'Written on the Wind',
#  'The Best Years of Our Lives',
#  'Bright Eyes',
#  'Sorry, Wrong Number',
#  'Ninotchka',
#  'Mr. Smith Goes to Washington',
#  'The Grapes of Wrath',
#  'Road to Morocco',
#  'Monkey Business',
#  "You Can't Take It With You",
#  'Gone with the Wind',
#  'Anchors Aweigh',
#  'Bringing Up Baby',
#  'Dial M for Murder',
#  'Citizen Kane',
#  'The Lone Ranger',
#  'Dodsworth',
#  'She Wore a Yellow Ribbon',
#  'Arsenic and Old Lace',
#  'The Gnome-Mobile',
#  'Body and Soul',
#  'Dead Reckoning',
#  'Blue Hawaii',
#  "It's a Wonderful Life",
#  'The Fighting Seabees',
#  "It's a Mad, Mad, Mad, Mad World",
#  'Speechless',
#  'Angel on My Shoulder',
#  'Out of the Past',
#  "Don't Bother to Knock",
#  'Scarlet Street',
#  'The Pride of the Yankees',
#  'The Fly',
#  'Lured',
#  'I Am Sam',
#  'Batman Forever',
#  'Jingle All the Way',
#  'Falling Down',
#  'No Way Out',
#  'Postcards from the Edge',
#  'Crimson Tide',
#  'Beverly Hills Cop II',
#  'Star Trek VI: The Undiscovered Country',
#  'Monkeybone',
#  "Ferris Bueller's Day Off",
#  'Manhattan',
#  'Deconstructing Harry',
#  'Stardust Memories',
#  'Sleeper',
#  'Manhattan Murder Mystery',
#  'Muppets from Space',
#  'Muppet Treasure Island',
#  'The Muppets Take Manhattan',
#  'Black Knight',
#  'Sesame Street Presents Follow That Bird',
#  'The Muppet Christmas Carol',
#  'The Muppet Movie',
#  'The Adventures of Elmo in Grouchland',
#  'True Crime',
#  'Tucker: The Man and His Dream',
#  'Men in Black',
#  'Heist',
#  'Addams Family Values',
#  'Touch of Evil',
#  'Fletch',
#  'Young Frankenstein',
#  'Falling in Love',
#  'Husbands and Wives',
#  'Crimes and Misdemeanors',
#  'One Fine Day',
#  'The Curse of the Jade Scorpion',
#  'Demolition Man',
#  'Sugar & Spice',
#  'Immediate Family',
#  'The Accused',
#  'Bulletproof',
#  'The Waterboy',
#  'The Wedding Singer',
#  'Deuce Bigalow: Male Gigolo',
#  'Remember the Titans',
#  'A Simple Twist of Fate',
#  'Problem Child 2',
#  'October Sky',
#  'The People vs. Larry Flynt',
#  'Sweet Home Alabama',
#  'Runaway Bride',
#  'Exit to Eden',
#  'Frankie and Johnny',
#  'Nothing in Common',
#  'Dear God',
#  'The Princess Diaries',
#  'Young Doctors in Love',
#  'The Other Sister',
#  'Pretty Woman',
#  'Beaches',
#  'Gettysburg',
#  'Tombstone',
#  'Cannonball Run II',
#  'The Cannonball Run',
#  'North',
#  "National Lampoon's Loaded Weapon 1",
#  'Anywhere But Here',
#  'Bowfinger',
#  'Star Trek III: The Search for Spock',
#  'Shoot to Kill',
#  'Swordfish',
#  'Star Trek II: The Wrath of Khan',
#  'Full Tilt Boogie',
#  'Girls Just Want to Have Fun',
#  'Total Recall',
#  'Grosse Pointe Blank',
#  'Murder at 1600',
#  'Detroit Rock City',
#  'Scream 2',
#  'Joe Somebody',
#  'Here On Earth',
#  'The Mighty Ducks',
#  'Drop Dead Gorgeous',
#  'Nashville',
#  'M*A*S*H',
#  'McCabe & Mrs. Miller',
#  'The Player',
#  'The Incredible Shrinking Woman',
#  'Outbreak',
#  'Liar Liar',
#  'State and Main',
#  'The Spanish Prisoner',
#  'Things Change',
#  'Boogie Nights',
#  'The Blues Brothers',
#  'Night Shift',
#  'Star Trek: The Motion Picture',
#  'Starship Troopers',
#  'True Romance',
#  'Celtic Pride',
#  "The Man Who Wasn't There",
#  'Eraser',
#  "She's So Lovely",
#  'Casual Sex?',
#  'Rocky III',
#  'Stir Crazy',
#  'Rocky IV',
#  'Staying Alive',
#  '3 Ninjas Knuckle Up',
#  'Rocky II',
#  'Coneheads',
#  'The Great White Hype',
#  'Sleepers',
#  'Waiting to Exhale',
#  'Mercury Rising',
#  'Roadside Prophets',
#  'Stakeout',
#  'F/X2',
#  'Men at Work',
#  'Jerry Maguire',
#  'Superstar',
#  'The Way We Were',
#  'Westworld',
#  'The Swarm',
#  'The Nude Bomb',
#  'American Gigolo',
#  'Hairspray',
#  'Cavalcade',
#  'How Green Was My Valley',
#  'Frankenstein Meets the Wolf Man',
#  'The Lady Eve',
#  'Little Lord Fauntleroy',
#  'A Damsel in Distress',
#  'Mutiny on the Bounty',
#  'The Invisible Man',
#  "Hang 'em High",
#  'El Dorado',
#  'Kingpin',
#  'Osmosis Jones',
#  'Shallow Hal',
#  'Sudden Death',
#  'Dumb and Dumber',
#  'Dogma',
#  'Meet John Doe',
#  'A Christmas Carol',
#  'The Adventures of Robin Hood',
#  'House of Frankenstein',
#  'Hangmen Also Die!',
#  'The Dream Team',
#  'Tommy Boy',
#  'Everything You Always Wanted to Know About Sex *But Were Afraid to Ask',
#  'High Noon',
#  'The Big Country',
#  'Mister Roberts',
#  'The Sons of Katie Elder',
#  'In Old California',
#  'Voyage to the Bottom of the Sea',
#  'The Big Trees',
#  'Rough Night in Jericho',
#  'Limelight',
#  'The Searchers',
#  'The Long Gray Line',
#  'The Alamo',
#  'The Big Heat',
#  'Cape Fear',
#  'Lonely Are the Brave',
#  'Dark Command',
#  "Donovan's Reef",
#  'True Grit',
#  'Paint Your Wagon',
#  'Cat Ballou',
#  'The Apple Dumpling Gang',
#  'From Here to Eternity',
#  "Jacob's Ladder",
#  'Pink Cadillac',
#  'Bronco Billy',
#  'Sudden Impact',
#  'Dirty Harry',
#  'Honkytonk Man',
#  'Change of Habit',
#  'Fear Strikes Out',
#  'The Benny Goodman Story',
#  "Ocean's Eleven",
#  'The Gay Divorcee',
#  'The Great Dictator',
#  'The Mark of Zorro',
#  'It Happened One Night',
#  'Grand Hotel',
#  'Impact',
#  "Gentleman's Agreement",
#  'Seconds',
#  'The Killing',
#  'For Whom the Bell Tolls',
#  'Penny Serenade',
#  'The Snows of Kilimanjaro',
#  'The Young Lions',
#  'Hans Christian Andersen',
#  'Airport',
#  'Mr. & Mrs. Smith',
#  'Golden Earrings',
#  'The Life of Emile Zola',
#  'The Glenn Miller Story',
#  'The Love Bug',
#  'Murder, My Sweet',
#  'Macao',
#  'A Streetcar Named Desire',
#  'The Apple Dumpling Gang Rides Again',
#  'Young at Heart',
#  '20 Million Miles to Earth',
#  'Gaslight',
#  'Babes in Toyland',
#  'Rebel Without a Cause',
#  'An American in Paris',
#  'Pollyanna',
#  'The Apartment',
#  'Something to Sing About',
#  'On the Town',
#  'A Star Is Born',
#  'Holiday Inn',
#  "The Children's Hour",
#  'Taxi Driver',
#  'The Wrong Guy',
#  'Dirty Work',
#  'Billy Madison',
#  'Down to Earth',
#  'Class',
#  'To Be or Not to Be',
#  'Pursued',
#  'The Talk of the Town',
#  'The Lost Weekend',
#  'The Strange Love of Martha Ivers',
#  'Santa Fe Trail',
#  'The Quiet Man',
#  'The Thin Man',
#  'Mrs. Parker and the Vicious Circle',
#  'Basquiat',
#  'The Funeral',
#  'Mixed Nuts',
#  'Dr. T and the Women',
#  'Serving Sara',
#  'Antitrust',
#  'Backdraft',
#  'Home Alone',
#  'Almost Heroes',
#  'The Royal Tenenbaums',
#  'Small Time Crooks',
#  'Heat',
#  'Pecker',
#  'For Love of the Game',
#  'Deep Impact',
#  'Coyote Ugly',
#  'The Negotiator',
#  'Sunset Strip',
#  'Fight Club',
#  'Blow',
#  'The Green Mile',
#  'Evolution',
#  'Dude, Where’s My Car?',
#  'Airheads',
#  'Short Cuts',
#  'Stardom',
#  'Snake Eyes',
#  'Abandon',
#  'The Impostors',
#  'Highlander III: The Sorcerer',
#  ...]

# %%
genreNetwork = G.subgraph(movieNodes).copy()
movieGenre = {movie[0]: movie[1]['Genre'] for movie in genreNetwork.nodes(data=True)}

# %%
nx.set_node_attributes(movieNetworkBackbone, movieGenre, name = 'Genre')

# %%
set([genre for actor,genre in genreAtt])

genreCommunities = []
for genre in set([genre for actor,genre in genreAtt]):
    genreCommunities.append([node[0] for node in genreNetwork.nodes(data=True) if node[1]['Genre'] == genre])

# %%
print(f'Modularity with genre as community: {nx.algorithms.community.modularity(movieNetworkBackbone, genreCommunities)}')
print(f'Modularity with Louvain algorithm: {nx.algorithms.community.modularity(movieNetworkBackbone, partsMovie)}')
# Out:
# 0.08546511139017213
# 0.6535915229823477
