# %% [markdown]
# # Clustering

# %%
import pandas as pd
import numpy as np
import re
import networkx as nx
import matplotlib.pyplot as plt

moviesDf = pd.read_pickle("moviesDf.pkl")
moviesDf
# Out:
#      TitleId                          MovieTitle  \
# 0    0000399              Jack and the Beanstalk
# 1    0000430                     A Chess Dispute
# 2    0000653              A Calamitous Elopement
# 3    0002816              The Drummer of the 8th
# 4    0003662       The Battle of Elderbush Gulch
# ..       ...                                 ...
# 971  0088249                Terror in the Aisles
# 972  0088263           Michael Jackson: Thriller
# 973  0088323               The NeverEnding Story
# 974  0088381  Nausicaä of the Valley of the Wind
# 975  0088402                       The Wild Life
#
#                                                 Actors
# 0                                       [Thomas White]
# 1                                     [Alfred Collins]
# 2    [Harry Solter, Linda Arvidson, Charles Inslee,...
# 3       [Cyril Gardner, Mildred Harris, Frank Borzage]
# 4    [Mae Marsh, Leslie Loveridge, Alfred Paget, Ro...
# ..                                                 ...
# 971  [Donald Pleasence, Nancy Allen, Fred Asparagus...
# 972  [Michael Jackson, Ola Ray, Brandon Scott Mille...
# 973  [Barret Oliver, Gerald McRaney, Chris Eastman,...
# 974  [Sumi Shimamoto, Mahito Tsujimura, Minoru Yada...
# 975  [Chris Penn, Eric Stoltz, Jenny Wright, Lea Th...
#
# [976 rows x 3 columns]

# %%
actor_column = list(moviesDf["Actors"].to_numpy())
G = nx.Graph()

for movie_cast in actor_column[:100]:
    G.add_nodes_from(movie_cast)
    
    if (len(movie_cast) > 1):
        for actor in movie_cast[1:]:
            G.add_edge(movie_cast[0], actor)
    
print(G.nodes())
# Out:
# ['Thomas White', 'Alfred Collins', 'Harry Solter', 'Linda Arvidson', 'Charles Inslee', 'George Gebhardt', 'Robert Harron', 'Cyril Gardner', 'Mildred Harris', 'Frank Borzage', 'Mae Marsh', 'Leslie Loveridge', 'Alfred Paget', 'Lillian Gish', 'Charles Hill Mailes', 'Frank Opperman', 'Joseph McDermott', 'Violet MacMillan', 'Fred Woodward', 'Vivian Reed', 'Pierre Couderc', 'Juanita Hansen', 'Jacqueline Lovell', 'Frank Moore', 'Bernadine Zuber', 'Dave Anderson', 'Charles Chaplin', 'Edna Purviance', 'Ben Turpin', 'Peter Sellers', 'Fred Goodwins', 'Jack Henderson', 'Bud Jamison', 'John Rand', 'Billy Armstrong', 'Agnes Ayres', 'Robert Bolder', 'Charles Hitchcock', 'Charlotte Mineau', 'Courtenay Foote', 'Myrtle Stedman', 'Herbert Standing', 'Adele Farrington', 'George Berrell', 'Francesca Bertini', 'Dixie Carr', 'Jane Darwell', 'Marjorie Daw', 'Mabel Normand', 'Alice Davenport', 'Joe Bordeaux', 'Edgar Kennedy', 'Glen Cavender', 'Billy Gilbert', 'Frank Dolan', 'Ted Edwards', 'Keystone Kops', 'Eric Campbell', 'Lloyd Bacon', 'Albert Austin', 'Leo White', 'Henry Bergman', 'Buster Keaton', 'Josephine Stevens', 'Arthur Earle', 'Luke the Dog', 'Charles Dudley', 'Alice Lake', 'Agnes Neilson', 'Zanny Petersen', 'Nicolai Neiiendam', 'Svend Kornbeck', 'Philip Bech', 'Lilly Jacobson', 'Frederik Jacobsen', 'Albert Paul', 'Harold Lloyd', 'Bebe Daniels
# %%
gn = nx.algorithms.community.girvan_newman(G)

communities = tuple(sorted(c) for c in next(gn))
modularity = nx.algorithms.community.modularity(G, communities)

print(communities)
# Out:
# (['Thomas White'], ['Alfred Collins'], ['Agnes Ayres', 'Albert Austin', 'Alfred Paget', 'Ben Turpin', 'Billy Armstrong', 'Bud Jamison', 'Charles Chaplin', 'Charles Hill Mailes', 'Charles Hitchcock', 'Charles Inslee', 'Charlotte Mineau', 'Edna Purviance', 'Eric Campbell', 'Frank Opperman', 'Fred Goodwins', 'George Gebhardt', 'Harry Solter', 'Henry Bergman', 'Jack Henderson', 'Jack Wilson', 'John Rand', 'Joseph McDermott', 'Leo White', 'Leslie Loveridge', 'Lillian Gish', 'Linda Arvidson', 'Lloyd Bacon', 'Loyal Underwood', 'Mae Marsh', 'Peter Sellers', 'Robert Bolder', 'Robert Harron', 'Syd Chaplin', 'Tom Wilson'], ['Bernadine Zuber', 'Cyril Gardner', 'Dave Anderson', 'Frank Borzage', 'Frank Moore', 'Fred Woodward', 'Jacqueline Lovell', 'Juanita Hansen', 'Mildred Harris', 'Pierre Couderc', 'Violet MacMillan', 'Vivian Reed'], ['Adele Farrington', 'Courtenay Foote', 'Dixie Carr', 'Francesca Bertini', 'George Berrell', 'Herbert Standing', 'Jane Darwell', 'Marjorie Daw', 'Myrtle Stedman'], ['Agnes Neilson', 'Alice Davenport', 'Alice Lake', 'Alice Ward', 'Anita Garvin', 'Anna Dodge', 'Arthur Earle', 'Arthur Thalasso', 'Baldwin Cooke', 'Bebe Daniels', 'Ben Lyon', 'Berton Churchill', 'Bill Patton', 'Billy Bletcher', 'Billy Gilbert', 'Bobby Burns', 'Buddy Moore', 'Buster Keaton', 'Charles Dudley', 'Charles Meredith', 'Charles Ruggles', 'Charley Young', 'Charlie Hall', 'Clarence Geldert', 'Clifford Thompson', 'Dorothy Layton', 'Ed Brandenburg', 'Eddie Baker', 'Edgar Kennedy', 'Edward Martindel', 'Elliott Dexter', 'Eric Mayne', 'Estelle Etterre', 'Evelyn Burns', 'Fay Holderness', 'Florence Lee', 'Florence Vidor', 'Ford West', 'Frank Dolan', 'Frank Jonasson', 'Fritz the Horse', 'George Rowe', 'Gertrude Claire', 'Glen Cavender', 'Gus Leonard', 'Hal Berg', 'Harold Lloyd', 'Harry Bernard', 'Harry Langdon', 'Harry Semels', 'Helen Gilmore', 'Irene Purcell', 'Irving Cummings', 'Jack Ackroyd', 'Jack Edwards', 'Jack Morgan', 'Jack Richardson', 'Jackie Condon', 'James Gleason', 'James Neill', 'Jimmy Aubrey', 'Joe Bordeaux', 'Joe Keaton', 'Joe Roberts', 'Joseph Singleton', 'Josephine Stevens', 'Julia Faye', 'Julie Leonard', 'Katherine Grant', 'Kay Deslys', 'Keystone Kops', 'Kitty Bradbury', 'Leo Booth', 'Leo Willis', 'Leona Anderson', 'Lew Cody', 'Lew Harvey', 'Lige Conley', 'Lilyan Irene', 'Lloyd Hamilton', 'Lloyd Hughes', 'Louise Keaton', 'Luke the Dog', 'Lyle Tayo', 'Mabel Normand', 'Madge Bellamy', 'Mae Laurel', 'Marcella Daly', 'Mark Jones', 'Mary Carlisle', 'Mathilde Brundage', 'May Foster', 'May Wallace', 'Mickey Daniels', 'Mildred Davis', 'Myra Keaton', 'Noah Young', 'Oliver Hardy', 'Peggy Montgomery', 'Porter Hall', 'Raymond Hatton', 'Richard Belfield', 'Richard Daniels', 'Richard Headrick', 'Robert Brower', 'Robert Frazer', 'Roger Moore', 'Rolfe Sedan', 'Roscoe Karns', 'Roy Brooks', 'Russell Hardie', 'Ruth Hiatt', 'Sam Kaufman', 'Sam Lufkin', 'Sammy Brooks', 'Spencer Charters', 'Stan Laurel', 'Sylvia Ashton', 'Ted Edwards', 'Ted Shawn', 'Thelma Todd', 'Theodore Roberts', 'Tiny Sandford', 'Tiny Ward', 'Una Merkel', 'Vernon Dent', 'Virginia Fox', 'Wally Howe', 'Wheeler Dryden', 'Willard Robertson', 'William Austin', 'William Blaisdell', 'William Gillespie', 'Zasu Pitts'], ['Albert Paul', 'Frederik Jacobsen', 'Lilly Jacobson', 'Nicolai Neiiendam', 'Philip Bech', 'Svend Kornbeck', 'Zanny Petersen'], ['Addie Foster', 'Al Hill', 'Alan Mowbray', 'Alexander Kirkland', 'Alice Joyce', 'Allen Jenkins', 'Anders Randolf', 'Angelo Rossitto', 'Anita Louise', 'Anne Shirley', 'Anthony Bushell', 'Arthur Byron', 'Arthur Lake', 'Arthur Vinton', 'Astrid Allwyn', 'Barbara Kent', 'Barbara Leonard', 'Barbara Stanwyck', 'Basil Rathbone', 'Bela Lugosi', 'Ben Alexander', 'Beryl Mercer', 'Bessie Love', 'Bette Davis', 'Betty Sinclair', 'Bill Elliott', 'Billie Dove', 'Billy Bevan', 'Blanche Friderici', 'Bobby Dunn', 'Bradley Page', 'Bruce Cabot', 'Budd Fine', 'Burr McIntosh', 'Carole Lombard', 'Carroll Nye', 'Cary Grant', 'Catherine Dale Owen', 'Cecil Holland', 'Cecilia ...

# %%
print(f'The modularity is {modularity}')
# Out:
# The modularity is 0.6350652143037497

# %%
node_color = []
for node in G.nodes():
    if node in communities[0]:
        node_color.append('blue')
    if node in communities[1]:
        node_color.append('red')
    if node in communities[2]:
        node_color.append('yellow')
    if node in communities[3]:
        node_color.append('orange')
    if node in communities[4]:
        node_color.append('violet')
    if node in communities[5]:
        node_color.append('skyblue')
    if node in communities[6]:
        node_color.append('green')
    if node in communities[7]:
        node_color.append('forestgreen')
    if node in communities[8]:
        node_color.append('darkkhaki')
    if node in communities[9]:
        node_color.append('pink')
    if node in communities[10]:
        node_color.append('deeppink')
    if node in communities[11]:
        node_color.append('teal')
    if node in communities[12]:
        node_color.append('cyan')
    if node in communities[13]:
        node_color.append('coral')
    if node in communities[14]:
        node_color.append('darkmagenta')
    if node in communities[15]:
        node_color.append('darkgoldenrod')
    if node in communities[16]:
        node_color.append('maroon')
    if node in communities[17]:
        node_color.append('gray')
    if node in communities[18]:
        node_color.append('tomato')
    if node in communities[19]:
        node_color.append('lemonchiffon')
    if node in communities[20]:
        node_color.append('thistle')
    if node in communities[21]:
        node_color.append('azure')
    if node in communities[22]:
        node_color.append('crimson')
    if node in communities[23]:
        node_color.append('lawngreen')

# %%
nx.draw(G,node_size=10,node_color=node_color)

# %%
print("hello")
# Out:
# hello
