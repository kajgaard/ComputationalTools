# %%
import pandas as pd
df_reviews = pd.read_pickle(r'reviewsFromImdb/networkData3.pkl')

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')

# %%
#df_reviews['Review_tokens'] = df_reviews.apply(lambda row: tokenizer.tokenize(x.lower() for x in row['Reviews']), axis=1)

# %%
#df_reviews.apply(lambda row: tokenizer.tokenize(x.lower() for x in row['Reviews']), axis=1)
sent_tokens = []
for row in df_reviews["Reviews"]:
    tokens = []
    for sub in row:
        tokens.append(tokenizer.tokenize(sub.lower()))
    sent_tokens.append(tokens)
df_reviews['Review_tokens'] = sent_tokens

# %%
df_reviews
# Out:
#       TitleId            MovieTitle  \
# 0     0235679  Pokémon 3: The Movie
# 1     0221889   Beautiful Creatures
# 2     0268200          Brigham City
# 3     0260332        روزی که زن شدم
# 4     0238588          Shadow Magic
# ...       ...                   ...
# 1991  0066579         Women in Love
# 1992  0322824                 Japón
# 1993  0285462             Boat Trip
# 1994  0285531          Dreamcatcher
# 1995  0323642    Piglet's Big Movie
#
#                                                  Actors  \
# 0     [Rica Matsumoto, Veronica Taylor, Rachael Lill...
# 1     [Susan Lynch, Iain Glen, Rachel Weisz, Tom Man...
# 2     [Richard Dutcher, Wilford Brimley, Carrie Morg...
# 3     [Fatemeh Cherag Akhar, Hassan Nebhan, Shahr Ba...
# 4     [Jared Harris, Yu Xia, Yufei Xing, Peiqi Liu, ...
# ...                                                 ...
# 1991  [Alan Bates, Oliver Reed, Glenda Jackson, Jenn...
# 1992  [Alejandro Ferretis, Magdalena Flores, Yolanda...
# 1993  [Horatio Sanz, Roselyn Sanchez, Maurice Godin,...
# 1994  [Morgan Freeman, Thomas Jane, Jason Lee, Damia...
# 1995  [John Fiedler, Jim Cummings, Andre Stojka, Kat...
#
#                                                  Genres  \
# 0     [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 2     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# ...                                                 ...
# 1991  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 1992  [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# 1993                     [{'id': 35, 'name': 'Comedy'}]
# 1994  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 1995  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
#
#                                                 Reviews Rating  \
# 0     [The other day, I was looking through some old...    5.8
# 1     [What I liked about the film "Beautiful Creatu...    5.8
# 2     [First and foremost, Brigham City is a murder ...    6.7
# 3     [I had completely forgotten about this movie, ...    7.3
# 4     [Ann Hus first directorial and writing effort...    7.2
# ...                                                 ...    ...
# 1991  [Ken Russell's adaptation of D. H. Lawrence's ...    7.1
# 1992  [Japon, a film by first-time director Carlos R...    6.9
# 1993  [Man I don't understand why people come down s...    4.9
# 1994  [This Stephen King adaptation is underrated, s...    5.5
# 1995  [Piglet's Big Movie is a sweet children's movi...    6.1
#
#                                           Review_tokens
# 0     [[the, other, day, i, was, looking, through, s...
# 1     [[what, i, liked, about, the, film, beautiful,...
# 2     [[first, and, foremost, brigham, city, is, a, ...
# 3     [[i, had, completely, forgotten, about, this, ...
# 4     [[ann, hu, s, first, directorial, and, writing...
# ...                                                 ...
# 1991  [[ken, russell, s, adaptation, of, d, h, lawre...
# 1992  [[japon, a, film, by, first, time, director, c...
# 1993  [[man, i, don, t, understand, why, people, com...
# 1994  [[this, stephen, king, adaptation, is, underra...
# 1995  [[piglet, s, big, movie, is, a, sweet, childre...
#
# [1996 rows x 7 columns]

# %%
df_sentimentValues = pd.read_csv('Sentiment_values.txt', sep='\t',engine='python')
df_word_and_scores = df_sentimentValues[['word', 'happiness_average']].copy()
sentiment_dict = dict(zip(df_word_and_scores.word, df_word_and_scores.happiness_average))

# %%
ext_list = []
for row in df_reviews['Review_tokens']:
    review_in_list =[]
    for reviews in row:
        tokens_in_list = []
        for token in reviews:
            if token in sentiment_dict.keys():
                tokens_in_list.append(token)
        review_in_list.append(len(tokens_in_list))
    ext_list.append(review_in_list)

# %%
reviews_for_movie =[]
for row in df_reviews['Review_tokens']:
    sentiments_for_review = []
    for review in row:
        sentiments_for_token = []
        for token in review:
            if token in sentiment_dict.keys():
                sentiments_for_token.append(sentiment_dict[token])
        sentiments_for_review.append(int(sum(sentiments_for_token)))
    reviews_for_movie.append(sentiments_for_review)
df_reviews['Sentiment'] = reviews_for_movie

# %%
print(ext_list[0])
print(len(df_reviews['Sentiment']))
# Out:
# [137, 146, 289, 330, 179, 292, 264, 218, 50, 978, 235, 52, 416, 559, 66, 116, 306, 315, 145, 201, 183, 56, 36, 198, 30]
# 1996

# %%
#df_reviews['Average_sentiment'] = [(x for x in df_reviews['Sentiment'][index] / (y for y in ext_list[index])) for index in range(len(df_reviews['Sentiment']))]
res = [i / j for i, j in zip(df_reviews['Sentiment'][index], ext_list[index]) for index in range(len(df_reviews['Sentiment']))]
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [37], in <cell line: 2>()
#       1 #df_reviews['Average_sentiment'] = [(x for x in df_reviews['Sentiment'][index] / (y for y in ext_list[index])) for index in range(len(df_reviews['Sentiment']))]
# ----> 2 res = [i / j for i, j in zip(df_reviews['Sentiment'][index], ext_list[index]) for index in range(len(df_reviews['Sentiment']))]
#
# Input In [37], in <listcomp>(.0)
#       1 #df_reviews['Average_sentiment'] = [(x for x in df_reviews['Sentiment'][index] / (y for y in ext_list[index])) for index in range(len(df_reviews['Sentiment']))]
# ----> 2 res = [i / j for i, j in zip(df_reviews['Sentiment'][index], ext_list[index]) for index in range(len(df_reviews['Sentiment']))]
#
# ZeroDivisionError: division by zero

# %%
df_reviews
# Out:
#       TitleId            MovieTitle  \
# 0     0235679  Pokémon 3: The Movie
# 1     0221889   Beautiful Creatures
# 2     0268200          Brigham City
# 3     0260332        روزی که زن شدم
# 4     0238588          Shadow Magic
# ...       ...                   ...
# 1991  0066579         Women in Love
# 1992  0322824                 Japón
# 1993  0285462             Boat Trip
# 1994  0285531          Dreamcatcher
# 1995  0323642    Piglet's Big Movie
#
#                                                  Actors  \
# 0     [Rica Matsumoto, Veronica Taylor, Rachael Lill...
# 1     [Susan Lynch, Iain Glen, Rachel Weisz, Tom Man...
# 2     [Richard Dutcher, Wilford Brimley, Carrie Morg...
# 3     [Fatemeh Cherag Akhar, Hassan Nebhan, Shahr Ba...
# 4     [Jared Harris, Yu Xia, Yufei Xing, Peiqi Liu, ...
# ...                                                 ...
# 1991  [Alan Bates, Oliver Reed, Glenda Jackson, Jenn...
# 1992  [Alejandro Ferretis, Magdalena Flores, Yolanda...
# 1993  [Horatio Sanz, Roselyn Sanchez, Maurice Godin,...
# 1994  [Morgan Freeman, Thomas Jane, Jason Lee, Damia...
# 1995  [John Fiedler, Jim Cummings, Andre Stojka, Kat...
#
#                                                  Genres  \
# 0     [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 2     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# ...                                                 ...
# 1991  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 1992  [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# 1993                     [{'id': 35, 'name': 'Comedy'}]
# 1994  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 1995  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
#
#                                                 Reviews Rating  \
# 0     [The other day, I was looking through some old...    5.8
# 1     [What I liked about the film "Beautiful Creatu...    5.8
# 2     [First and foremost, Brigham City is a murder ...    6.7
# 3     [I had completely forgotten about this movie, ...    7.3
# 4     [Ann Hus first directorial and writing effort...    7.2
# ...                                                 ...    ...
# 1991  [Ken Russell's adaptation of D. H. Lawrence's ...    7.1
# 1992  [Japon, a film by first-time director Carlos R...    6.9
# 1993  [Man I don't understand why people come down s...    4.9
# 1994  [This Stephen King adaptation is underrated, s...    5.5
# 1995  [Piglet's Big Movie is a sweet children's movi...    6.1
#
#                                           Review_tokens  \
# 0     [[the, other, day, i, was, looking, through, s...
# 1     [[what, i, liked, about, the, film, beautiful,...
# 2     [[first, and, foremost, brigham, city, is, a, ...
# 3     [[i, had, completely, forgotten, about, this, ...
# 4     [[ann, hu, s, first, directorial, and, writing...
# ...                                                 ...
# 1991  [[ken, russell, s, adaptation, of, d, h, lawre...
# 1992  [[japon, a, film, by, first, time, director, c...
# 1993  [[man, i, don, t, understand, why, people, com...
# 1994  [[this, stephen, king, adaptation, is, underra...
# 1995  [[piglet, s, big, movie, is, a, sweet, childre...
#
#                                               Sentiment
# 0     [755, 805, 1575, 1833, 1007, 1620, 1473, 1184,...
# 1     [1387, 1411, 1469, 2889, 910, 1358, 653, 720, ...
# 2     [2313, 1638, 965, 708, 962, 1521, 954, 358, 85...
# 3     [1031, 1260, 1444, 302, 515, 267, 1268, 592, 2...
# 4     [702, 865, 680, 599, 4113, 533, 608, 577, 463,...
# ...                                                 ...
# 1991  [1930, 1377, 3407, 2049, 1188, 576, 423, 825, ...
# 1992  [2763, 2241, 1864, 493, 1629, 1440, 794, 832, ...
# 1993  [965, 539, 600, 2531, 312, 961, 641, 772, 5041...
# 1994  [663, 3448, 1905, 4429, 2080, 555, 1621, 1369,...
# 1995  [787, 640, 845, 432, 734, 767, 69, 754, 924, 8...
#
# [1996 rows x 8 columns]

# %%
print(min(df_reviews['Average_sentiment']))
print(max(df_reviews['Average_sentiment']))
df_reviews.to_pickle("Sentiment_for_reviews.pkl")

# %%
avg_sentiemnt_for_movies = df_reviews.groupby(['titleId']).mean()
avg_sentiemnt_for_movies

# %%
print(min(avg_sentiemnt_for_movies['Average_sentiment']))
print(max(avg_sentiemnt_for_movies['Average_sentiment']))
